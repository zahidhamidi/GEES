# %% [markdown]
# <a href="https://colab.research.google.com/github/zahidhamidi/GEES/blob/main/CMDB_Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import libraries

import os
import pandas as pd
from openpyxl import load_workbook
import re
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## python script to read all file names directory in a folder

path = '/content/drive/MyDrive/PETRONAS/W4 November'


for root, directories, files in os.walk(path, topdown=False):
	for name in files:
		print(os.path.join(root, name))
	for name in directories:
		print(os.path.join(root, name))
# Out:
# /content/drive/MyDrive/PETRONAS/W4 November/34 CMDB EUD Batch Upload Template V1.0_08112021.xlsx
# /content/drive/MyDrive/PETRONAS/W4 November/People Details - 26 Aug 2021.xlsx
# /content/drive/MyDrive/PETRONAS/W4 November/ServiceOwner_OrderStatus_01Dec2021_Auto.xlsx
# /content/drive/MyDrive/PETRONAS/W4 November/DAAS (Desktop as a Service) Report – V2 - 01 Dec 2021.xlsx
# /content/drive/MyDrive/PETRONAS/W4 November/00 CMDB Register_COMPILED (3).xlsx
# /content/drive/MyDrive/PETRONAS/W4 November/35 CMDB EUD Batch Upload Template V1.0_18112021 (1).xlsx

# %%
##################################################################################################################################################################################



## Import excel file to pandas (Input ICT2u, 00 CMDB compiled, myGenie, People Details and CMDB Batch Upload Template file path here)
## xlsx1 = ICT2U
## xlsx2 = 00 CMDB Register compiled
## xlsx3 = myGenie DAAS
## xlsx4 = People Details
## xlsx5 = CMDB Batch upload template




xls1 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/W4 November/ServiceOwner_OrderStatus_01Dec2021_Auto.xlsx')
xls2 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/W4 November/00 CMDB Register_COMPILED (3).xlsx')
xls3 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/W4 November/DAAS (Desktop as a Service) Report – V2 - 01 Dec 2021.xlsx')
xls4 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/W4 November/People Details - 26 Aug 2021.xlsx')
xls5 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/W4 November/34 CMDB EUD Batch Upload Template V1.0_08112021.xlsx')


##############################################################################################################################################################################

# %%
## Read Excel Data with pandas

data1 = pd.read_excel(xls1, sheet_name="Sheet1")
acc1 = pd.read_excel(xls1, sheet_name="Sheet1")

data2 = pd.read_excel(xls2, sheet_name="CMDB Register Progress")
acc2 = pd.read_excel(xls2, sheet_name="CMDB Register Progress")

data3 = pd.read_excel(xls2, sheet_name="PC INFO")

data6 = pd.read_excel(xls3, sheet_name = "DAAS (Desktop as a Service) Rep")
acc6 = pd.read_excel(xls3, sheet_name = "DAAS (Desktop as a Service) Rep")

data7 = pd.read_excel(xls4, sheet_name = 'People Details')
acc7 = pd.read_excel(xls4, sheet_name = 'People Details')


data8 = pd.read_excel(xls5, sheet_name = 'Device Info')
acc8 = pd.read_excel(xls5, sheet_name = 'Device Info')

# %%
## Cleaning empty rows for data1

data1.columns.values[1] = "myGenie Request Number"

nan_value = float("NaN")

data1.replace("", nan_value, inplace=True)

data1.dropna(subset = ["myGenie Request Number"], inplace=True)


## Cleaning empty rows for acc1

acc1.columns.values[1] = "myGenie Request Number"

nan_value = float("NaN")

acc1.replace("", nan_value, inplace=True)

acc1.dropna(subset = ["myGenie Request Number"], inplace=True)

# %%
## Filter order item Status, Service Sub Category column

data1 = data1[(data1['Order Item Status'] == 'Completed') & (data1['Service Sub Category'] == 'Personal Computer (PC)')]


## Filter order item status for PC Accessories

acc1 = acc1[(acc1['Order Item Status'] == 'Completed') & (acc1['Service Sub Category'] == 'PC Accessories') & (acc1['Service Name'] != 'Headset') ]
acc1
# Out:
#       MyGeniie Created Date  ...                                      Order Details
# 276     Apr  9 2021 10:00AM  ...  Region Area : West Malaysia (Johor) | Alternat...
# 283     Apr  7 2021  3:39PM  ...  Region Area : PETT (T1) | Alternate Recipient ...
# 313     Apr 12 2021  1:53AM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 314     Apr 12 2021  1:53AM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 493     Apr 19 2021  6:44AM  ...  Region Area : West Malaysia (Johor) | Alternat...
# ...                     ...  ...                                                ...
# 13361   Oct 24 2021  9:14PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13363   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13364   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13365   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13366   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
#
# [682 rows x 25 columns]

# %%
## Convert Order Number column from float to int

data1['Order Number'] = data1['Order Number'].astype(int)



## Convert order number column from float to int for PC accessories

acc1['Order Number'] = acc1['Order Number'].astype(int)

# %%
## Clean required columns only for data1

data1 = pd.DataFrame(data1, columns= ['myGenie Request Number','Order Item Number', 'Service Name','Custodian User Name','Custodian Email','Delivery Address','Identifer 1 Value','Identifier 2 Value','Order Details' ])


## Clean required columns only for acc1

acc1 = pd.DataFrame(acc1, columns= ['myGenie Request Number','Order Item Number', 'Service Name','Custodian User Name','Custodian Email','Delivery Address','Identifer 1 Value','Identifier 2 Value','Order Details' ])
acc1
# Out:
#       myGenie Request Number  ...                                      Order Details
# 276          REQ000003546242  ...  Region Area : West Malaysia (Johor) | Alternat...
# 283          REQ000003540877  ...  Region Area : PETT (T1) | Alternate Recipient ...
# 313          REQ000003550044  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 314          REQ000003550045  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 493          REQ000003566374  ...  Region Area : West Malaysia (Johor) | Alternat...
# ...                      ...  ...                                                ...
# 13361        REQ000004019650  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13363        REQ000004019648  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13364        REQ000004019737  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13365        REQ000004019504  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 13366        REQ000004019649  ...  Region Area : PETT (T2) | Alternate Recipient ...
#
# [682 rows x 9 columns]

# %%
## Create Region column 

data1['Region'] = ""


## Create Region column 

acc1['Region'] = ""

# %%
## Cleaning empty rows for data1

nan_value = float("NaN")

data1.replace("", nan_value, inplace=True)

data1.dropna(subset = ["Delivery Address"], inplace=True)


## Cleaning empty rows for acc1

nan_value = float("NaN")

acc1.replace("", nan_value, inplace=True)

acc1.dropna(subset = ["Delivery Address"], inplace=True)

# %%
# ## Fill Region column relative to address data

# data1.assign(Region = "")

# if data1.loc[data1['Delivery Address'].str.contains("Kuala Lumpur")]:
#   data1.insert("Kuala Lumpur", "Region", "")
  

# # data1.loc[data1['Delivery Address'] == 'Kuala Lumpur', 'Region'] = 'Central'

# %%
## Clean required columns only for data2

data2 = pd.DataFrame(data2, columns= ['myGenie Request Number','STATUS'])


## Clean required columns only for data2

acc2 = pd.DataFrame(acc2, columns= ['myGenie Request Number','STATUS'])

# %%
## VLOOKUP myGenie Request Number   

outer_join = pd.merge(data1, 
                      data2, 
                      on ='myGenie Request Number', 
                      how ='outer')







## VLOOKUP myGenie Request Number (PC Accessories)  

acc_join = pd.merge(acc1, 
                      acc2, 
                      on ='myGenie Request Number', 
                      how ='outer')




acc_join
# Out:
#       myGenie Request Number  ...                          STATUS
# 0            REQ000003546242  ...  Requested to Register in  CMDB
# 1            REQ000003540877  ...  Requested to Register in  CMDB
# 2            REQ000003550044  ...  Requested to Register in  CMDB
# 3            REQ000003550045  ...  Requested to Register in  CMDB
# 4            REQ000003566374  ...  Requested to Register in  CMDB
# ...                      ...  ...                             ...
# 15536        REQ000004096243  ...  Requested to Register in  CMDB
# 15537        REQ000004096281  ...  Requested to Register in  CMDB
# 15538        REQ000004054654  ...  Requested to Register in  CMDB
# 15539        REQ000004054654  ...  Requested to Register in  CMDB
# 15540        REQ000004054654  ...  Requested to Register in  CMDB
#
# [15541 rows x 11 columns]

# %%
## Get only STATUS column not registered to CMDB

outer_join.drop(outer_join[outer_join['STATUS'] == "Requested to Register in  CMDB"].index, inplace = True)

data4 = outer_join[["Identifier 2 Value","Custodian Email"]]


data4 = data4.rename(columns={'Identifier 2 Value': 'Name'})




## Get only STATUS column not registered to CMDB (PC Accessories)

acc_join.drop(acc_join[acc_join['STATUS'] == "Requested to Register in  CMDB"].index, inplace = True)

acc4 = acc_join[["Identifier 2 Value","Custodian Email"]]


acc4 = acc4.rename(columns={'Identifier 2 Value': 'Name'})
acc4
# Out:
#            Name                      Custodian Email
# 619  5CG124ZX03              rajmanz@petronas.com.my
# 620  CN413039J4              rajmanz@petronas.com.my
# 622  CN413039K0    nurhazirah.ismail@petronas.com.my
# 649  CN413039J1   syifaainina.shukor@petronas.com.my
# 654  CN41303BQW  ainazulaikha.ahmady@petronas.com.my
# 655  CN41303BQV    nurqistina.azaman@petronas.com.my
# 657  CN413039HY          mnazricheon@petronas.com.my
# 658  5CG124ZX46          low.meishan@petronas.com.my
# 659  CN41303BPT          low.meishan@petronas.com.my
# 660  CN41182G14          mnazricheon@petronas.com.my
# 661  5CG124ZX2K          mnazricheon@petronas.com.my
# 664  CN41303BQ1           tankainhwa@petronas.com.my
# 665  5CG123ZCS4           tankainhwa@petronas.com.my
# 668  CN413039JX    sarah.limsuethoey@petronas.com.my
# 669  5CG124ZWW4    sarah.limsuethoey@petronas.com.my
# 672  CN41303BQ7                   hasnun@klcc.com.my
# 673  5CG126X7D6                   hasnun@klcc.com.my

# %%
#outer_join

# %%
## Create new columns

outer_join['Hostname'] = ''



outer_join.Hostname = 'H'     # A single value 'propagates' to all column cells



# Create new columns


acc_join['Hostname'] = ''



acc_join.Hostname = 'H'     # A single value 'propagates' to all column cells
acc_join
# Out:
#     myGenie Request Number  Order Item Number  ... STATUS Hostname
# 619        REQ000004047121          2683710.0  ...    NaN        H
# 620        REQ000004046867          2683709.0  ...    NaN        H
# 622        REQ000004043901          2683451.0  ...    NaN        H
# 649        REQ000004046790          2684411.0  ...    NaN        H
# 654        REQ000004051789          2684957.0  ...    NaN        H
# 655        REQ000004051872          2684968.0  ...    NaN        H
# 657        REQ000004057191          2685428.0  ...    NaN        H
# 658        REQ000004054309          2685301.0  ...    NaN        H
# 659        REQ000004054557          2685302.0  ...    NaN        H
# 660        REQ000004054797          2685316.0  ...    NaN        H
# 661        REQ000004055054          2685315.0  ...    NaN        H
# 664        REQ000004065721          2716172.0  ...    NaN        H
# 665        REQ000004065723          2716171.0  ...    NaN        H
# 668        REQ000004061380          2710756.0  ...    NaN        H
# 669        REQ000004061650          2710757.0  ...    NaN        H
# 672        REQ000004087362          2719682.0  ...    NaN        H
# 673        REQ000004087528          2719685.0  ...    NaN        H
#
# [17 rows x 12 columns]

# %%
## Rename columns

outer_join1 = outer_join.rename(columns={'Identifier 2 Value': 'Name'})


## Rename columns

acc_join1 = acc_join.rename(columns={'Identifier 2 Value': 'Name'})
acc_join1
# Out:
#     myGenie Request Number  Order Item Number  ... STATUS Hostname
# 619        REQ000004047121          2683710.0  ...    NaN        H
# 620        REQ000004046867          2683709.0  ...    NaN        H
# 622        REQ000004043901          2683451.0  ...    NaN        H
# 649        REQ000004046790          2684411.0  ...    NaN        H
# 654        REQ000004051789          2684957.0  ...    NaN        H
# 655        REQ000004051872          2684968.0  ...    NaN        H
# 657        REQ000004057191          2685428.0  ...    NaN        H
# 658        REQ000004054309          2685301.0  ...    NaN        H
# 659        REQ000004054557          2685302.0  ...    NaN        H
# 660        REQ000004054797          2685316.0  ...    NaN        H
# 661        REQ000004055054          2685315.0  ...    NaN        H
# 664        REQ000004065721          2716172.0  ...    NaN        H
# 665        REQ000004065723          2716171.0  ...    NaN        H
# 668        REQ000004061380          2710756.0  ...    NaN        H
# 669        REQ000004061650          2710757.0  ...    NaN        H
# 672        REQ000004087362          2719682.0  ...    NaN        H
# 673        REQ000004087528          2719685.0  ...    NaN        H
#
# [17 rows x 12 columns]

# %%
## Reorder columns in outer_join

outer_join1 = outer_join1[["Name","Hostname","Service Name"]]




## Reorder columns in outer_join

acc_join1 = acc_join1[["Name","Hostname","Service Name"]]
acc_join1
# Out:
#            Name Hostname     Service Name
# 619  5CG124ZX03        H  Docking Station
# 620  CN413039J4        H      Monitor 24”
# 622  CN413039K0        H      Monitor 24”
# 649  CN413039J1        H      Monitor 24”
# 654  CN41303BQW        H      Monitor 24”
# 655  CN41303BQV        H      Monitor 24”
# 657  CN413039HY        H      Monitor 24”
# 658  5CG124ZX46        H  Docking Station
# 659  CN41303BPT        H      Monitor 24”
# 660  CN41182G14        H      Monitor 24”
# 661  5CG124ZX2K        H  Docking Station
# 664  CN41303BQ1        H      Monitor 24”
# 665  5CG123ZCS4        H  Docking Station
# 668  CN413039JX        H      Monitor 24”
# 669  5CG124ZWW4        H  Docking Station
# 672  CN41303BQ7        H      Monitor 24”
# 673  5CG126X7D6        H  Docking Station

# %%
## Creating Hostname column

# making copy of Name column
new = outer_join1["Name"].copy()
 

# overwriting name column
outer_join1["Hostname"]= outer_join1["Hostname"].str.cat(new, sep="")
 




## Creating Hostname column

# making copy of Name column
new_acc = acc_join1["Name"].copy()
 

# overwriting name column
acc_join1["Hostname"]= acc_join1["Hostname"].str.cat(new_acc, sep="")
 
acc_join1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Name     Hostname     Service Name
# 619  5CG124ZX03  H5CG124ZX03  Docking Station
# 620  CN413039J4  HCN413039J4      Monitor 24”
# 622  CN413039K0  HCN413039K0      Monitor 24”
# 649  CN413039J1  HCN413039J1      Monitor 24”
# 654  CN41303BQW  HCN41303BQW      Monitor 24”
# 655  CN41303BQV  HCN41303BQV      Monitor 24”
# 657  CN413039HY  HCN413039HY      Monitor 24”
# 658  5CG124ZX46  H5CG124ZX46  Docking Station
# 659  CN41303BPT  HCN41303BPT      Monitor 24”
# 660  CN41182G14  HCN41182G14      Monitor 24”
# 661  5CG124ZX2K  H5CG124ZX2K  Docking Station
# 664  CN41303BQ1  HCN41303BQ1      Monitor 24”
# 665  5CG123ZCS4  H5CG123ZCS4  Docking Station
# 668  CN413039JX  HCN413039JX      Monitor 24”
# 669  5CG124ZWW4  H5CG124ZWW4  Docking Station
# 672  CN41303BQ7  HCN41303BQ7      Monitor 24”
# 673  5CG126X7D6  H5CG126X7D6  Docking Station

# %%
## PC part

outer_join1 = outer_join1[["Name","Name","Hostname","Service Name"]]

outer_join1.columns.values[1] = "Serial Number"

outer_join1['Operating System'] = ''
outer_join1['Status'] = ''
outer_join1['Status Reason'] = ''
outer_join1["Operating System"] = ''

outer_join1.Status = 'Deployed'






## PC Accessories part

acc_join1 = acc_join1[["Name","Name","Hostname","Service Name"]]

acc_join1.columns.values[1] = "Serial Number"

acc_join1['Operating System'] = ''
acc_join1['Status'] = ''
acc_join1['Status Reason'] = ''
acc_join1["Operating System"] = ''

acc_join1.Status = 'Deployed'

acc_join1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            Name Serial Number  ...    Status Status Reason
# 619  5CG124ZX03    5CG124ZX03  ...  Deployed
# 620  CN413039J4    CN413039J4  ...  Deployed
# 622  CN413039K0    CN413039K0  ...  Deployed
# 649  CN413039J1    CN413039J1  ...  Deployed
# 654  CN41303BQW    CN41303BQW  ...  Deployed
# 655  CN41303BQV    CN41303BQV  ...  Deployed
# 657  CN413039HY    CN413039HY  ...  Deployed
# 658  5CG124ZX46    5CG124ZX46  ...  Deployed
# 659  CN41303BPT    CN41303BPT  ...  Deployed
# 660  CN41182G14    CN41182G14  ...  Deployed
# 661  5CG124ZX2K    5CG124ZX2K  ...  Deployed
# 664  CN41303BQ1    CN41303BQ1  ...  Deployed
# 665  5CG123ZCS4    5CG123ZCS4  ...  Deployed
# 668  CN413039JX    CN413039JX  ...  Deployed
# 669  5CG124ZWW4    5CG124ZWW4  ...  Deployed
# 672  CN41303BQ7    CN41303BQ7  ...  Deployed
# 673  5CG126X7D6    5CG126X7D6  ...  Deployed
#
# [17 rows x 7 columns]

# %%
## Clean required columns only for data3

data8 = pd.DataFrame(data8, columns= ['ICT2U Model','Category',"Type",'Item','Capability List','PC Model','RAM'])
data8


## Clean required columns only for acc3 (PC Accessories)

acc8 = pd.DataFrame(data8, columns= ['ICT2U Model','Category',"Type",'Item','Capability List','PC Model','RAM'])
acc8
# Out:
#                                        ICT2U Model  ...    RAM
# 0                                            Riser  ...    NaN
# 1                                    Laptop (8 GB)  ...    8GB
# 2                                   Laptop (16 GB)  ...   16GB
# 3                                    Laptop 2-in-1  ...   16GB
# 4                                      Monitor 24”  ...    NaN
# 5                                  Laptop Standard  ...   16GB
# 6                               Desktop All-in-One  ...    8GB
# 7                                 Desktop Standard  ...    8GB
# 8                                  Docking Station  ...    NaN
# 9                                      Monitor 30"  ...    NaN
# 10                            Workstation Standard  ...  128GB
# 11                              Workstation Mobile  ...   32GB
# 12                                            iPad  ...    NaN
# 13                                iPad Accessories  ...    NaN
# 14      Intrinsically Safe Certified Zone 1 Tablet  ...    NaN
# 15  Intrinsically Safe Certified Zone 1 Smartphone  ...    NaN
#
# [16 rows x 7 columns]

# %%
## Rename columns

data3 = data8.rename(columns={'ICT2U Model': 'Service Name'})

data3



## Rename columns

acc3 = acc8.rename(columns={'ICT2U Model': 'Service Name'})

acc3
# Out:
#                                       Service Name  ...    RAM
# 0                                            Riser  ...    NaN
# 1                                    Laptop (8 GB)  ...    8GB
# 2                                   Laptop (16 GB)  ...   16GB
# 3                                    Laptop 2-in-1  ...   16GB
# 4                                      Monitor 24”  ...    NaN
# 5                                  Laptop Standard  ...   16GB
# 6                               Desktop All-in-One  ...    8GB
# 7                                 Desktop Standard  ...    8GB
# 8                                  Docking Station  ...    NaN
# 9                                      Monitor 30"  ...    NaN
# 10                            Workstation Standard  ...  128GB
# 11                              Workstation Mobile  ...   32GB
# 12                                            iPad  ...    NaN
# 13                                iPad Accessories  ...    NaN
# 14      Intrinsically Safe Certified Zone 1 Tablet  ...    NaN
# 15  Intrinsically Safe Certified Zone 1 Smartphone  ...    NaN
#
# [16 rows x 7 columns]

# %%
## VLOOKUP myGenie Request Number   

outer_join2 = pd.merge(outer_join, 
                      data3, 
                      on ='Service Name', 
                      how ='outer')


## Cleaning empty rows for outer_join2

nan_value = float("NaN")

outer_join2.replace("", nan_value, inplace=True)

outer_join2.dropna(subset = ["myGenie Request Number"], inplace=True)






## VLOOKUP myGenie Request Number   

acc_join2 = pd.merge(acc_join, 
                      acc3, 
                      on ='Service Name', 
                      how ='outer')


## Cleaning empty rows for outer_join2

nan_value = float("NaN")

acc_join2.replace("", nan_value, inplace=True)

acc_join2.dropna(subset = ["myGenie Request Number"], inplace=True)



acc_join2
# Out:
#    myGenie Request Number  Order Item Number  ...              PC Model  RAM
# 0         REQ000004047121          2683710.0  ...      HP USB-C Dock G4  NaN
# 1         REQ000004054309          2685301.0  ...      HP USB-C Dock G4  NaN
# 2         REQ000004055054          2685315.0  ...      HP USB-C Dock G4  NaN
# 3         REQ000004065723          2716171.0  ...      HP USB-C Dock G4  NaN
# 4         REQ000004061650          2710757.0  ...      HP USB-C Dock G4  NaN
# 5         REQ000004087528          2719685.0  ...      HP USB-C Dock G4  NaN
# 6         REQ000004046867          2683709.0  ...  HP EliteDisplay E243  NaN
# 7         REQ000004043901          2683451.0  ...  HP EliteDisplay E243  NaN
# 8         REQ000004046790          2684411.0  ...  HP EliteDisplay E243  NaN
# 9         REQ000004051789          2684957.0  ...  HP EliteDisplay E243  NaN
# 10        REQ000004051872          2684968.0  ...  HP EliteDisplay E243  NaN
# 11        REQ000004057191          2685428.0  ...  HP EliteDisplay E243  NaN
# 12        REQ000004054557          2685302.0  ...  HP EliteDisplay E243  NaN
# 13        REQ000004054797          2685316.0  ...  HP EliteDisplay E243  NaN
# 14        REQ000004065721          2716172.0  ...  HP EliteDisplay E243  NaN
# 15        REQ000004061380          2710756.0  ...  HP EliteDisplay E243  NaN
# 16        REQ000004087362          2719682.0  ...  HP EliteDisplay E243  NaN
#
# [17 rows x 18 columns]

# %%
## Clean required columns only for outer_join2

outer_join2 = pd.DataFrame(outer_join2, columns= ['Service Name','Category',"Type",'Item','PC Model','RAM','PC Model','Capability List'])




## Clean required columns only for acc_join2

acc_join2 = pd.DataFrame(acc_join2, columns= ['Service Name','Category',"Type",'Item','PC Model','RAM','PC Model','Capability List'])

acc_join2
# Out:
#        Service Name  Category  ...              PC Model Capability List
# 0   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 1   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 2   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 3   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 4   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 5   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 6       Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 7       Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 8       Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 9       Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 10      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 11      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 12      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 13      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 14      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 15      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 16      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
#
# [17 rows x 8 columns]

# %%
# merge1 = pd.merge(outer_join1, outer_join2, on='Service Name')

# merge1

## VLOOKUP myGenie Request Number   

merge1 = pd.merge(outer_join1, 
                      outer_join2, 
                      on ='Service Name', 
                      how ='outer')

final1 = merge1.drop_duplicates(subset="Serial Number")



## Part 2 PC Accessories

   
macc1 = pd.merge(acc_join1, 
                      acc_join2, 
                      on ='Service Name', 
                      how ='outer')

facc1 = macc1.drop_duplicates(subset="Serial Number")

facc1
# Out:
#            Name Serial Number  ...              PC Model Capability List
# 0    5CG124ZX03    5CG124ZX03  ...      HP USB-C Dock G4           Other
# 6    5CG124ZX46    5CG124ZX46  ...      HP USB-C Dock G4           Other
# 12   5CG124ZX2K    5CG124ZX2K  ...      HP USB-C Dock G4           Other
# 18   5CG123ZCS4    5CG123ZCS4  ...      HP USB-C Dock G4           Other
# 24   5CG124ZWW4    5CG124ZWW4  ...      HP USB-C Dock G4           Other
# 30   5CG126X7D6    5CG126X7D6  ...      HP USB-C Dock G4           Other
# 36   CN413039J4    CN413039J4  ...  HP EliteDisplay E243           Other
# 47   CN413039K0    CN413039K0  ...  HP EliteDisplay E243           Other
# 58   CN413039J1    CN413039J1  ...  HP EliteDisplay E243           Other
# 69   CN41303BQW    CN41303BQW  ...  HP EliteDisplay E243           Other
# 80   CN41303BQV    CN41303BQV  ...  HP EliteDisplay E243           Other
# 91   CN413039HY    CN413039HY  ...  HP EliteDisplay E243           Other
# 102  CN41303BPT    CN41303BPT  ...  HP EliteDisplay E243           Other
# 113  CN41182G14    CN41182G14  ...  HP EliteDisplay E243           Other
# 124  CN41303BQ1    CN41303BQ1  ...  HP EliteDisplay E243           Other
# 135  CN413039JX    CN413039JX  ...  HP EliteDisplay E243           Other
# 146  CN41303BQ7    CN41303BQ7  ...  HP EliteDisplay E243           Other
#
# [17 rows x 14 columns]

# %%
## Part 1

final1.drop('Service Name',
  axis='columns', inplace=True)



## Part 2

facc1.drop('Service Name',
  axis='columns', inplace=True)



facc1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#            Name Serial Number  ...              PC Model Capability List
# 0    5CG124ZX03    5CG124ZX03  ...      HP USB-C Dock G4           Other
# 6    5CG124ZX46    5CG124ZX46  ...      HP USB-C Dock G4           Other
# 12   5CG124ZX2K    5CG124ZX2K  ...      HP USB-C Dock G4           Other
# 18   5CG123ZCS4    5CG123ZCS4  ...      HP USB-C Dock G4           Other
# 24   5CG124ZWW4    5CG124ZWW4  ...      HP USB-C Dock G4           Other
# 30   5CG126X7D6    5CG126X7D6  ...      HP USB-C Dock G4           Other
# 36   CN413039J4    CN413039J4  ...  HP EliteDisplay E243           Other
# 47   CN413039K0    CN413039K0  ...  HP EliteDisplay E243           Other
# 58   CN413039J1    CN413039J1  ...  HP EliteDisplay E243           Other
# 69   CN41303BQW    CN41303BQW  ...  HP EliteDisplay E243           Other
# 80   CN41303BQV    CN41303BQV  ...  HP EliteDisplay E243           Other
# 91   CN413039HY    CN413039HY  ...  HP EliteDisplay E243           Other
# 102  CN41303BPT    CN41303BPT  ...  HP EliteDisplay E243           Other
# 113  CN41182G14    CN41182G14  ...  HP EliteDisplay E243           Other
# 124  CN41303BQ1    CN41303BQ1  ...  HP EliteDisplay E243           Other
# 135  CN413039JX    CN413039JX  ...  HP EliteDisplay E243           Other
# 146  CN41303BQ7    CN41303BQ7  ...  HP EliteDisplay E243           Other
#
# [17 rows x 13 columns]

# %%
## VLOOKUP myGenie Request Number   

merge2 = pd.merge(final1, 
                      data4, 
                      on ='Name', 
                      how ='outer')






## VLOOKUP myGenie Request Number  (PC Accessories) 

macc2 = pd.merge(facc1, 
                      acc4, 
                      on ='Name', 
                      how ='outer')




macc2
# Out:
#           Name  ...                      Custodian Email
# 0   5CG124ZX03  ...              rajmanz@petronas.com.my
# 1   5CG124ZX46  ...          low.meishan@petronas.com.my
# 2   5CG124ZX2K  ...          mnazricheon@petronas.com.my
# 3   5CG123ZCS4  ...           tankainhwa@petronas.com.my
# 4   5CG124ZWW4  ...    sarah.limsuethoey@petronas.com.my
# 5   5CG126X7D6  ...                   hasnun@klcc.com.my
# 6   CN413039J4  ...              rajmanz@petronas.com.my
# 7   CN413039K0  ...    nurhazirah.ismail@petronas.com.my
# 8   CN413039J1  ...   syifaainina.shukor@petronas.com.my
# 9   CN41303BQW  ...  ainazulaikha.ahmady@petronas.com.my
# 10  CN41303BQV  ...    nurqistina.azaman@petronas.com.my
# 11  CN413039HY  ...          mnazricheon@petronas.com.my
# 12  CN41303BPT  ...          low.meishan@petronas.com.my
# 13  CN41182G14  ...          mnazricheon@petronas.com.my
# 14  CN41303BQ1  ...           tankainhwa@petronas.com.my
# 15  CN413039JX  ...    sarah.limsuethoey@petronas.com.my
# 16  CN41303BQ7  ...                   hasnun@klcc.com.my
#
# [17 rows x 14 columns]

# %%
## Part 1

delivery = outer_join[["Delivery Address","Identifier 2 Value"]]


deli = delivery.rename(columns={'Identifier 2 Value': 'Name'})

deli

merge2 = pd.merge(merge2, 
                      deli, 
                      on ='Name', 
                      how ='outer')



## Part 2

delivery_acc = acc_join[["Delivery Address","Identifier 2 Value"]]


deli_acc = delivery_acc.rename(columns={'Identifier 2 Value': 'Name'})

deli_acc

macc2 = pd.merge(macc2, 
                      deli_acc, 
                      on ='Name', 
                      how ='outer')

# %%
# req = merge2["Category"]

# merge2.insert(loc=7,column = "Type", value = req)

merge2.columns.values[11] = "Short Description"


## Part 2

macc2.columns.values[11] = "Short Description"

# %%
macc2
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG124ZX03  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 1   5CG124ZX46  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 2   5CG124ZX2K  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 3   5CG123ZCS4  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 4   5CG124ZWW4  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 5   5CG126X7D6  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
# 6   CN413039J4  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 7   CN413039K0  ...  LVL 16, Tower 1, KLCC, 50450, KUALA LUMPUR, Ma...
# 8   CN413039J1  ...  Level 16 Tower 1 , KLCC, 50450, Kuala Lumpur, ...
# 9   CN41303BQW  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 10  CN41303BQV  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 11  CN413039HY  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 12  CN41303BPT  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 13  CN41182G14  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 14  CN41303BQ1  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 15  CN413039JX  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 16  CN41303BQ7  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
#
# [17 rows x 15 columns]

# %%
## Part 1
merge3 = merge2[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Capability List","Custodian Email","Custodian Email","Custodian Email","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]

## Part 2
macc3 = macc2[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Capability List","Custodian Email","Custodian Email","Custodian Email","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG124ZX03  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 1   5CG124ZX46  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 2   5CG124ZX2K  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 3   5CG123ZCS4  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 4   5CG124ZWW4  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 5   5CG126X7D6  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
# 6   CN413039J4  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 7   CN413039K0  ...  LVL 16, Tower 1, KLCC, 50450, KUALA LUMPUR, Ma...
# 8   CN413039J1  ...  Level 16 Tower 1 , KLCC, 50450, Kuala Lumpur, ...
# 9   CN41303BQW  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 10  CN41303BQV  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 11  CN413039HY  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 12  CN41303BPT  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 13  CN41182G14  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 14  CN41303BQ1  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 15  CN413039JX  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 16  CN41303BQ7  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
#
# [17 rows x 19 columns]

# %%
## Part 1

merge3.columns.values[10] = "Owned by"
merge3.columns.values[11] = "Owned by (Regional Focal Email)"
merge3.columns.values[12] = "Used by (User Email)"

## Part 2

macc3.columns.values[10] = "Owned by"
macc3.columns.values[11] = "Owned by (Regional Focal Email)"
macc3.columns.values[12] = "Used by (User Email)"
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG124ZX03  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 1   5CG124ZX46  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 2   5CG124ZX2K  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 3   5CG123ZCS4  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 4   5CG124ZWW4  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 5   5CG126X7D6  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
# 6   CN413039J4  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 7   CN413039K0  ...  LVL 16, Tower 1, KLCC, 50450, KUALA LUMPUR, Ma...
# 8   CN413039J1  ...  Level 16 Tower 1 , KLCC, 50450, Kuala Lumpur, ...
# 9   CN41303BQW  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 10  CN41303BQV  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 11  CN413039HY  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 12  CN41303BPT  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 13  CN41182G14  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 14  CN41303BQ1  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 15  CN413039JX  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 16  CN41303BQ7  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
#
# [17 rows x 19 columns]

# %%
## Part 1

merge3['Supported'] = ''



merge3.Supported = 'PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT'     # A single value 'propagates' to all column cells


## Part 2

macc3['Supported'] = ''



macc3.Supported = 'PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT'     # A single value 'propagates' to all column cells
macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#           Name  ...                                Supported
# 0   5CG124ZX03  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 1   5CG124ZX46  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 2   5CG124ZX2K  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 3   5CG123ZCS4  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 4   5CG124ZWW4  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 5   5CG126X7D6  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 6   CN413039J4  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 7   CN413039K0  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 8   CN413039J1  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 9   CN41303BQW  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 10  CN41303BQV  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 11  CN413039HY  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 12  CN41303BPT  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 13  CN41182G14  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 14  CN41303BQ1  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 15  CN413039JX  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 16  CN41303BQ7  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
#
# [17 rows x 20 columns]

# %%
## Part 1

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
merge3
# Out:
#            Name  ...                                   Delivery Address
# 0           NaN  ...  PETRONAS Refinery & Petrochemical Corp Sdn Bhd...
# 1           NaN  ...  PETRONAS Refinery & Petrochemical Corp Sdn Bhd...
# 2           NaN  ...  Concourse, Tower 1, PETRONAS Twin Towers, 5008...
# 3           NaN  ...  Concourse, Tower 1, PETRONAS Twin Towers, 5008...
# 4           NaN  ...  Concourse, Tower 1, PETRONAS Twin Tower, 50088...
# ..          ...  ...                                                ...
# 155  5CD135BFDM  ...  petronas gas berhad utilities kerteh, kerteh i...
# 156  CND1330L36  ...  Level 33 Tower 1, PETRONAS Twin Towers, 50088,...
# 157  CND1330L11  ...  Level 43, Tower 1, 50088, KL, Federal Territor...
# 158  CND1330L2D  ...  Level 43, Tower 1, 50088, KL, Federal Territor...
# 159  CND119066H  ...  Level 63, T1, PETT, KLCC, 50088, Kuala Lumpur,...
#
# [160 rows x 22 columns]

# %%
## Part 2

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG124ZX03  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 1   5CG124ZX46  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 2   5CG124ZX2K  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 3   5CG123ZCS4  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 4   5CG124ZWW4  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 5   5CG126X7D6  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
# 6   CN413039J4  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 7   CN413039K0  ...  LVL 16, Tower 1, KLCC, 50450, KUALA LUMPUR, Ma...
# 8   CN413039J1  ...  Level 16 Tower 1 , KLCC, 50450, Kuala Lumpur, ...
# 9   CN41303BQW  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 10  CN41303BQV  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 11  CN413039HY  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 12  CN41303BPT  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 13  CN41182G14  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 14  CN41303BQ1  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 15  CN413039JX  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 16  CN41303BQ7  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
#
# [17 rows x 22 columns]

# %%
## Part 1

merge3.columns.values[13] = "Supported by (MyGenie Support Group)"
merge3.columns.values[14] = "Model"
merge3.columns.values[15] = "Total RAM"
merge3.columns.values[19] = "Primary Capability"
merge3.columns.values[21] = "Location"


## Part 2

macc3.columns.values[13] = "Supported by (MyGenie Support Group)"
macc3.columns.values[14] = "Model"
macc3.columns.values[15] = "Total RAM"
macc3.columns.values[19] = "Primary Capability"
macc3.columns.values[21] = "Location"

macc3
# Out:
#           Name  ...                                           Location
# 0   5CG124ZX03  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 1   5CG124ZX46  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 2   5CG124ZX2K  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 3   5CG123ZCS4  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 4   5CG124ZWW4  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 5   5CG126X7D6  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
# 6   CN413039J4  ...  Level 65, Tower 1, Petronas Twin Towers, KLCC,...
# 7   CN413039K0  ...  LVL 16, Tower 1, KLCC, 50450, KUALA LUMPUR, Ma...
# 8   CN413039J1  ...  Level 16 Tower 1 , KLCC, 50450, Kuala Lumpur, ...
# 9   CN41303BQW  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 10  CN41303BQV  ...  LEVEL 16, TOWER 1, KLCC, 50450, KUALA LUMPUR, ...
# 11  CN413039HY  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 12  CN41303BPT  ...  Level 68, Tower 1, PETT KLCC, 50088, Kuala Lum...
# 13  CN41182G14  ...  LEVEL 19, TOWER 1, PETRONAS TWIN TOWERS, 50088...
# 14  CN41303BQ1  ...  Workstation #057, Level 10, Tower 3, 50088, KL...
# 15  CN413039JX  ...  Level 20, Tower 2 PETRONAS Twin Towers, Kuala ...
# 16  CN41303BQ7  ...  Level 32, Menara Dayabumi, KLCC Projek Service...
#
# [17 rows x 22 columns]

# %%
## Part 1 

OPU_column = pd.DataFrame(data1, columns = ["Custodian Email","Identifer 1 Value"])
OPU_column.columns.values[0] = "Owned by"

## Part 2

OPU_acc = pd.DataFrame(acc1, columns = ["Custodian Email","Identifer 1 Value"])
OPU_acc.columns.values[0] = "Owned by"
OPU_acc
# Out:
#                                   Owned by          Identifer 1 Value
# 276      mohammadfahmi.myusof@prefchem.com     PENGERANG RC SDN. BHD.
# 283    rajashaharaputra.ra@petronas.com.my         Petrosains Sdn Bhd
# 313       nurzaimah.razali@petronas.com.my  Petronas Carigali Sdn Bhd
# 314       nurzaimah.razali@petronas.com.my  Petronas Carigali Sdn Bhd
# 493         ashraff.mashal@petronas.com.my  PET Ref & Petchem Corp SB
# ...                                    ...                        ...
# 13361    norshazlina.azlan@petronas.com.my  Petroliam Nasional Berhad
# 13363    norshazlina.azlan@petronas.com.my  Petroliam Nasional Berhad
# 13364     hassan_abdullahb@petronas.com.my  Petroliam Nasional Berhad
# 13365  aiman.shamsuliwardi@petronas.com.my  Petroliam Nasional Berhad
# 13366         edurrah.jani@petronas.com.my  Petroliam Nasional Berhad
#
# [682 rows x 2 columns]

# %%
## Part 1

merge3['Manufacturer'] = ''
merge3['Domain'] = ''
merge3['Region'] = ''
merge3['OPU'] = ''



## Part 2

macc3['Manufacturer'] = ''
macc3['Domain'] = ''
macc3['Region'] = ''
macc3['OPU'] = ''

macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#           Name Serial Number     Hostname  ... Domain Region OPU
# 0   5CG124ZX03    5CG124ZX03  H5CG124ZX03  ...
# 1   5CG124ZX46    5CG124ZX46  H5CG124ZX46  ...
# 2   5CG124ZX2K    5CG124ZX2K  H5CG124ZX2K  ...
# 3   5CG123ZCS4    5CG123ZCS4  H5CG123ZCS4  ...
# 4   5CG124ZWW4    5CG124ZWW4  H5CG124ZWW4  ...
# 5   5CG126X7D6    5CG126X7D6  H5CG126X7D6  ...
# 6   CN413039J4    CN413039J4  HCN413039J4  ...
# 7   CN413039K0    CN413039K0  HCN413039K0  ...
# 8   CN413039J1    CN413039J1  HCN413039J1  ...
# 9   CN41303BQW    CN41303BQW  HCN41303BQW  ...
# 10  CN41303BQV    CN41303BQV  HCN41303BQV  ...
# 11  CN413039HY    CN413039HY  HCN413039HY  ...
# 12  CN41303BPT    CN41303BPT  HCN41303BPT  ...
# 13  CN41182G14    CN41182G14  HCN41182G14  ...
# 14  CN41303BQ1    CN41303BQ1  HCN41303BQ1  ...
# 15  CN413039JX    CN413039JX  HCN413039JX  ...
# 16  CN41303BQ7    CN41303BQ7  HCN41303BQ7  ...
#
# [17 rows x 26 columns]

# %%
## Part 1

merge3.Manufacturer = 'Hewlett Packard'     # A single value 'propagates' to all column cells

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region"]]


## Part 2

macc3.Manufacturer = 'Hewlett Packard'     # A single value 'propagates' to all column cells

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region"]]
macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#           Name  ... Region
# 0   5CG124ZX03  ...
# 1   5CG124ZX46  ...
# 2   5CG124ZX2K  ...
# 3   5CG123ZCS4  ...
# 4   5CG124ZWW4  ...
# 5   5CG126X7D6  ...
# 6   CN413039J4  ...
# 7   CN413039K0  ...
# 8   CN413039J1  ...
# 9   CN41303BQW  ...
# 10  CN41303BQV  ...
# 11  CN413039HY  ...
# 12  CN41303BPT  ...
# 13  CN41182G14  ...
# 14  CN41303BQ1  ...
# 15  CN413039JX  ...
# 16  CN41303BQ7  ...
#
# [17 rows x 24 columns]

# %%
## Part 1
# Inset OPU Column

merge3 = pd.merge(merge3, 
                      OPU_column, 
                      on ='Owned by', 
                      how ='left')

merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)


merge3
# Out:
#             Name Serial Number  ... Region          Identifer 1 Value
# 0            NaN           NaN  ...         Petroliam Nasional Berhad
# 540          NaN           NaN  ...         Petroliam Nasional Berhad
# 600          NaN           NaN  ...         Petroliam Nasional Berhad
# 660          NaN           NaN  ...         Petroliam Nasional Berhad
# 720          NaN           NaN  ...          PETRONAS DIGITAL SDN BHD
# 780   5CD135B4MD    5CD135B4MD  ...          Gas District Cooling (M)
# 781   5CD13577FM    5CD13577FM  ...          PETRONAS DIGITAL SDN BHD
# 782   5CD13577C4    5CD13577C4  ...          PRPC Util. & Facilit. SB
# 783   5CD13577HT    5CD13577HT  ...          PETRONAS DIGITAL SDN BHD
# 784   5CD13577BN    5CD13577BN  ...         Petroliam Nasional Berhad
# 785   5CD13577H0    5CD13577H0  ...         Petronas Carigali Sdn Bhd
# 786   5CD13577CW    5CD13577CW  ...          PETRONAS Dagangan Berhad
# 787   5CD13577D7    5CD13577D7  ...            PENGERANG RC SDN. BHD.
# 829   5CD135B48G    5CD135B48G  ...          PRPC Util. & Facilit. SB
# 833   5CD135B4BR    5CD135B4BR  ...          PETRONAS Lubricants Intl
# 837   5CD13577BS    5CD13577BS  ...         Petroliam Nasional Berhad
# 838   5CD112FHL6    5CD112FHL6  ...         Petronas Carigali Sdn Bhd
# 839   5CD13577JG    5CD13577JG  ...         Petroliam Nasional Berhad
# 1134  5CD13577KL    5CD13577KL  ...          PETRONAS Dagangan Berhad
# 1135  5CG9249GZY    5CG9249GZY  ...         Petroliam Nasional Berhad
# 1136  5CD13577LR    5CD13577LR  ...         Petroliam Nasional Berhad
# 1137  5CD135B54X    5CD135B54X  ...         Petroliam Nasional Berhad
# 1138  5CD112FHN0    5CD112FHN0  ...         Petronas Carigali Sdn Bhd
# 1139  5CD13577GW    5CD13577GW  ...         Petronas Carigali Sdn Bhd
# 1140  5CD13577HP    5CD13577HP  ...         Petroliam Nasional Berhad
# 1141  5CD135B43Y    5CD135B43Y  ...         Petroliam Nasional Berhad
# 1142  5CD135BFF0    5CD135BFF0  ...         Petroliam Nasional Berhad
# 1143  5CG9249GTS    5CG9249GTS  ...         Petroliam Nasional Berhad
# 1144  5CD13577GS    5CD13577GS  ...         Petroliam Nasional Berhad
# 1145  5CD135B4F0    5CD135B4F0  ...         Petronas Carigali Sdn Bhd
# 1146  5CD135B433    5CD135B433  ...              KLCC PROJEKS SDN BHD
# 1147  5CD13577GZ    5CD13577GZ  ...                Petrosains Sdn Bhd
# 1151  5CD13577KQ    5CD13577KQ  ...         Petroliam Nasional Berhad
# 1152  5CD13577J2    5CD13577J2  ...          PETRONAS DIGITAL SDN BHD
# 1153  5CD13577J9    5CD13577J9  ...         Petronas Carigali Sdn Bhd
# 1154  5CD1357785    5CD1357785  ...          PETRONAS Dagangan Berhad
# 1155  5CG94732MQ    5CG94732MQ  ...         Petroliam Nasional Berhad
# 1156  5CD112FHQD    5CD112FHQD  ...         Petronas Carigali Sdn Bhd
# 1157  5CD13577GQ    5CD13577GQ  ...         Petronas Carigali Sdn Bhd
# 1158  5CD13577KS    5CD13577KS  ...         Petronas Carigali Sdn Bhd
# 1159  5CD13577HR    5CD13577HR  ...         Petronas Carigali Sdn Bhd
# 1160  5CD13577H2    5CD13577H2  ...         Petroliam Nasional Berhad
# 1280  5CD13577G3    5CD13577G3  ...          Petronas Chemicals Group
# 1281  5CD135B43F    5CD135B43F  ...              KLCC PROJEKS SDN BHD
# 1282  5CD13577HM    5CD13577HM  ...          PETRONAS DIGITAL SDN BHD
# 1286  5CD13577HY    5CD13577HY  ...         Petroliam Nasional Berhad
# 1287  5CD135BFDM    5CD135BFDM  ...               PETRONAS Gas Berhad
# 1288  CND1330L36    CND1330L36  ...         P'NAS Chem Mktg (Labuan)
# 1289  CND1330L11    CND1330L11  ...          PETRONAS DIGITAL SDN BHD
# 1290  CND1330L2D    CND1330L2D  ...         Petroliam Nasional Berhad
# 1291  CND119066H    CND119066H  ...         Petroliam Nasional Berhad
#
# [51 rows x 25 columns]

# %%
## Part 2
# Inset OPU Column

macc3 = pd.merge(macc3, 
                      OPU_acc, 
                      on ='Owned by', 
                      how ='left')

macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... Region          Identifer 1 Value
# 0   5CG124ZX03    5CG124ZX03  ...         Petroliam Nasional Berhad
# 2   5CG124ZX46    5CG124ZX46  ...         Petroliam Nasional Berhad
# 4   5CG124ZX2K    5CG124ZX2K  ...         Petroliam Nasional Berhad
# 7   5CG123ZCS4    5CG123ZCS4  ...         Petroliam Nasional Berhad
# 9   5CG124ZWW4    5CG124ZWW4  ...         Petronas Carigali Sdn Bhd
# 11  5CG126X7D6    5CG126X7D6  ...              KLCC PROJEKS SDN BHD
# 15  CN413039K0    CN413039K0  ...         Petroliam Nasional Berhad
# 16  CN413039J1    CN413039J1  ...         Petroliam Nasional Berhad
# 17  CN41303BQW    CN41303BQW  ...         Petroliam Nasional Berhad
# 18  CN41303BQV    CN41303BQV  ...         Petroliam Nasional Berhad
#
# [10 rows x 25 columns]

# %%
## Part 1

merge3.columns.values[24] = "OPU"

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region","OPU"]]

merge3['Project Number'] = ''
merge3['Project Name'] = ''
merge3['Asset Type'] = ''
merge3['SAP Asset Number'] = ''


## Part 2

macc3.columns.values[24] = "OPU"

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region","OPU"]]

macc3['Project Number'] = ''
macc3['Project Name'] = ''
macc3['Asset Type'] = ''
macc3['SAP Asset Number'] = ''

macc3
# Out:
#           Name Serial Number  ... Asset Type SAP Asset Number
# 0   5CG124ZX03    5CG124ZX03  ...
# 2   5CG124ZX46    5CG124ZX46  ...
# 4   5CG124ZX2K    5CG124ZX2K  ...
# 7   5CG123ZCS4    5CG123ZCS4  ...
# 9   5CG124ZWW4    5CG124ZWW4  ...
# 11  5CG126X7D6    5CG126X7D6  ...
# 15  CN413039K0    CN413039K0  ...
# 16  CN413039J1    CN413039J1  ...
# 17  CN41303BQW    CN41303BQW  ...
# 18  CN41303BQV    CN41303BQV  ...
#
# [10 rows x 29 columns]

# %%
## Part 1

ict2u_column = pd.DataFrame(data1, columns = ["Custodian Email","Order Item Number"])

ict2u_column.columns.values[1] = "ICT2U Order Number"
ict2u_column.columns.values[0] = "Owned by"


## Part 2

ict2u_acc = pd.DataFrame(acc1, columns = ["Custodian Email","Order Item Number"])

ict2u_acc.columns.values[1] = "ICT2U Order Number"
ict2u_acc.columns.values[0] = "Owned by"

ict2u_acc
# Out:
#                                   Owned by  ICT2U Order Number
# 276      mohammadfahmi.myusof@prefchem.com             2488220
# 283    rajashaharaputra.ra@petronas.com.my             2488520
# 313       nurzaimah.razali@petronas.com.my             2488369
# 314       nurzaimah.razali@petronas.com.my             2488370
# 493         ashraff.mashal@petronas.com.my             2504550
# ...                                    ...                 ...
# 13361    norshazlina.azlan@petronas.com.my             2680972
# 13363    norshazlina.azlan@petronas.com.my             2680983
# 13364     hassan_abdullahb@petronas.com.my             2680982
# 13365  aiman.shamsuliwardi@petronas.com.my             2680981
# 13366         edurrah.jani@petronas.com.my             2680984
#
# [682 rows x 2 columns]

# %%
## Part 1
# Inset Order Number Column

merge3 = pd.merge(merge3, 
                      ict2u_column, 
                      on ='Owned by', 
                      how ='inner')

merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)


merge3
# Out:
#            Name Serial Number  ... SAP Asset Number ICT2U Order Number
# 0           NaN           NaN  ...                             2652687
# 27          NaN           NaN  ...                             2465934
# 30          NaN           NaN  ...                             2483252
# 33          NaN           NaN  ...                             2483267
# 36          NaN           NaN  ...                             2721759
# 39   5CD135B4MD    5CD135B4MD  ...                             2683617
# 40   5CD13577FM    5CD13577FM  ...                             2684022
# 41   5CD13577C4    5CD13577C4  ...                             2685048
# 42   5CD13577HT    5CD13577HT  ...                             2685056
# 43   5CD13577BN    5CD13577BN  ...                             2684953
# 44   5CD13577H0    5CD13577H0  ...                             2693287
# 45   5CD13577CW    5CD13577CW  ...                             2715722
# 46   5CD13577D7    5CD13577D7  ...                             2553546
# 88   5CD135B48G    5CD135B48G  ...                             2717638
# 90   5CD135B4BR    5CD135B4BR  ...                             2718047
# 92   5CD13577BS    5CD13577BS  ...                             2718665
# 93   5CD112FHL6    5CD112FHL6  ...                             2719083
# 94   5CD13577JG    5CD13577JG  ...                             2719156
# 95   5CD13577KL    5CD13577KL  ...                             2719424
# 96   5CG9249GZY    5CG9249GZY  ...                             2719886
# 97   5CD13577LR    5CD13577LR  ...                             2719889
# 98   5CD135B54X    5CD135B54X  ...                             2720277
# 99   5CD112FHN0    5CD112FHN0  ...                             2720342
# 100  5CD13577GW    5CD13577GW  ...                             2720381
# 101  5CD13577HP    5CD13577HP  ...                             2720099
# 102  5CD135B43Y    5CD135B43Y  ...                             2720109
# 103  5CD135BFF0    5CD135BFF0  ...                             2720176
# 104  5CG9249GTS    5CG9249GTS  ...                             2720215
# 105  5CD13577GS    5CD13577GS  ...                             2720234
# 106  5CD135B4F0    5CD135B4F0  ...                             2720237
# 107  5CD135B433    5CD135B433  ...                             2720627
# 108  5CD13577GZ    5CD13577GZ  ...                             2721288
# 110  5CD13577KQ    5CD13577KQ  ...                             2721354
# 111  5CD13577J2    5CD13577J2  ...                             2721388
# 112  5CD13577J9    5CD13577J9  ...                             2721391
# 113  5CD1357785    5CD1357785  ...                             2721399
# 114  5CG94732MQ    5CG94732MQ  ...                             2721144
# 115  5CD112FHQD    5CD112FHQD  ...                             2721223
# 116  5CD13577GQ    5CD13577GQ  ...                             2721232
# 117  5CD13577KS    5CD13577KS  ...                             2721587
# 118  5CD13577HR    5CD13577HR  ...                             2721626
# 119  5CD13577H2    5CD13577H2  ...                             2487837
# 149  5CD13577G3    5CD13577G3  ...                             2721471
# 150  5CD135B43F    5CD135B43F  ...                             2721489
# 151  5CD13577HM    5CD13577HM  ...                             2721508
# 152  5CD13577HY    5CD13577HY  ...                             2721779
# 153  5CD135BFDM    5CD135BFDM  ...                             2721804
# 154  CND1330L36    CND1330L36  ...                             2718230
# 155  CND1330L11    CND1330L11  ...                             2721638
# 156  CND1330L2D    CND1330L2D  ...                             2721514
# 157  CND119066H    CND119066H  ...                             2718270
#
# [51 rows x 30 columns]

# %%
## Part 2
# Inset Order Number Column

macc3 = pd.merge(macc3, 
                      ict2u_acc, 
                      on ='Owned by', 
                      how ='inner')

macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... SAP Asset Number ICT2U Order Number
# 0   5CG124ZX03    5CG124ZX03  ...                             2683710
# 2   5CG124ZX46    5CG124ZX46  ...                             2685301
# 4   5CG124ZX2K    5CG124ZX2K  ...                             2685428
# 7   5CG123ZCS4    5CG123ZCS4  ...                             2716172
# 9   5CG124ZWW4    5CG124ZWW4  ...                             2710756
# 11  5CG126X7D6    5CG126X7D6  ...                             2719682
# 13  CN413039K0    CN413039K0  ...                             2683451
# 14  CN413039J1    CN413039J1  ...                             2684411
# 15  CN41303BQW    CN41303BQW  ...                             2684957
# 16  CN41303BQV    CN41303BQV  ...                             2684968
#
# [10 rows x 30 columns]

# %%
## Part 1

mygenie_column = pd.DataFrame(data1, columns = ["Custodian Email","myGenie Request Number"])

mygenie_column.columns.values[0] = "Owned by"


## Part 2

mygenie_acc = pd.DataFrame(acc1, columns = ["Custodian Email","myGenie Request Number"])

mygenie_acc.columns.values[0] = "Owned by"
mygenie_acc
# Out:
#                                   Owned by myGenie Request Number
# 276      mohammadfahmi.myusof@prefchem.com        REQ000003546242
# 283    rajashaharaputra.ra@petronas.com.my        REQ000003540877
# 313       nurzaimah.razali@petronas.com.my        REQ000003550044
# 314       nurzaimah.razali@petronas.com.my        REQ000003550045
# 493         ashraff.mashal@petronas.com.my        REQ000003566374
# ...                                    ...                    ...
# 13361    norshazlina.azlan@petronas.com.my        REQ000004019650
# 13363    norshazlina.azlan@petronas.com.my        REQ000004019648
# 13364     hassan_abdullahb@petronas.com.my        REQ000004019737
# 13365  aiman.shamsuliwardi@petronas.com.my        REQ000004019504
# 13366         edurrah.jani@petronas.com.my        REQ000004019649
#
# [682 rows x 2 columns]

# %%
## Part 1
# Inset ICT2U Column

merge3 = pd.merge(merge3, 
                      mygenie_column, 
                      on ='Owned by', 
                      how ='inner')


merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

merge3
# Out:
#            Name Serial Number  ... ICT2U Order Number myGenie Request Number
# 0           NaN           NaN  ...            2652687        REQ000003858912
# 27          NaN           NaN  ...            2465934        REQ000003513343
# 30          NaN           NaN  ...            2483252        REQ000003513345
# 33          NaN           NaN  ...            2483267        REQ000003513348
# 36          NaN           NaN  ...            2721759        REQ000004103093
# 39   5CD135B4MD    5CD135B4MD  ...            2683617        REQ000004040947
# 40   5CD13577FM    5CD13577FM  ...            2684022        REQ000004045195
# 41   5CD13577C4    5CD13577C4  ...            2685048        REQ000004052417
# 42   5CD13577HT    5CD13577HT  ...            2685056        REQ000004052226
# 43   5CD13577BN    5CD13577BN  ...            2684953        REQ000004051195
# 44   5CD13577H0    5CD13577H0  ...            2693287        REQ000004058030
# 45   5CD13577CW    5CD13577CW  ...            2715722        REQ000004065969
# 46   5CD13577D7    5CD13577D7  ...            2553546        REQ000003429121
# 88   5CD135B48G    5CD135B48G  ...            2717638        REQ000004065043
# 90   5CD135B4BR    5CD135B4BR  ...            2718047        REQ000004065978
# 92   5CD13577BS    5CD13577BS  ...            2718665        REQ000004070273
# 93   5CD112FHL6    5CD112FHL6  ...            2719083        REQ000004075299
# 94   5CD13577JG    5CD13577JG  ...            2719156        REQ000004075767
# 95   5CD13577KL    5CD13577KL  ...            2719424        REQ000004080761
# 96   5CG9249GZY    5CG9249GZY  ...            2719886        REQ000004082003
# 97   5CD13577LR    5CD13577LR  ...            2719889        REQ000004082004
# 98   5CD135B54X    5CD135B54X  ...            2720277        REQ000004096289
# 99   5CD112FHN0    5CD112FHN0  ...            2720342        REQ000004096373
# 100  5CD13577GW    5CD13577GW  ...            2720381        REQ000004096256
# 101  5CD13577HP    5CD13577HP  ...            2720099        REQ000004096414
# 102  5CD135B43Y    5CD135B43Y  ...            2720109        REQ000004096443
# 103  5CD135BFF0    5CD135BFF0  ...            2720176        REQ000004096437
# 104  5CG9249GTS    5CG9249GTS  ...            2720215        REQ000004096439
# 105  5CD13577GS    5CD13577GS  ...            2720234        REQ000004096410
# 106  5CD135B4F0    5CD135B4F0  ...            2720237        REQ000004096300
# 107  5CD135B433    5CD135B433  ...            2720627        REQ000004096417
# 108  5CD13577GZ    5CD13577GZ  ...            2721288        REQ000004101825
# 110  5CD13577KQ    5CD13577KQ  ...            2721354        REQ000004101927
# 111  5CD13577J2    5CD13577J2  ...            2721388        REQ000004101625
# 112  5CD13577J9    5CD13577J9  ...            2721391        REQ000004101833
# 113  5CD1357785    5CD1357785  ...            2721399        REQ000004101536
# 114  5CG94732MQ    5CG94732MQ  ...            2721144        REQ000004095970
# 115  5CD112FHQD    5CD112FHQD  ...            2721223        REQ000004096263
# 116  5CD13577GQ    5CD13577GQ  ...            2721232        REQ000004096206
# 117  5CD13577KS    5CD13577KS  ...            2721587        REQ000004101532
# 118  5CD13577HR    5CD13577HR  ...            2721626        REQ000004101628
# 119  5CD13577H2    5CD13577H2  ...            2487837        REQ000003538655
# 149  5CD13577G3    5CD13577G3  ...            2721471        REQ000004101837
# 150  5CD135B43F    5CD135B43F  ...            2721489        REQ000004101624
# 151  5CD13577HM    5CD13577HM  ...            2721508        REQ000004101531
# 152  5CD13577HY    5CD13577HY  ...            2721779        REQ000004103651
# 153  5CD135BFDM    5CD135BFDM  ...            2721804        REQ000004103482
# 154  CND1330L36    CND1330L36  ...            2718230        REQ000004075446
# 155  CND1330L11    CND1330L11  ...            2721638        REQ000004103156
# 156  CND1330L2D    CND1330L2D  ...            2721514        REQ000004103085
# 157  CND119066H    CND119066H  ...            2718270        REQ000004074295
#
# [51 rows x 31 columns]

# %%
## Part 2
# Inset ICT2U Column

macc3 = pd.merge(macc3, 
                      mygenie_acc, 
                      on ='Owned by', 
                      how ='inner')


macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... ICT2U Order Number myGenie Request Number
# 0   5CG124ZX03    5CG124ZX03  ...            2683710        REQ000004047121
# 2   5CG124ZX46    5CG124ZX46  ...            2685301        REQ000004054309
# 4   5CG124ZX2K    5CG124ZX2K  ...            2685428        REQ000004057191
# 7   5CG123ZCS4    5CG123ZCS4  ...            2716172        REQ000004065721
# 9   5CG124ZWW4    5CG124ZWW4  ...            2710756        REQ000004061380
# 11  5CG126X7D6    5CG126X7D6  ...            2719682        REQ000004087362
# 13  CN413039K0    CN413039K0  ...            2683451        REQ000004043901
# 14  CN413039J1    CN413039J1  ...            2684411        REQ000004046790
# 15  CN41303BQW    CN41303BQW  ...            2684957        REQ000004051789
# 16  CN41303BQV    CN41303BQV  ...            2684968        REQ000004051872
#
# [10 rows x 31 columns]

# %%
## Part 1

merge3['Vendor Schedule Number (EOL)'] = ''
merge3['Lessor Returned Verification (EOL)'] = ''
merge3['Return Batch Number (EOL)'] = ''
merge3['Return Item Number (EOL)'] = ''
merge3['Return Date To Lessor (EOL)'] = ''
merge3['Return Date By User (EOL)'] = ''


## Part 2

macc3['Vendor Schedule Number (EOL)'] = ''
macc3['Lessor Returned Verification (EOL)'] = ''
macc3['Return Batch Number (EOL)'] = ''
macc3['Return Item Number (EOL)'] = ''
macc3['Return Date To Lessor (EOL)'] = ''
macc3['Return Date By User (EOL)'] = ''
macc3
# Out:
#           Name  ... Return Date By User (EOL)
# 0   5CG124ZX03  ...
# 2   5CG124ZX46  ...
# 4   5CG124ZX2K  ...
# 7   5CG123ZCS4  ...
# 9   5CG124ZWW4  ...
# 11  5CG126X7D6  ...
# 13  CN413039K0  ...
# 14  CN413039J1  ...
# 15  CN41303BQW  ...
# 16  CN41303BQV  ...
#
# [10 rows x 37 columns]

# %%
# header_row = 2

# data6.columns = data6.iloc[header_row]


# date_column1 = pd.DataFrame(data6, columns = ["SR Number","Submit Date"])

# date_column1.dropna(subset = ["SR Number"], inplace=True)

# date_column1 = date_column1.drop([0,2])

# date_column1.columns.values[1] = "Contract Start Date"
# date_column1.columns.values[0] = "myGenie Request Number"



# date_column1
# genie

# %%
# merge3 = pd.merge(merge3, 
#                       genie, 
#                       on ='myGenie Request Number', 
#                       how ='inner')

# %%
# # Inset Date columns

# genie = pd.DataFrame(data1,columns= ['myGenie Request Number'] )

# merge3 = pd.merge(merge3, 
#                       genie, 
#                       on ='myGenie Request Number', 
#                       how ='inner')


# merge3

# %%
## Part 1

merge6 = pd.DataFrame(data6, columns= ['DAAS (Desktop as a Service) Report – V2','Unnamed: 7'])

merge6.columns = merge6.iloc[2] 

merge6 = merge6[0:]

# %%
## Part 2

macc6 = pd.DataFrame(acc6, columns= ['DAAS (Desktop as a Service) Report – V2','Unnamed: 7'])

macc6.columns = macc6.iloc[2] 

macc6 = macc6[0:]

macc6
# Out:
# 2                       SR Number      Completion Date
# 0      Service Request Management                  NaN
# 1                             NaN                  NaN
# 2                       SR Number      Completion Date
# 3                 REQ000002513479                  NaN
# 4                 REQ000002889971  2021-01-11 14:26:03
# ...                           ...                  ...
# 60135             REQ000004117571  2021-12-01 08:44:27
# 60136             REQ000004117504  2021-12-01 09:14:19
# 60137             REQ000004117594  2021-12-01 09:17:00
# 60138             REQ000004117787  2021-12-01 09:30:37
# 60139             REQ000004117796  2021-12-01 09:34:26
#
# [60140 rows x 2 columns]

# %%
# Drop rows (Part 1)

merge6 = merge6.drop([merge6.index[0], merge6.index[1],merge6.index[2]])




# Drop rows (Part 2)

macc6 = macc6.drop([macc6.index[0], macc6.index[1],macc6.index[2]])
macc6
# Out:
# 2            SR Number      Completion Date
# 3      REQ000002513479                  NaN
# 4      REQ000002889971  2021-01-11 14:26:03
# 5      REQ000002889971  2021-01-11 14:26:03
# 6      REQ000002889971  2021-01-11 14:26:03
# 7      REQ000002889971  2021-01-11 14:26:03
# ...                ...                  ...
# 60135  REQ000004117571  2021-12-01 08:44:27
# 60136  REQ000004117504  2021-12-01 09:14:19
# 60137  REQ000004117594  2021-12-01 09:17:00
# 60138  REQ000004117787  2021-12-01 09:30:37
# 60139  REQ000004117796  2021-12-01 09:34:26
#
# [60137 rows x 2 columns]

# %%
## Rename column[0] as myGenie Request Number (Part 1)

merge6.columns.values[0] = "myGenie Request Number"


## Rename column[0] as myGenie Request Number (Part 2)

macc6.columns.values[0] = "myGenie Request Number"
macc6
# Out:
# 2     myGenie Request Number      Completion Date
# 3            REQ000002513479                  NaN
# 4            REQ000002889971  2021-01-11 14:26:03
# 5            REQ000002889971  2021-01-11 14:26:03
# 6            REQ000002889971  2021-01-11 14:26:03
# 7            REQ000002889971  2021-01-11 14:26:03
# ...                      ...                  ...
# 60135        REQ000004117571  2021-12-01 08:44:27
# 60136        REQ000004117504  2021-12-01 09:14:19
# 60137        REQ000004117594  2021-12-01 09:17:00
# 60138        REQ000004117787  2021-12-01 09:30:37
# 60139        REQ000004117796  2021-12-01 09:34:26
#
# [60137 rows x 2 columns]

# %%
## convert datetime column to only date (Part 1)

merge6['Completion Date1'] = pd.to_datetime(merge6['Completion Date']).dt.date
  


## convert datetime column to only date (Part 2)

macc6['Completion Date1'] = pd.to_datetime(macc6['Completion Date']).dt.date
macc6
# Out:
# 2     myGenie Request Number      Completion Date Completion Date1
# 3            REQ000002513479                  NaN              NaT
# 4            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 5            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 6            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 7            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# ...                      ...                  ...              ...
# 60135        REQ000004117571  2021-12-01 08:44:27       2021-12-01
# 60136        REQ000004117504  2021-12-01 09:14:19       2021-12-01
# 60137        REQ000004117594  2021-12-01 09:17:00       2021-12-01
# 60138        REQ000004117787  2021-12-01 09:30:37       2021-12-01
# 60139        REQ000004117796  2021-12-01 09:34:26       2021-12-01
#
# [60137 rows x 3 columns]

# %%
## Part 1
## Drop duplicates in myGenie Request Number column

merge6.drop_duplicates(subset = "myGenie Request Number", keep = 'first', inplace = True )


## Drop COmpletion Date column

merge6.drop(['Completion Date'], axis = 1)


## Part 2
## Drop duplicates in myGenie Request Number column

macc6.drop_duplicates(subset = "myGenie Request Number", keep = 'first', inplace = True )


## Drop COmpletion Date column

macc6.drop(['Completion Date'], axis = 1)
macc6
# Out:
# 2     myGenie Request Number      Completion Date Completion Date1
# 3            REQ000002513479                  NaN              NaT
# 4            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 8            REQ000002945934  2021-02-04 18:41:41       2021-02-04
# 12           REQ000002953496                  NaN              NaT
# 14           REQ000002969398                  NaN              NaT
# ...                      ...                  ...              ...
# 60135        REQ000004117571  2021-12-01 08:44:27       2021-12-01
# 60136        REQ000004117504  2021-12-01 09:14:19       2021-12-01
# 60137        REQ000004117594  2021-12-01 09:17:00       2021-12-01
# 60138        REQ000004117787  2021-12-01 09:30:37       2021-12-01
# 60139        REQ000004117796  2021-12-01 09:34:26       2021-12-01
#
# [24523 rows x 3 columns]

# %%
# Part 1
# Fill Operating system column

merge3.loc[:,'Operating System'] = 'Windows 10'


# Fill Status Reason column with N/A

merge3.loc[:,'Status Reason'] = 'N/A'

# Fill Domain column with PETRONAS.PETRONET.DIR

merge3.loc[:,'Domain'] = 'PETRONAS.PETRONET.DIR'

# Fill Asset Type column with Leasing

merge3.loc[:,'Asset Type'] = 'Leasing'

# Fill Project Number column with N/A

merge3.loc[:,'Project Number'] = 'N/A'

# Fill Project Name column with N/A

merge3.loc[:,'Project Name'] = 'N/A'

# Fill SAP Asset Number column with N/A

merge3.loc[:,'SAP Asset Number'] = 'N/A'





# Part 2
# Fill Operating system column

macc3.loc[:,'Operating System'] = 'Windows 10'


# Fill Status Reason column with N/A

macc3.loc[:,'Status Reason'] = 'N/A'

# Fill Domain column with PETRONAS.PETRONET.DIR

macc3.loc[:,'Domain'] = 'PETRONAS.PETRONET.DIR'

# Fill Asset Type column with Leasing

macc3.loc[:,'Asset Type'] = 'Leasing'

# Fill Project Number column with N/A

macc3.loc[:,'Project Number'] = 'N/A'

# Fill Project Name column with N/A

macc3.loc[:,'Project Name'] = 'N/A'

# Fill SAP Asset Number column with N/A

macc3.loc[:,'SAP Asset Number'] = 'N/A'

# %%
## Drop Completion Date column (Part 1)

merge6 = merge6.drop(['Completion Date'], axis = 1)


## Drop Completion Date column (Part 2)

macc6 = macc6.drop(['Completion Date'], axis = 1)
macc6
# Out:
# 2     myGenie Request Number Completion Date1
# 3            REQ000002513479              NaT
# 4            REQ000002889971       2021-01-11
# 8            REQ000002945934       2021-02-04
# 12           REQ000002953496              NaT
# 14           REQ000002969398              NaT
# ...                      ...              ...
# 60135        REQ000004117571       2021-12-01
# 60136        REQ000004117504       2021-12-01
# 60137        REQ000004117594       2021-12-01
# 60138        REQ000004117787       2021-12-01
# 60139        REQ000004117796       2021-12-01
#
# [24523 rows x 2 columns]

# %%
# Create End of warranty date (Completion Date1 + 3 years) - Part 1

merge6["ContendDate"] = merge6['Completion Date1'] + pd.offsets.DateOffset(years=3)


# Create End of warranty date (Completion Date1 + 3 years) - Part 2

macc6["ContendDate"] = macc6['Completion Date1'] + pd.offsets.DateOffset(years=3)
macc6
# Out:
# 2     myGenie Request Number Completion Date1 ContendDate
# 3            REQ000002513479              NaT         NaT
# 4            REQ000002889971       2021-01-11  2024-01-11
# 8            REQ000002945934       2021-02-04  2024-02-04
# 12           REQ000002953496              NaT         NaT
# 14           REQ000002969398              NaT         NaT
# ...                      ...              ...         ...
# 60135        REQ000004117571       2021-12-01  2024-12-01
# 60136        REQ000004117504       2021-12-01  2024-12-01
# 60137        REQ000004117594       2021-12-01  2024-12-01
# 60138        REQ000004117787       2021-12-01  2024-12-01
# 60139        REQ000004117796       2021-12-01  2024-12-01
#
# [24523 rows x 3 columns]

# %%
## Create Warranty Start, Warranty end, Status and Registered date columns - Part 1

merge6["Warranty Start"] = merge6["Completion Date1"]
merge6["Warranty End"] = merge6["ContendDate"]
merge6["STATUS"] = "Requested to Register in  CMDB"
merge6["REGISTERED DATE"] = ''



## Create Warranty Start, Warranty end, Status and Registered date columns - Part 2

macc6["Warranty Start"] = macc6["Completion Date1"]
macc6["Warranty End"] = macc6["ContendDate"]
macc6["STATUS"] = "Requested to Register in  CMDB"
macc6["REGISTERED DATE"] = ''
macc6
# Out:
# 2     myGenie Request Number  ... REGISTERED DATE
# 3            REQ000002513479  ...
# 4            REQ000002889971  ...
# 8            REQ000002945934  ...
# 12           REQ000002953496  ...
# 14           REQ000002969398  ...
# ...                      ...  ...             ...
# 60135        REQ000004117571  ...
# 60136        REQ000004117504  ...
# 60137        REQ000004117594  ...
# 60138        REQ000004117787  ...
# 60139        REQ000004117796  ...
#
# [24523 rows x 7 columns]

# %%
# # Inset Date columns - Part 1

merge6 = pd.merge(merge3, 
                      merge6, 
                      on ='myGenie Request Number', 
                      how ='inner')

merge6
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0          NaN           NaN  ...  Requested to Register in  CMDB
# 1          NaN           NaN  ...  Requested to Register in  CMDB
# 2          NaN           NaN  ...  Requested to Register in  CMDB
# 3          NaN           NaN  ...  Requested to Register in  CMDB
# 4   5CD135B4MD    5CD135B4MD  ...  Requested to Register in  CMDB
# 5   5CD13577FM    5CD13577FM  ...  Requested to Register in  CMDB
# 6   5CD13577C4    5CD13577C4  ...  Requested to Register in  CMDB
# 7   5CD13577HT    5CD13577HT  ...  Requested to Register in  CMDB
# 8   5CD13577BN    5CD13577BN  ...  Requested to Register in  CMDB
# 9   5CD13577H0    5CD13577H0  ...  Requested to Register in  CMDB
# 10  5CD13577CW    5CD13577CW  ...  Requested to Register in  CMDB
# 11  5CD13577D7    5CD13577D7  ...  Requested to Register in  CMDB
# 12  5CD135B48G    5CD135B48G  ...  Requested to Register in  CMDB
# 13  5CD135B4BR    5CD135B4BR  ...  Requested to Register in  CMDB
# 14  5CD13577BS    5CD13577BS  ...  Requested to Register in  CMDB
# 15  5CD112FHL6    5CD112FHL6  ...  Requested to Register in  CMDB
# 16  5CD13577JG    5CD13577JG  ...  Requested to Register in  CMDB
# 17  5CD13577KL    5CD13577KL  ...  Requested to Register in  CMDB
# 18  5CG9249GZY    5CG9249GZY  ...  Requested to Register in  CMDB
# 19  5CD13577LR    5CD13577LR  ...  Requested to Register in  CMDB
# 20  5CD135B54X    5CD135B54X  ...  Requested to Register in  CMDB
# 21  5CD112FHN0    5CD112FHN0  ...  Requested to Register in  CMDB
# 22  5CD13577GW    5CD13577GW  ...  Requested to Register in  CMDB
# 23  5CD13577HP    5CD13577HP  ...  Requested to Register in  CMDB
# 24  5CD135B43Y    5CD135B43Y  ...  Requested to Register in  CMDB
# 25  5CD135BFF0    5CD135BFF0  ...  Requested to Register in  CMDB
# 26  5CG9249GTS    5CG9249GTS  ...  Requested to Register in  CMDB
# 27  5CD13577GS    5CD13577GS  ...  Requested to Register in  CMDB
# 28  5CD135B4F0    5CD135B4F0  ...  Requested to Register in  CMDB
# 29  5CD135B433    5CD135B433  ...  Requested to Register in  CMDB
# 30  5CD13577GZ    5CD13577GZ  ...  Requested to Register in  CMDB
# 31  5CD13577KQ    5CD13577KQ  ...  Requested to Register in  CMDB
# 32  5CD13577J2    5CD13577J2  ...  Requested to Register in  CMDB
# 33  5CD13577J9    5CD13577J9  ...  Requested to Register in  CMDB
# 34  5CD1357785    5CD1357785  ...  Requested to Register in  CMDB
# 35  5CG94732MQ    5CG94732MQ  ...  Requested to Register in  CMDB
# 36  5CD112FHQD    5CD112FHQD  ...  Requested to Register in  CMDB
# 37  5CD13577GQ    5CD13577GQ  ...  Requested to Register in  CMDB
# 38  5CD13577KS    5CD13577KS  ...  Requested to Register in  CMDB
# 39  5CD13577HR    5CD13577HR  ...  Requested to Register in  CMDB
# 40  5CD13577H2    5CD13577H2  ...  Requested to Register in  CMDB
# 41  5CD13577G3    5CD13577G3  ...  Requested to Register in  CMDB
# 42  5CD135B43F    5CD135B43F  ...  Requested to Register in  CMDB
# 43  5CD13577HM    5CD13577HM  ...  Requested to Register in  CMDB
# 44  5CD13577HY    5CD13577HY  ...  Requested to Register in  CMDB
# 45  5CD135BFDM    5CD135BFDM  ...  Requested to Register in  CMDB
# 46  CND1330L36    CND1330L36  ...  Requested to Register in  CMDB
# 47  CND1330L11    CND1330L11  ...  Requested to Register in  CMDB
# 48  CND1330L2D    CND1330L2D  ...  Requested to Register in  CMDB
# 49  CND119066H    CND119066H  ...  Requested to Register in  CMDB
#
# [50 rows x 43 columns]

# %%
# # Inset Date columns - Part 2

macc6 = pd.merge(macc3, 
                      macc6, 
                      on ='myGenie Request Number', 
                      how ='inner')

macc6
# Out:
#          Name Serial Number  ...                          STATUS REGISTERED DATE
# 0  5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1  5CG124ZX46    5CG124ZX46  ...  Requested to Register in  CMDB
# 2  5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 3  5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 4  5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 5  5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6  CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7  CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8  CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [10 rows x 43 columns]

# %%
# Change owned by column with names and certifier - Part 1

data7 = pd.DataFrame(data7,columns= ["Full Name","Internet E-mail"] )
data7["Owned by"] = data7["Internet E-mail"]


# Change owned by column with names and certifier - Part 2

acc7 = pd.DataFrame(acc7,columns= ["Full Name","Internet E-mail"] )
acc7["Owned by"] = acc7["Internet E-mail"]
acc7
# Out:
#                                    Full Name  ...                         Owned by
# 0                          AP FS2 (FNA/PETH)  ...           ap.fs2@petronas.com.my
# 1      DFP Technical Helpdesk (TECH_OPE/DFP)  ...             technical@dfp.com.my
# 2                        FSDAP 005 (SDD/PDB)  ...         fsdap005@petronas.com.my
# 3                         FSDAP001 (FSD/PDB)  ...         fsdap001@petronas.com.my
# 4                         FSDAP002 (FSD/PDB)  ...         fsdap002@petronas.com.my
# ...                                      ...  ...                              ...
# 89020          Zuraida M Zabidi (LEGAL/PETH)  ...  zuraida.mzabidi@petronas.com.my
# 89021     Zuraidah Bt Hassan (USCA/Upstream)  ...           zuraih@petronas.com.my
# 89022        Zuraina Tamrin (OPERATION/PRPC)  ...   zuraina.tamrin@petronas.com.my
# 89023       Zuraina Tamrin (OPERATIONS/PRPC)  ...    zuraina.tamri@petronas.com.my
# 89024                                    NaN  ...                              NaN
#
# [89025 rows x 3 columns]

# %%
# # Inset Owner Name column - Part 1

merge7 = pd.merge(merge6, 
                      data7, 
                      on ='Owned by', 
                      how ='inner')

merge7
# Out:
#           Name  ...                       Internet E-mail
# 0          NaN  ...        nabilla.khisha@petronas.com.my
# 1          NaN  ...  mohamadfadhilha.azma@petronas.com.my
# 2          NaN  ...               zainurm@petronas.com.my
# 3          NaN  ...           mok.wenting@petronas.com.my
# 4   5CD135B4MD  ...                    tkamal@klcc.com.my
# 5   5CD13577FM  ...            tan.leepei@petronas.com.my
# 6   5CD13577HT  ...    nurfarhan.rizalman@petronas.com.my
# 7   5CD13577BN  ...        hurilain.rosli@petronas.com.my
# 8   5CD13577H0  ...           mark.tingay@petronas.com.my
# 9   5CD13577CW  ...         sarah_arahman@petronas.com.my
# 10  5CD13577D7  ...    khadijah.amuthalib@petronas.com.my
# 11  5CD135B48G  ...         edwandy.afand@petronas.com.my
# 12  5CD135B4BR  ...      rashidah.hussin@pli-petronas.com
# 13  5CD13577BS  ...        ainifadhilah_m@petronas.com.my
# 14  5CD112FHL6  ...        naisah.zakaria@petronas.com.my
# 15  5CD13577JG  ...         zarina_hassan@petronas.com.my
# 16  5CD13577KL  ...          shaidi_ahmad@petronas.com.my
# 17  5CG9249GZY  ...       aizila.sulaiman@petronas.com.my
# 18  5CD13577LR  ...       khairi.mdsuhada@petronas.com.my
# 19  5CD135B54X  ...      nurafeefa.bungsu@petronas.com.my
# 20  5CD112FHN0  ...   mohanaramanee.thami@petronas.com.my
# 21  5CD13577GW  ...           luqman.zani@petronas.com.my
# 22  5CD13577HP  ...           lim_laysean@petronas.com.my
# 23  5CD135B43Y  ...         munirah.zaidi@petronas.com.my
# 24  5CD135BFF0  ...        syefik.suhaimi@petronas.com.my
# 25  5CG9249GTS  ...          luqman.saari@petronas.com.my
# 26  5CD13577GS  ...               chiewml@petronas.com.my
# 27  5CD13577GZ  ...   norfarahaimi.mustaf@petronas.com.my
# 28  5CD13577KQ  ...         munawar.anuar@petronas.com.my
# 29  5CD13577J2  ...          atiqah.azlan@petronas.com.my
# 30  5CD13577J9  ...      ahmadafiq.mahadi@petronas.com.my
# 31  5CD1357785  ...          nadhil.latif@petronas.com.my
# 32  5CG94732MQ  ...  nuraqilah.ahmadbadar@petronas.com.my
# 33  5CD112FHQD  ...        arie_syahriful@petronas.com.my
# 34  5CD13577GQ  ...  norazman.chemahmoodm@petronas.com.my
# 35  5CD13577KS  ...       fadhlilah_rahim@petronas.com.my
# 36  5CD13577HR  ...           norfaezah_j@petronas.com.my
# 37  5CD13577H2  ...      nuramani.mokhtar@petronas.com.my
# 38  5CD13577G3  ...            norhafizan@petronas.com.my
# 39  5CD135B43F  ...                    hasnun@klcc.com.my
# 40  5CD135B43F  ...                    hasnun@klcc.com.my
# 41  5CD13577HM  ...      noraida.alisbana@petronas.com.my
# 42  5CD13577HY  ...          faizul_nizam@petronas.com.my
# 43  5CD135BFDM  ...             tan.alvin@petronas.com.my
# 44  CND1330L36  ...          zhixiong.ong@petronas.com.my
# 45  CND1330L11  ...   krishnamraju.denduk@petronas.com.my
# 46  CND1330L2D  ...          fatmanazihah@petronas.com.my
# 47  CND119066H  ...       shahrina_araman@petronas.com.my
#
# [48 rows x 45 columns]

# %%
# # Inset Owner Name column - Part 2

macc7 = pd.merge(macc6, 
                      acc7, 
                      on ='Owned by', 
                      how ='inner')

macc7
# Out:
#           Name  ...                      Internet E-mail
# 0   5CG124ZX03  ...              rajmanz@petronas.com.my
# 1   5CG124ZX2K  ...          mnazricheon@petronas.com.my
# 2   5CG123ZCS4  ...           tankainhwa@petronas.com.my
# 3   5CG124ZWW4  ...    sarah.limsuethoey@petronas.com.my
# 4   5CG126X7D6  ...                   hasnun@klcc.com.my
# 5   5CG126X7D6  ...                   hasnun@klcc.com.my
# 6   CN413039K0  ...    nurhazirah.ismail@petronas.com.my
# 7   CN413039J1  ...   syifaainina.shukor@petronas.com.my
# 8   CN41303BQW  ...  ainazulaikha.ahmady@petronas.com.my
# 9   CN41303BQW  ...  ainazulaikha.ahmady@petronas.com.my
# 10  CN41303BQV  ...    nurqistina.azaman@petronas.com.my
#
# [11 rows x 45 columns]

# %%
## Part 1
merge7 = merge7.drop(['Internet E-mail'], axis = 1)

merge7
# Out:
#           Name  ...                                          Full Name
# 0          NaN  ...                         Nabilla Khisham (HRM/PETH)
# 1          NaN  ...                   M Fadhil Hanafi Azman (GFC/PETH)
# 2          NaN  ...          Sy Zainuddin B Sy A Rahman (MPM/Upstream)
# 3          NaN  ...                        Mok Wen Ting (HRM/Upstream)
# 4   5CD135B4MD  ...                           Tuan Kamal Tuan Abdullah
# 5   5CD13577FM  ...                        Tan Lee Pei (DE-IS/DIGITAL)
# 6   5CD13577HT  ...  Nur Farhana Intan Suhaila Rizalman (DE-SAP/DIG...
# 7   5CD13577BN  ...                          Huril-Ain Rosli (GP/PETH)
# 8   5CD13577H0  ...             Mark Robert Paul Tingay (Exp/Upstream)
# 9   5CD13577CW  ...                        Sarah Bt A Rahman (SDD/PDB)
# 10  5CD13577D7  ...              Khadijah A Muthalib (OPERATIONS/PRPC)
# 11  5CD135B48G  ...             Edwandy Afandi (MANUFACTURING/PRPC UF)
# 12  5CD135B4BR  ...                         Rashidah bt Hussin (PLISB)
# 13  5CD13577BS  ...               Ainifadhilah Bt Mahayuddin (GP/PETH)
# 14  5CD112FHL6  ...                Nur Aisah Bt Zakaria (SKO/Upstream)
# 15  5CD13577JG  ...                  Zarina Bt Hassan Basri (GRM/PETH)
# 16  5CD13577KL  ...                           Shaidi B Ahmad (TSD/PDB)
# 17  5CG9249GZY  ...                     Aizila Sulaiman (COE/Upstream)
# 18  5CD13577LR  ...                       M Khairi M Suhada (GPD/PD&T)
# 19  5CD135B54X  ...                        Nurafeefa Bungsu (GFC/PETH)
# 20  5CD112FHN0  ...          Mohana Ramanee Thamilarasu (COE/Upstream)
# 21  5CD13577GW  ...                 W M Luqman W M Zani (COE/Upstream)
# 22  5CD13577HP  ...                           Lim Lay Sean (GTCM/PD&T)
# 23  5CD135B43Y  ...                     Munirah Bt Md Zaidi (HRM/PETH)
# 24  5CD135BFF0  ...                Nik Syefik Safwan Suhaimi (GP/PETH)
# 25  5CG9249GTS  ...                                       Luqman Saari
# 26  5CD13577GS  ...                          Chiew Mei Ling (GIA/PETH)
# 27  5CD13577GZ  ...             Norfarah Aimi Mustafa (HRA/PETROSAINS)
# 28  5CD13577KQ  ...          Ahmad Munawar Mohmad Anuar (EDL_HRM/PETH)
# 29  5CD13577J2  ...                      Atiqah Azlan (DE-SAP/DIGITAL)
# 30  5CD13577J9  ...                 Ahmad Afiq B Mahadi (COE/Upstream)
# 31  5CD1357785  ...                       M Nadhil B A Latif (CBD/PDB)
# 32  5CG94732MQ  ...                         Nur AqilahAhmad Badaruddin
# 33  5CD112FHQD  ...           Arie Pratiwi Bt Syahriful (SKO/Upstream)
# 34  5CD13577GQ  ...                      Nor Azman Che Mahmood - M Noh
# 35  5CD13577KS  ...               M Fadhlilah B A Rahim (IVA/Upstream)
# 36  5CD13577HR  ...                 Norfaezah Bt Jaffar (MPM/Upstream)
# 37  5CD13577H2  ...                       Nur Amani Mokhtar (HRM/PD&T)
# 38  5CD13577G3  ...                    Nor Hafizan Bt Tambi (O&D/PCGB)
# 39  5CD135B43F  ...               Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 40  5CD135B43F  ...               Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 41  5CD13577HM  ...                  Noraida Alis Bana (CS-SA/DIGITAL)
# 42  5CD13577HY  ...             Faizul Nizam B Ismail A (MPM/Upstream)
# 43  5CD135BFDM  ...                               Tan Al Vin (GPU/PGB)
# 44  CND1330L36  ...                           Ong Zhi Xiong (O&D/PCGB)
# 45  CND1330L11  ...            Krishnam Raju Dendukuri (DE-PS/DIGITAL)
# 46  CND1330L2D  ...           Fatma Nazihah Bt M Khatib (S&C/Upstream)
# 47  CND119066H  ...                     Shahrina Bt A Raman (HRM/PETH)
#
# [48 rows x 44 columns]

# %%
## Part 2
macc7 = macc7.drop(['Internet E-mail'], axis = 1)
macc7
# Out:
#           Name  ...                             Full Name
# 0   5CG124ZX03  ...      Rajman Zareqh B Zainol (GP/PETH)
# 1   5CG124ZX2K  ...            M Nazri B Che On (GP/PETH)
# 2   5CG123ZCS4  ...               Tan Kain Hwa (GPD/PD&T)
# 3   5CG124ZWW4  ...    Sarah Lim Suet Hoey (Exp/Upstream)
# 4   5CG126X7D6  ...  Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 5   5CG126X7D6  ...  Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 6   CN413039K0  ...          Nur Hazirah Ismail (GP/PETH)
# 7   CN413039J1  ...         Syifa'ainina Shukor (GP/PETH)
# 8   CN41303BQW  ...             Aina Zulaikha Ahmad Yusri
# 9   CN41303BQW  ...   Aina Zulaikha Ahmad Yusri (GP/PETH)
# 10  CN41303BQV  ...          Nur Qistina Azaman (GP/PETH)
#
# [11 rows x 44 columns]

# %%
## Fill up Owned by column with Full name column data - Part 1

merge7["Owned by"] = merge7["Full Name"]


## Fill up Owned by column with Full name column data - Part 2

macc7["Owned by"] = macc7["Full Name"]
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name  ...                             Full Name
# 0   5CG124ZX03  ...      Rajman Zareqh B Zainol (GP/PETH)
# 1   5CG124ZX2K  ...            M Nazri B Che On (GP/PETH)
# 2   5CG123ZCS4  ...               Tan Kain Hwa (GPD/PD&T)
# 3   5CG124ZWW4  ...    Sarah Lim Suet Hoey (Exp/Upstream)
# 4   5CG126X7D6  ...  Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 5   5CG126X7D6  ...  Hasnun Niza Abdul Rahim (CTRL/KLCCP)
# 6   CN413039K0  ...          Nur Hazirah Ismail (GP/PETH)
# 7   CN413039J1  ...         Syifa'ainina Shukor (GP/PETH)
# 8   CN41303BQW  ...             Aina Zulaikha Ahmad Yusri
# 9   CN41303BQW  ...   Aina Zulaikha Ahmad Yusri (GP/PETH)
# 10  CN41303BQV  ...          Nur Qistina Azaman (GP/PETH)
#
# [11 rows x 44 columns]

# %%
## Drop Full name column - Part 1

merge7 = merge7.drop(['Full Name'], axis = 1)


## Drop Full name column - Part 2

macc7 = macc7.drop(['Full Name'], axis = 1)
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 43 columns]

# %%
# Extract states from address - Part 1

States = ['Kuala Lumpur','KL','Petronas Twin Towers','PETRONAS Twin Towers','Selangor','Terengganu','Johor','Melaka','Perlis','Kedah','Perak','Negeri Sembilan','Sarawak','Sabah','Kelantan','Pahang', 'Pulau Pinang']
pat = '|'.join(r"\b{}\b".format(x) for x in States)

merge7['States1'] = merge7['Location'].str.extract('('+ pat + ')', expand=False, flags=re.I)



# Extract states from address - Part 2

States = ['Kuala Lumpur','KL','Petronas Twin Towers','PETRONAS Twin Towers','Selangor','Terengganu','Johor','Melaka','Perlis','Kedah','Perak','Negeri Sembilan','Sarawak','Sabah','Kelantan','Pahang', 'Pulau Pinang']
pat = '|'.join(r"\b{}\b".format(x) for x in States)

macc7['States1'] = macc7['Location'].str.extract('('+ pat + ')', expand=False, flags=re.I)
macc7
# Out:
#           Name Serial Number  ... REGISTERED DATE               States1
# 0   5CG124ZX03    5CG124ZX03  ...                  Petronas Twin Towers
# 1   5CG124ZX2K    5CG124ZX2K  ...                  PETRONAS TWIN TOWERS
# 2   5CG123ZCS4    5CG123ZCS4  ...                          Kuala Lumpur
# 3   5CG124ZWW4    5CG124ZWW4  ...                  PETRONAS Twin Towers
# 4   5CG126X7D6    5CG126X7D6  ...                          Kuala Lumpur
# 5   5CG126X7D6    5CG126X7D6  ...                          Kuala Lumpur
# 6   CN413039K0    CN413039K0  ...                          KUALA LUMPUR
# 7   CN413039J1    CN413039J1  ...                          Kuala Lumpur
# 8   CN41303BQW    CN41303BQW  ...                          KUALA LUMPUR
# 9   CN41303BQW    CN41303BQW  ...                          KUALA LUMPUR
# 10  CN41303BQV    CN41303BQV  ...                          KUALA LUMPUR
#
# [11 rows x 44 columns]

# %%
# Set the conditions for determining values in new column: - Part 1

conditions = [
    (merge7['States1'] == 'Kuala Lumpur'),
    (merge7['States1'] == 'KL'),
    (merge7['States1'] == 'Petronas Twin Towers'),
    (merge7['States1'] == 'Selangor'),
    (merge7['States1'] == 'Terengganu'),
    (merge7['States1'] == 'Johor'),
    (merge7['States1'] == 'Melaka'),
    (merge7['States1'] == 'Perlis'),
    (merge7['States1'] == 'Kedah'),
    (merge7['States1'] == 'Perak'),
    (merge7['States1'] == 'Negeri Sembilan'),
    (merge7['States1'] == 'Sarawak'),
    (merge7['States1'] == 'Sabah'),
    (merge7['States1'] == 'Kelantan'),
    (merge7['States1'] == 'Pahang'),
    (merge7['States1'] == 'Pulau Pinang'),
    (merge7['States1'] == 'PETRONAS Twin Towers'),
    (merge7['States1'] == 'Kl'),
    (merge7['States1'] == 'KUALA LUMPUR'),
    (merge7['States1'] == 'Labuan'),
    (merge7['States1'] == 'PETRONAS TWIN TOWERS')]


# Set the new column values in order of the conditions they should
#	correspond to:

choices = ['Central','Central','Central','Central','East Coast','West Coast','West Coast','West Coast','West Coast','West Coast','West Coast','East Malaysia', 'East Malaysia','East Coast','East Coast','West Coast','Central','Central','Central','East Malaysia','Central']

# Add new column based on conditions and choices:

merge7['Region1'] = np.select(conditions, choices, default='')
merge7['Region'] = merge7['Region1']

merge7
# Out:
#           Name Serial Number  ...               States1        Region1
# 0          NaN           NaN  ...                 Johor     West Coast
# 1          NaN           NaN  ...                 Johor     West Coast
# 2          NaN           NaN  ...                 Johor     West Coast
# 3          NaN           NaN  ...                 Johor     West Coast
# 4   5CD135B4MD    5CD135B4MD  ...                    KL        Central
# 5   5CD13577FM    5CD13577FM  ...  PETRONAS Twin Towers        Central
# 6   5CD13577HT    5CD13577HT  ...          Kuala Lumpur        Central
# 7   5CD13577BN    5CD13577BN  ...                    KL        Central
# 8   5CD13577H0    5CD13577H0  ...                    KL        Central
# 9   5CD13577CW    5CD13577CW  ...  PETRONAS Twin Towers        Central
# 10  5CD13577D7    5CD13577D7  ...                 Johor     West Coast
# 11  5CD135B48G    5CD135B48G  ...                 Johor     West Coast
# 12  5CD135B4BR    5CD135B4BR  ...          Kuala Lumpur        Central
# 13  5CD13577BS    5CD13577BS  ...          Kuala Lumpur        Central
# 14  5CD112FHL6    5CD112FHL6  ...               Sarawak  East Malaysia
# 15  5CD13577JG    5CD13577JG  ...          KUALA LUMPUR        Central
# 16  5CD13577KL    5CD13577KL  ...  Petronas Twin Towers        Central
# 17  5CG9249GZY    5CG9249GZY  ...               Sarawak  East Malaysia
# 18  5CD13577LR    5CD13577LR  ...                    KL        Central
# 19  5CD135B54X    5CD135B54X  ...                    KL        Central
# 20  5CD112FHN0    5CD112FHN0  ...               Sarawak  East Malaysia
# 21  5CD13577GW    5CD13577GW  ...                    kl
# 22  5CD13577HP    5CD13577HP  ...  PETRONAS Twin Towers        Central
# 23  5CD135B43Y    5CD135B43Y  ...  PETRONAS Twin Towers        Central
# 24  5CD135BFF0    5CD135BFF0  ...                    KL        Central
# 25  5CG9249GTS    5CG9249GTS  ...                    KL        Central
# 26  5CD13577GS    5CD13577GS  ...  PETRONAS Twin Towers        Central
# 27  5CD13577GZ    5CD13577GZ  ...                    KL        Central
# 28  5CD13577KQ    5CD13577KQ  ...          KUALA LUMPUR        Central
# 29  5CD13577J2    5CD13577J2  ...                    KL        Central
# 30  5CD13577J9    5CD13577J9  ...                    KL        Central
# 31  5CD1357785    5CD1357785  ...                    KL        Central
# 32  5CG94732MQ    5CG94732MQ  ...                    KL        Central
# 33  5CD112FHQD    5CD112FHQD  ...               Sarawak  East Malaysia
# 34  5CD13577GQ    5CD13577GQ  ...  PETRONAS Twin Towers        Central
# 35  5CD13577KS    5CD13577KS  ...                    KL        Central
# 36  5CD13577HR    5CD13577HR  ...  Petronas Twin Towers        Central
# 37  5CD13577H2    5CD13577H2  ...                    KL        Central
# 38  5CD13577G3    5CD13577G3  ...                    KL        Central
# 39  5CD135B43F    5CD135B43F  ...          Kuala Lumpur        Central
# 40  5CD135B43F    5CD135B43F  ...          Kuala Lumpur        Central
# 41  5CD13577HM    5CD13577HM  ...                    KL        Central
# 42  5CD13577HY    5CD13577HY  ...                    KL        Central
# 43  5CD135BFDM    5CD135BFDM  ...            terengganu
# 44  CND1330L36    CND1330L36  ...  PETRONAS Twin Towers        Central
# 45  CND1330L11    CND1330L11  ...                    KL        Central
# 46  CND1330L2D    CND1330L2D  ...                    KL        Central
# 47  CND119066H    CND119066H  ...          Kuala Lumpur        Central
#
# [48 rows x 45 columns]

# %%
# Set the conditions for determining values in new column: - Part 2

conditions = [
    (macc7['States1'] == 'Kuala Lumpur'),
    (macc7['States1'] == 'KL'),
    (macc7['States1'] == 'Petronas Twin Towers'),
    (macc7['States1'] == 'Selangor'),
    (macc7['States1'] == 'Terengganu'),
    (macc7['States1'] == 'Johor'),
    (macc7['States1'] == 'Melaka'),
    (macc7['States1'] == 'Perlis'),
    (macc7['States1'] == 'Kedah'),
    (macc7['States1'] == 'Perak'),
    (macc7['States1'] == 'Negeri Sembilan'),
    (macc7['States1'] == 'Sarawak'),
    (macc7['States1'] == 'Sabah'),
    (macc7['States1'] == 'Kelantan'),
    (macc7['States1'] == 'Pahang'),
    (macc7['States1'] == 'Pulau Pinang'),
    (macc7['States1'] == 'PETRONAS Twin Towers'),
    (macc7['States1'] == 'Kl'),
    (macc7['States1'] == 'KUALA LUMPUR'),
    (macc7['States1'] == 'Labuan'),
    (macc7['States1'] == 'PETRONAS TWIN TOWERS')]


# Set the new column values in order of the conditions they should
#	correspond to:

choices = ['Central','Central','Central','Central','East Coast','West Coast','West Coast','West Coast','West Coast','West Coast','West Coast','East Malaysia', 'East Malaysia','East Coast','East Coast','West Coast','Central','Central','Central','East Malaysia','Central']

# Add new column based on conditions and choices:

macc7['Region1'] = np.select(conditions, choices, default='')
macc7['Region'] = macc7['Region1']

macc7
# Out:
#           Name Serial Number  ...               States1  Region1
# 0   5CG124ZX03    5CG124ZX03  ...  Petronas Twin Towers  Central
# 1   5CG124ZX2K    5CG124ZX2K  ...  PETRONAS TWIN TOWERS  Central
# 2   5CG123ZCS4    5CG123ZCS4  ...          Kuala Lumpur  Central
# 3   5CG124ZWW4    5CG124ZWW4  ...  PETRONAS Twin Towers  Central
# 4   5CG126X7D6    5CG126X7D6  ...          Kuala Lumpur  Central
# 5   5CG126X7D6    5CG126X7D6  ...          Kuala Lumpur  Central
# 6   CN413039K0    CN413039K0  ...          KUALA LUMPUR  Central
# 7   CN413039J1    CN413039J1  ...          Kuala Lumpur  Central
# 8   CN41303BQW    CN41303BQW  ...          KUALA LUMPUR  Central
# 9   CN41303BQW    CN41303BQW  ...          KUALA LUMPUR  Central
# 10  CN41303BQV    CN41303BQV  ...          KUALA LUMPUR  Central
#
# [11 rows x 45 columns]

# %%
## Drop states1 and region1 columns - Part 1

merge7 = merge7.drop(['States1','Region1'], axis = 1)


## Drop states1 and region1 columns - Part 2

macc7 = macc7.drop(['States1','Region1'], axis = 1)
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 43 columns]

# %%
## Part 1

merge7['Completion Date1'] = pd.to_datetime(merge7['Completion Date1'], format='%Y-%m-%d')


## Part 2

macc7['Completion Date1'] = pd.to_datetime(macc7['Completion Date1'], format='%Y-%m-%d')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 43 columns]

# %%
## Part 1
merge7.insert(20, 'Lessor', '')

## Part 2
macc7.insert(20, 'Lessor', '')
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 44 columns]

# %%
## Fill up lessor with CTC - Part 1

merge7['Lessor'] = "CTC"


## Fill up lessor with CTC - Part 2

macc7['Lessor'] = "CTC"
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 44 columns]

# %%
## Part 1

merge7 = merge7.loc[:,~merge7.columns.duplicated()]

## Part 2

macc7 = macc7.loc[:,~macc7.columns.duplicated()]
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 41 columns]

# %%
## Part 1

merge7['Completion Date1'] = merge7['Completion Date1'].dt.strftime('%d/%m/%Y')


## Part 2

macc7['Completion Date1'] = macc7['Completion Date1'].dt.strftime('%d/%m/%Y')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 41 columns]

# %%
## Part 1

merge7['ContendDate'] = merge7['ContendDate'].dt.strftime('%d/%m/%Y')


## Part 2

macc7['ContendDate'] = macc7['ContendDate'].dt.strftime('%d/%m/%Y')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 41 columns]

# %%
## Part 1

merge7["Warranty Start"] = merge7["Completion Date1"]
merge7["Warranty End"] = merge7["ContendDate"]


## Part 2

macc7["Warranty Start"] = macc7["Completion Date1"]
macc7["Warranty End"] = macc7["ContendDate"]
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 41 columns]

# %%
## Part 1

merge7['Vendor Schedule Number (EOL)'] = 'N/A'
merge7['Return Batch Number (EOL)'] = 'N/A'
merge7['Return Item Number (EOL)'] = 'N/A'
merge7['Return Date To Lessor (EOL)'] = 'N/A'
merge7['Return Date By User (EOL)'] = 'N/A'
merge7['Lessor Returned Verification (EOL)'] = 'N/A'


## Part 2

macc7['Vendor Schedule Number (EOL)'] = 'N/A'
macc7['Return Batch Number (EOL)'] = 'N/A'
macc7['Return Item Number (EOL)'] = 'N/A'
macc7['Return Date To Lessor (EOL)'] = 'N/A'
macc7['Return Date By User (EOL)'] = 'N/A'
macc7['Lessor Returned Verification (EOL)'] = 'N/A'

macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG124ZX03    5CG124ZX03  ...  Requested to Register in  CMDB
# 1   5CG124ZX2K    5CG124ZX2K  ...  Requested to Register in  CMDB
# 2   5CG123ZCS4    5CG123ZCS4  ...  Requested to Register in  CMDB
# 3   5CG124ZWW4    5CG124ZWW4  ...  Requested to Register in  CMDB
# 4   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 5   5CG126X7D6    5CG126X7D6  ...  Requested to Register in  CMDB
# 6   CN413039K0    CN413039K0  ...  Requested to Register in  CMDB
# 7   CN413039J1    CN413039J1  ...  Requested to Register in  CMDB
# 8   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 9   CN41303BQW    CN41303BQW  ...  Requested to Register in  CMDB
# 10  CN41303BQV    CN41303BQV  ...  Requested to Register in  CMDB
#
# [11 rows x 41 columns]

# %%
# acc1 = data1[(data1['Order Item Status'] == 'Completed') & (data1['Service Sub Category'] == 'PC Accessories')]
# acc1

# %%
# ##################################################################################################################################################################################3
# ## Part 1
# # determining the name of the file to be saved (Change the file path here)
# file_name = '/content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx'

# ## Part 2
# # determining the name of the file to be saved (Change the file path here)
# file_acc = '/content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx'
  
# # saving the excel
# merge7.to_excel(file_name,'Desktop')
# print('DataFrame is written to Excel File successfully.')

# # saving the excel
# macc7.to_excel(file_acc,'PC Accessories')
# print('DataFrame is written to Excel File successfully.')

###############################################################################################################################################################################

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 7.6 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.2

# %%
path = r"/content/drive/MyDrive/PETRONAS/W4 November/35 CMDB EUD Batch Upload Template V1.0_18112021 (1).xlsx"

writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
merge7.to_excel(writer, sheet_name = 'Desktop')
macc7.to_excel(writer, sheet_name = 'PC Accessories')
writer.save()
writer.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/xlsxwriter/workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
