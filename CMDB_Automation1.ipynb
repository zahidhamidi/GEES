# %% [markdown]
# <a href="https://colab.research.google.com/github/zahidhamidi/GEES/blob/main/CMDB_Automation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import libraries

import os
import pandas as pd
from openpyxl import load_workbook
import re
import numpy as np

# %%
## python script to read all file names directory in a folder

path = '/content/drive/MyDrive/PETRONAS'


for root, directories, files in os.walk(path, topdown=False):
	for name in files:
		print(os.path.join(root, name))
	for name in directories:
		print(os.path.join(root, name))
# Out:
# /content/drive/MyDrive/PETRONAS/34 CMDB EUD Batch Upload Template V1.0_08112021.xlsx
# /content/drive/MyDrive/PETRONAS/People Details - 26 Aug 2021.xlsx
# /content/drive/MyDrive/PETRONAS/myGenie_Closed Date_DAAS (Desktop as a Service) Report – V2 - 22 Nov 2021.xlsx
# /content/drive/MyDrive/PETRONAS/00 CMDB Register_COMPILED (2).xlsx
# /content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021 (1).xlsx
# /content/drive/MyDrive/PETRONAS/ICT2U_New PC Request_ServiceOwner_OrderStatus_22Nov2021.xlsx
# /content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx

# %%
##################################################################################################################################################################################



## Import excel file to pandas (Input ICT2u, 00 CMDB compiled, myGenie, People Details and CMDB Batch Upload Template file path here)
## xlsx1 = ICT2U
## xlsx2 = 00 CMDB Register compiled
## xlsx3 = myGenie DAAS
## xlsx4 = People Details
## xlsx5 = CMDB Batch upload template




xls1 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/ICT2U_New PC Request_ServiceOwner_OrderStatus_22Nov2021.xlsx')
xls2 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/00 CMDB Register_COMPILED (2).xlsx')
xls3 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/myGenie_Closed Date_DAAS (Desktop as a Service) Report – V2 - 22 Nov 2021.xlsx')
xls4 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/People Details - 26 Aug 2021.xlsx')
xls5 = pd.ExcelFile(r'/content/drive/MyDrive/PETRONAS/34 CMDB EUD Batch Upload Template V1.0_08112021.xlsx')


##############################################################################################################################################################################

# %%
## Read Excel Data with pandas

data1 = pd.read_excel(xls1, sheet_name="Sheet1")
acc1 = pd.read_excel(xls1, sheet_name="Sheet1")

data2 = pd.read_excel(xls2, sheet_name="CMDB Register Progress")
acc2 = pd.read_excel(xls2, sheet_name="CMDB Register Progress")

data3 = pd.read_excel(xls2, sheet_name="PC INFO")

data6 = pd.read_excel(xls3, sheet_name = "DAAS (Desktop as a Service) Rep")
acc6 = pd.read_excel(xls3, sheet_name = "DAAS (Desktop as a Service) Rep")

data7 = pd.read_excel(xls4, sheet_name = 'People Details')
acc7 = pd.read_excel(xls4, sheet_name = 'People Details')


data8 = pd.read_excel(xls5, sheet_name = 'Device Info')
acc8 = pd.read_excel(xls5, sheet_name = 'Device Info')

# %%
## Cleaning empty rows for data1

data1.columns.values[1] = "myGenie Request Number"

nan_value = float("NaN")

data1.replace("", nan_value, inplace=True)

data1.dropna(subset = ["myGenie Request Number"], inplace=True)


## Cleaning empty rows for acc1

acc1.columns.values[1] = "myGenie Request Number"

nan_value = float("NaN")

acc1.replace("", nan_value, inplace=True)

acc1.dropna(subset = ["myGenie Request Number"], inplace=True)

# %%
## Filter order item Status, Service Sub Category column

data1 = data1[(data1['Order Item Status'] == 'Completed') & (data1['Service Sub Category'] == 'Personal Computer (PC)')]


## Filter order item status for PC Accessories

acc1 = acc1[(acc1['Order Item Status'] == 'Completed') & (acc1['Service Sub Category'] == 'PC Accessories') & (acc1['Service Name'] != 'Headset') ]
acc1
# Out:
#       MyGeniie Created Date  ...                                      Order Details
# 276     Apr  9 2021 10:00AM  ...  Region Area : West Malaysia (Johor) | Alternat...
# 283     Apr  7 2021  3:39PM  ...  Region Area : PETT (T1) | Alternate Recipient ...
# 313     Apr 12 2021  1:53AM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 314     Apr 12 2021  1:53AM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 493     Apr 19 2021  6:44AM  ...  Region Area : West Malaysia (Johor) | Alternat...
# ...                     ...  ...                                                ...
# 12984   Oct 24 2021  9:14PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12986   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12987   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12988   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12989   Oct 24 2021  9:04PM  ...  Region Area : PETT (T2) | Alternate Recipient ...
#
# [664 rows x 25 columns]

# %%
## Convert Order Number column from float to int

data1['Order Number'] = data1['Order Number'].astype(int)



## Convert order number column from float to int for PC accessories

acc1['Order Number'] = acc1['Order Number'].astype(int)

# %%
## Clean required columns only for data1

data1 = pd.DataFrame(data1, columns= ['myGenie Request Number','Order Item Number', 'Service Name','Custodian User Name','Custodian Email','Delivery Address','Identifer 1 Value','Identifier 2 Value','Order Details' ])


## Clean required columns only for acc1

acc1 = pd.DataFrame(acc1, columns= ['myGenie Request Number','Order Item Number', 'Service Name','Custodian User Name','Custodian Email','Delivery Address','Identifer 1 Value','Identifier 2 Value','Order Details' ])
acc1
# Out:
#       myGenie Request Number  ...                                      Order Details
# 276          REQ000003546242  ...  Region Area : West Malaysia (Johor) | Alternat...
# 283          REQ000003540877  ...  Region Area : PETT (T1) | Alternate Recipient ...
# 313          REQ000003550044  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 314          REQ000003550045  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 493          REQ000003566374  ...  Region Area : West Malaysia (Johor) | Alternat...
# ...                      ...  ...                                                ...
# 12984        REQ000004019650  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12986        REQ000004019648  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12987        REQ000004019737  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12988        REQ000004019504  ...  Region Area : PETT (T2) | Alternate Recipient ...
# 12989        REQ000004019649  ...  Region Area : PETT (T2) | Alternate Recipient ...
#
# [664 rows x 9 columns]

# %%
## Create Region column 

data1['Region'] = ""


## Create Region column 

acc1['Region'] = ""

# %%
## Cleaning empty rows for data1

nan_value = float("NaN")

data1.replace("", nan_value, inplace=True)

data1.dropna(subset = ["Delivery Address"], inplace=True)


## Cleaning empty rows for acc1

nan_value = float("NaN")

acc1.replace("", nan_value, inplace=True)

acc1.dropna(subset = ["Delivery Address"], inplace=True)

# %%
# ## Fill Region column relative to address data

# data1.assign(Region = "")

# if data1.loc[data1['Delivery Address'].str.contains("Kuala Lumpur")]:
#   data1.insert("Kuala Lumpur", "Region", "")
  

# # data1.loc[data1['Delivery Address'] == 'Kuala Lumpur', 'Region'] = 'Central'

# %%
## Clean required columns only for data2

data2 = pd.DataFrame(data2, columns= ['myGenie Request Number','STATUS'])


## Clean required columns only for data2

acc2 = pd.DataFrame(acc2, columns= ['myGenie Request Number','STATUS'])

# %%
## VLOOKUP myGenie Request Number   

outer_join = pd.merge(data1, 
                      data2, 
                      on ='myGenie Request Number', 
                      how ='outer')







## VLOOKUP myGenie Request Number (PC Accessories)  

acc_join = pd.merge(acc1, 
                      acc2, 
                      on ='myGenie Request Number', 
                      how ='outer')




acc_join
# Out:
#       myGenie Request Number  ...                          STATUS
# 0            REQ000003546242  ...  Requested to Register in  CMDB
# 1            REQ000003540877  ...  Requested to Register in  CMDB
# 2            REQ000003550044  ...  Requested to Register in  CMDB
# 3            REQ000003550045  ...  Requested to Register in  CMDB
# 4            REQ000003566374  ...  Requested to Register in  CMDB
# ...                      ...  ...                             ...
# 15376        REQ000004023055  ...  Requested to Register in  CMDB
# 15377        REQ000004026757  ...  Requested to Register in  CMDB
# 15378        REQ000004027082  ...  Requested to Register in  CMDB
# 15379        REQ000004031948  ...  Requested to Register in  CMDB
# 15380        REQ000004011990  ...  Requested to Register in  CMDB
#
# [15381 rows x 11 columns]

# %%
## Get only STATUS column not registered to CMDB

outer_join.drop(outer_join[outer_join['STATUS'] == "Requested to Register in  CMDB"].index, inplace = True)

data4 = outer_join[["Identifier 2 Value","Custodian Email"]]


data4 = data4.rename(columns={'Identifier 2 Value': 'Name'})




## Get only STATUS column not registered to CMDB (PC Accessories)

acc_join.drop(acc_join[acc_join['STATUS'] == "Requested to Register in  CMDB"].index, inplace = True)

acc4 = acc_join[["Identifier 2 Value","Custodian Email"]]


acc4 = acc4.rename(columns={'Identifier 2 Value': 'Name'})
acc4
# Out:
#            Name                       Custodian Email
# 619  5CG123ZCDB      atikah_abuhassan@petronas.com.my
# 620  CN41182G5N   ainaathirah.ablatip@petronas.com.my
# 621  CN413039JB         firdaus.razak@petronas.com.my
# 622  CN413039JM          maziah_manaf@petronas.com.my
# 623  5CG123ZCBL        hanif_zulkapli@petronas.com.my
# 624  CN413039HH          maziah_manaf@petronas.com.my
# 625  CN413039JH        hanif_zulkapli@petronas.com.my
# 626  5CG123ZCCM         firdaus.razak@petronas.com.my
# 627  CN41182G5J           amira.fauzi@petronas.com.my
# 628  5CG124ZWR5  sergio.fondevillealv@petronas.com.my
# 629  CN413039JP   leonardoramon.lopez@petronas.com.my
# 630  5CG124ZWKV           amira.fauzi@petronas.com.my
# 631  CN41182G42         yongken.phoon@petronas.com.my
# 632         NaN         yongken.phoon@petronas.com.my
# 633  5CG123ZCRB          maziah_manaf@petronas.com.my
# 634  CN413039JT  sergio.fondevillealv@petronas.com.my
# 635  5CG115X1R6         yongken.phoon@petronas.com.my
# 636   CN41303HR         firdaus.razak@petronas.com.my
# 637  5CG123ZCDY         luqman_rahman@petronas.com.my
# 638  CN413039JL        hanif_zulkapli@petronas.com.my
# 639  5CG124ZV80          erniezanasir@petronas.com.my
# 640  5CG123ZCDD   leonardoramon.lopez@petronas.com.my
# 641  CN413039HN          erniezanasir@petronas.com.my
# 642  CN413039JW          erniezanasir@petronas.com.my
# 643  CN41182G5B  sergio.fondevillealv@petronas.com.my
# 644  CN41182G60   leonardoramon.lopez@petronas.com.my
# 645  CN413039J5           amira.fauzi@petronas.com.my
# 646  CN413039J8     anisliyana.zahari@petronas.com.my
# 647  CN413039JD      badariah.bahadon@petronas.com.my
# 648  CN41182G64                emylia@petronas.com.my
# 649  5CG123ZCDG      hassan_abdullahb@petronas.com.my
# 650         NaN       shatilla.zainal@petronas.com.my
# 651  5CG123ZCCL          mnizam_ahmad@petronas.com.my
# 652  CN41182G4V          mnizam_ahmad@petronas.com.my
# 653  CN41182G4N     megatahmadfaiz.abdaz@petronas.com
# 654  5CG123ZCRY     megatahmadfaiz.abdaz@petronas.com
# 655  5CG123ZCFL      ankajkumar.sinha@petronas.com.my

# %%
#outer_join

# %%
## Create new columns

outer_join['Hostname'] = ''



outer_join.Hostname = 'H'     # A single value 'propagates' to all column cells



# Create new columns


acc_join['Hostname'] = ''



acc_join.Hostname = 'H'     # A single value 'propagates' to all column cells
acc_join
# Out:
#     myGenie Request Number  Order Item Number  ... STATUS Hostname
# 619        REQ000004040520          2683748.0  ...    NaN        H
# 620        REQ000004038654          2683490.0  ...    NaN        H
# 621        REQ000004045318          2684161.0  ...    NaN        H
# 622        REQ000004045140          2684166.0  ...    NaN        H
# 623        REQ000004044807          2684153.0  ...    NaN        H
# 624        REQ000004045136          2684160.0  ...    NaN        H
# 625        REQ000004045321          2684167.0  ...    NaN        H
# 626        REQ000004045092          2684158.0  ...    NaN        H
# 627        REQ000004045142          2684169.0  ...    NaN        H
# 628        REQ000004044812          2684170.0  ...    NaN        H
# 629        REQ000004045137          2684164.0  ...    NaN        H
# 630        REQ000004044808          2684154.0  ...    NaN        H
# 631        REQ000004045095          2684156.0  ...    NaN        H
# 632        REQ000004045094          2684152.0  ...    NaN        H
# 633        REQ000004045133          2684148.0  ...    NaN        H
# 634        REQ000004045016          2684151.0  ...    NaN        H
# 635        REQ000004045143          2684149.0  ...    NaN        H
# 636        REQ000004045093          2684172.0  ...    NaN        H
# 637        REQ000004045015          2684157.0  ...    NaN        H
# 638        REQ000004045322          2684171.0  ...    NaN        H
# 639        REQ000004044810          2684155.0  ...    NaN        H
# 640        REQ000004045131          2684168.0  ...    NaN        H
# 641        REQ000004044813          2684162.0  ...    NaN        H
# 642        REQ000004045138          2684165.0  ...    NaN        H
# 643        REQ000004045135          2684159.0  ...    NaN        H
# 644        REQ000004045134          2684150.0  ...    NaN        H
# 645        REQ000004044815          2684163.0  ...    NaN        H
# 646        REQ000004046391          2684440.0  ...    NaN        H
# 647        REQ000004048120          2684461.0  ...    NaN        H
# 648        REQ000004051999          2684881.0  ...    NaN        H
# 649        REQ000004051997          2684882.0  ...    NaN        H
# 650        REQ000004055470          2685412.0  ...    NaN        H
# 651        REQ000004058764          2694407.0  ...    NaN        H
# 652        REQ000004058763          2694406.0  ...    NaN        H
# 653        REQ000004063730          2716398.0  ...    NaN        H
# 654        REQ000004063555          2716399.0  ...    NaN        H
# 655        REQ000004062045          2711209.0  ...    NaN        H
#
# [37 rows x 12 columns]

# %%
## Rename columns

outer_join1 = outer_join.rename(columns={'Identifier 2 Value': 'Name'})


## Rename columns

acc_join1 = acc_join.rename(columns={'Identifier 2 Value': 'Name'})
acc_join1
# Out:
#     myGenie Request Number  Order Item Number  ... STATUS Hostname
# 619        REQ000004040520          2683748.0  ...    NaN        H
# 620        REQ000004038654          2683490.0  ...    NaN        H
# 621        REQ000004045318          2684161.0  ...    NaN        H
# 622        REQ000004045140          2684166.0  ...    NaN        H
# 623        REQ000004044807          2684153.0  ...    NaN        H
# 624        REQ000004045136          2684160.0  ...    NaN        H
# 625        REQ000004045321          2684167.0  ...    NaN        H
# 626        REQ000004045092          2684158.0  ...    NaN        H
# 627        REQ000004045142          2684169.0  ...    NaN        H
# 628        REQ000004044812          2684170.0  ...    NaN        H
# 629        REQ000004045137          2684164.0  ...    NaN        H
# 630        REQ000004044808          2684154.0  ...    NaN        H
# 631        REQ000004045095          2684156.0  ...    NaN        H
# 632        REQ000004045094          2684152.0  ...    NaN        H
# 633        REQ000004045133          2684148.0  ...    NaN        H
# 634        REQ000004045016          2684151.0  ...    NaN        H
# 635        REQ000004045143          2684149.0  ...    NaN        H
# 636        REQ000004045093          2684172.0  ...    NaN        H
# 637        REQ000004045015          2684157.0  ...    NaN        H
# 638        REQ000004045322          2684171.0  ...    NaN        H
# 639        REQ000004044810          2684155.0  ...    NaN        H
# 640        REQ000004045131          2684168.0  ...    NaN        H
# 641        REQ000004044813          2684162.0  ...    NaN        H
# 642        REQ000004045138          2684165.0  ...    NaN        H
# 643        REQ000004045135          2684159.0  ...    NaN        H
# 644        REQ000004045134          2684150.0  ...    NaN        H
# 645        REQ000004044815          2684163.0  ...    NaN        H
# 646        REQ000004046391          2684440.0  ...    NaN        H
# 647        REQ000004048120          2684461.0  ...    NaN        H
# 648        REQ000004051999          2684881.0  ...    NaN        H
# 649        REQ000004051997          2684882.0  ...    NaN        H
# 650        REQ000004055470          2685412.0  ...    NaN        H
# 651        REQ000004058764          2694407.0  ...    NaN        H
# 652        REQ000004058763          2694406.0  ...    NaN        H
# 653        REQ000004063730          2716398.0  ...    NaN        H
# 654        REQ000004063555          2716399.0  ...    NaN        H
# 655        REQ000004062045          2711209.0  ...    NaN        H
#
# [37 rows x 12 columns]

# %%
## Reorder columns in outer_join

outer_join1 = outer_join1[["Name","Hostname","Service Name"]]




## Reorder columns in outer_join

acc_join1 = acc_join1[["Name","Hostname","Service Name"]]
acc_join1
# Out:
#            Name Hostname     Service Name
# 619  5CG123ZCDB        H  Docking Station
# 620  CN41182G5N        H      Monitor 24”
# 621  CN413039JB        H      Monitor 24”
# 622  CN413039JM        H      Monitor 24”
# 623  5CG123ZCBL        H  Docking Station
# 624  CN413039HH        H      Monitor 24”
# 625  CN413039JH        H      Monitor 24”
# 626  5CG123ZCCM        H  Docking Station
# 627  CN41182G5J        H      Monitor 24”
# 628  5CG124ZWR5        H  Docking Station
# 629  CN413039JP        H      Monitor 24”
# 630  5CG124ZWKV        H  Docking Station
# 631  CN41182G42        H      Monitor 24”
# 632         NaN        H      Monitor 24”
# 633  5CG123ZCRB        H  Docking Station
# 634  CN413039JT        H      Monitor 24”
# 635  5CG115X1R6        H  Docking Station
# 636   CN41303HR        H      Monitor 24”
# 637  5CG123ZCDY        H  Docking Station
# 638  CN413039JL        H      Monitor 24”
# 639  5CG124ZV80        H  Docking Station
# 640  5CG123ZCDD        H  Docking Station
# 641  CN413039HN        H      Monitor 24”
# 642  CN413039JW        H      Monitor 24”
# 643  CN41182G5B        H      Monitor 24”
# 644  CN41182G60        H      Monitor 24”
# 645  CN413039J5        H      Monitor 24”
# 646  CN413039J8        H      Monitor 24”
# 647  CN413039JD        H      Monitor 24”
# 648  CN41182G64        H      Monitor 24”
# 649  5CG123ZCDG        H  Docking Station
# 650         NaN        H      Monitor 24”
# 651  5CG123ZCCL        H  Docking Station
# 652  CN41182G4V        H      Monitor 24”
# 653  CN41182G4N        H      Monitor 24”
# 654  5CG123ZCRY        H  Docking Station
# 655  5CG123ZCFL        H  Docking Station

# %%
## Creating Hostname column

# making copy of Name column
new = outer_join1["Name"].copy()
 

# overwriting name column
outer_join1["Hostname"]= outer_join1["Hostname"].str.cat(new, sep="")
 




## Creating Hostname column

# making copy of Name column
new_acc = acc_join1["Name"].copy()
 

# overwriting name column
acc_join1["Hostname"]= acc_join1["Hostname"].str.cat(new_acc, sep="")
 
acc_join1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Name     Hostname     Service Name
# 619  5CG123ZCDB  H5CG123ZCDB  Docking Station
# 620  CN41182G5N  HCN41182G5N      Monitor 24”
# 621  CN413039JB  HCN413039JB      Monitor 24”
# 622  CN413039JM  HCN413039JM      Monitor 24”
# 623  5CG123ZCBL  H5CG123ZCBL  Docking Station
# 624  CN413039HH  HCN413039HH      Monitor 24”
# 625  CN413039JH  HCN413039JH      Monitor 24”
# 626  5CG123ZCCM  H5CG123ZCCM  Docking Station
# 627  CN41182G5J  HCN41182G5J      Monitor 24”
# 628  5CG124ZWR5  H5CG124ZWR5  Docking Station
# 629  CN413039JP  HCN413039JP      Monitor 24”
# 630  5CG124ZWKV  H5CG124ZWKV  Docking Station
# 631  CN41182G42  HCN41182G42      Monitor 24”
# 632         NaN          NaN      Monitor 24”
# 633  5CG123ZCRB  H5CG123ZCRB  Docking Station
# 634  CN413039JT  HCN413039JT      Monitor 24”
# 635  5CG115X1R6  H5CG115X1R6  Docking Station
# 636   CN41303HR   HCN41303HR      Monitor 24”
# 637  5CG123ZCDY  H5CG123ZCDY  Docking Station
# 638  CN413039JL  HCN413039JL      Monitor 24”
# 639  5CG124ZV80  H5CG124ZV80  Docking Station
# 640  5CG123ZCDD  H5CG123ZCDD  Docking Station
# 641  CN413039HN  HCN413039HN      Monitor 24”
# 642  CN413039JW  HCN413039JW      Monitor 24”
# 643  CN41182G5B  HCN41182G5B      Monitor 24”
# 644  CN41182G60  HCN41182G60      Monitor 24”
# 645  CN413039J5  HCN413039J5      Monitor 24”
# 646  CN413039J8  HCN413039J8      Monitor 24”
# 647  CN413039JD  HCN413039JD      Monitor 24”
# 648  CN41182G64  HCN41182G64      Monitor 24”
# 649  5CG123ZCDG  H5CG123ZCDG  Docking Station
# 650         NaN          NaN      Monitor 24”
# 651  5CG123ZCCL  H5CG123ZCCL  Docking Station
# 652  CN41182G4V  HCN41182G4V      Monitor 24”
# 653  CN41182G4N  HCN41182G4N      Monitor 24”
# 654  5CG123ZCRY  H5CG123ZCRY  Docking Station
# 655  5CG123ZCFL  H5CG123ZCFL  Docking Station

# %%
## PC part

outer_join1 = outer_join1[["Name","Name","Hostname","Service Name"]]

outer_join1.columns.values[1] = "Serial Number"

outer_join1['Operating System'] = ''
outer_join1['Status'] = ''
outer_join1['Status Reason'] = ''
outer_join1["Operating System"] = ''

outer_join1.Status = 'Deployed'






## PC Accessories part

acc_join1 = acc_join1[["Name","Name","Hostname","Service Name"]]

acc_join1.columns.values[1] = "Serial Number"

acc_join1['Operating System'] = ''
acc_join1['Status'] = ''
acc_join1['Status Reason'] = ''
acc_join1["Operating System"] = ''

acc_join1.Status = 'Deployed'

acc_join1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            Name Serial Number  ...    Status Status Reason
# 619  5CG123ZCDB    5CG123ZCDB  ...  Deployed
# 620  CN41182G5N    CN41182G5N  ...  Deployed
# 621  CN413039JB    CN413039JB  ...  Deployed
# 622  CN413039JM    CN413039JM  ...  Deployed
# 623  5CG123ZCBL    5CG123ZCBL  ...  Deployed
# 624  CN413039HH    CN413039HH  ...  Deployed
# 625  CN413039JH    CN413039JH  ...  Deployed
# 626  5CG123ZCCM    5CG123ZCCM  ...  Deployed
# 627  CN41182G5J    CN41182G5J  ...  Deployed
# 628  5CG124ZWR5    5CG124ZWR5  ...  Deployed
# 629  CN413039JP    CN413039JP  ...  Deployed
# 630  5CG124ZWKV    5CG124ZWKV  ...  Deployed
# 631  CN41182G42    CN41182G42  ...  Deployed
# 632         NaN           NaN  ...  Deployed
# 633  5CG123ZCRB    5CG123ZCRB  ...  Deployed
# 634  CN413039JT    CN413039JT  ...  Deployed
# 635  5CG115X1R6    5CG115X1R6  ...  Deployed
# 636   CN41303HR     CN41303HR  ...  Deployed
# 637  5CG123ZCDY    5CG123ZCDY  ...  Deployed
# 638  CN413039JL    CN413039JL  ...  Deployed
# 639  5CG124ZV80    5CG124ZV80  ...  Deployed
# 640  5CG123ZCDD    5CG123ZCDD  ...  Deployed
# 641  CN413039HN    CN413039HN  ...  Deployed
# 642  CN413039JW    CN413039JW  ...  Deployed
# 643  CN41182G5B    CN41182G5B  ...  Deployed
# 644  CN41182G60    CN41182G60  ...  Deployed
# 645  CN413039J5    CN413039J5  ...  Deployed
# 646  CN413039J8    CN413039J8  ...  Deployed
# 647  CN413039JD    CN413039JD  ...  Deployed
# 648  CN41182G64    CN41182G64  ...  Deployed
# 649  5CG123ZCDG    5CG123ZCDG  ...  Deployed
# 650         NaN           NaN  ...  Deployed
# 651  5CG123ZCCL    5CG123ZCCL  ...  Deployed
# 652  CN41182G4V    CN41182G4V  ...  Deployed
# 653  CN41182G4N    CN41182G4N  ...  Deployed
# 654  5CG123ZCRY    5CG123ZCRY  ...  Deployed
# 655  5CG123ZCFL    5CG123ZCFL  ...  Deployed
#
# [37 rows x 7 columns]

# %%
## Clean required columns only for data3

data8 = pd.DataFrame(data8, columns= ['ICT2U Model','Category',"Type",'Item','Capability List','PC Model','RAM'])
data8


## Clean required columns only for acc3 (PC Accessories)

acc8 = pd.DataFrame(data8, columns= ['ICT2U Model','Category',"Type",'Item','Capability List','PC Model','RAM'])
acc8
# Out:
#                                        ICT2U Model  ...    RAM
# 0                                            Riser  ...    NaN
# 1                                    Laptop (8 GB)  ...    8GB
# 2                                   Laptop (16 GB)  ...   16GB
# 3                                    Laptop 2-in-1  ...   16GB
# 4                                      Monitor 24”  ...    NaN
# 5                                  Laptop Standard  ...   16GB
# 6                               Desktop All-in-One  ...    8GB
# 7                                 Desktop Standard  ...    8GB
# 8                                  Docking Station  ...    NaN
# 9                                      Monitor 30"  ...    NaN
# 10                            Workstation Standard  ...  128GB
# 11                              Workstation Mobile  ...   32GB
# 12                                            iPad  ...    NaN
# 13                                iPad Accessories  ...    NaN
# 14      Intrinsically Safe Certified Zone 1 Tablet  ...    NaN
# 15  Intrinsically Safe Certified Zone 1 Smartphone  ...    NaN
#
# [16 rows x 7 columns]

# %%
## Rename columns

data3 = data8.rename(columns={'ICT2U Model': 'Service Name'})

data3



## Rename columns

acc3 = acc8.rename(columns={'ICT2U Model': 'Service Name'})

acc3
# Out:
#                                       Service Name  ...    RAM
# 0                                            Riser  ...    NaN
# 1                                    Laptop (8 GB)  ...    8GB
# 2                                   Laptop (16 GB)  ...   16GB
# 3                                    Laptop 2-in-1  ...   16GB
# 4                                      Monitor 24”  ...    NaN
# 5                                  Laptop Standard  ...   16GB
# 6                               Desktop All-in-One  ...    8GB
# 7                                 Desktop Standard  ...    8GB
# 8                                  Docking Station  ...    NaN
# 9                                      Monitor 30"  ...    NaN
# 10                            Workstation Standard  ...  128GB
# 11                              Workstation Mobile  ...   32GB
# 12                                            iPad  ...    NaN
# 13                                iPad Accessories  ...    NaN
# 14      Intrinsically Safe Certified Zone 1 Tablet  ...    NaN
# 15  Intrinsically Safe Certified Zone 1 Smartphone  ...    NaN
#
# [16 rows x 7 columns]

# %%
## VLOOKUP myGenie Request Number   

outer_join2 = pd.merge(outer_join, 
                      data3, 
                      on ='Service Name', 
                      how ='outer')


## Cleaning empty rows for outer_join2

nan_value = float("NaN")

outer_join2.replace("", nan_value, inplace=True)

outer_join2.dropna(subset = ["myGenie Request Number"], inplace=True)






## VLOOKUP myGenie Request Number   

acc_join2 = pd.merge(acc_join, 
                      acc3, 
                      on ='Service Name', 
                      how ='outer')


## Cleaning empty rows for outer_join2

nan_value = float("NaN")

acc_join2.replace("", nan_value, inplace=True)

acc_join2.dropna(subset = ["myGenie Request Number"], inplace=True)



acc_join2
# Out:
#    myGenie Request Number  Order Item Number  ...              PC Model  RAM
# 0         REQ000004040520          2683748.0  ...      HP USB-C Dock G4  NaN
# 1         REQ000004044807          2684153.0  ...      HP USB-C Dock G4  NaN
# 2         REQ000004045092          2684158.0  ...      HP USB-C Dock G4  NaN
# 3         REQ000004044812          2684170.0  ...      HP USB-C Dock G4  NaN
# 4         REQ000004044808          2684154.0  ...      HP USB-C Dock G4  NaN
# 5         REQ000004045133          2684148.0  ...      HP USB-C Dock G4  NaN
# 6         REQ000004045143          2684149.0  ...      HP USB-C Dock G4  NaN
# 7         REQ000004045015          2684157.0  ...      HP USB-C Dock G4  NaN
# 8         REQ000004044810          2684155.0  ...      HP USB-C Dock G4  NaN
# 9         REQ000004045131          2684168.0  ...      HP USB-C Dock G4  NaN
# 10        REQ000004051997          2684882.0  ...      HP USB-C Dock G4  NaN
# 11        REQ000004058764          2694407.0  ...      HP USB-C Dock G4  NaN
# 12        REQ000004063555          2716399.0  ...      HP USB-C Dock G4  NaN
# 13        REQ000004062045          2711209.0  ...      HP USB-C Dock G4  NaN
# 14        REQ000004038654          2683490.0  ...  HP EliteDisplay E243  NaN
# 15        REQ000004045318          2684161.0  ...  HP EliteDisplay E243  NaN
# 16        REQ000004045140          2684166.0  ...  HP EliteDisplay E243  NaN
# 17        REQ000004045136          2684160.0  ...  HP EliteDisplay E243  NaN
# 18        REQ000004045321          2684167.0  ...  HP EliteDisplay E243  NaN
# 19        REQ000004045142          2684169.0  ...  HP EliteDisplay E243  NaN
# 20        REQ000004045137          2684164.0  ...  HP EliteDisplay E243  NaN
# 21        REQ000004045095          2684156.0  ...  HP EliteDisplay E243  NaN
# 22        REQ000004045094          2684152.0  ...  HP EliteDisplay E243  NaN
# 23        REQ000004045016          2684151.0  ...  HP EliteDisplay E243  NaN
# 24        REQ000004045093          2684172.0  ...  HP EliteDisplay E243  NaN
# 25        REQ000004045322          2684171.0  ...  HP EliteDisplay E243  NaN
# 26        REQ000004044813          2684162.0  ...  HP EliteDisplay E243  NaN
# 27        REQ000004045138          2684165.0  ...  HP EliteDisplay E243  NaN
# 28        REQ000004045135          2684159.0  ...  HP EliteDisplay E243  NaN
# 29        REQ000004045134          2684150.0  ...  HP EliteDisplay E243  NaN
# 30        REQ000004044815          2684163.0  ...  HP EliteDisplay E243  NaN
# 31        REQ000004046391          2684440.0  ...  HP EliteDisplay E243  NaN
# 32        REQ000004048120          2684461.0  ...  HP EliteDisplay E243  NaN
# 33        REQ000004051999          2684881.0  ...  HP EliteDisplay E243  NaN
# 34        REQ000004055470          2685412.0  ...  HP EliteDisplay E243  NaN
# 35        REQ000004058763          2694406.0  ...  HP EliteDisplay E243  NaN
# 36        REQ000004063730          2716398.0  ...  HP EliteDisplay E243  NaN
#
# [37 rows x 18 columns]

# %%
## Clean required columns only for outer_join2

outer_join2 = pd.DataFrame(outer_join2, columns= ['Service Name','Category',"Type",'Item','PC Model','RAM','PC Model','Capability List'])




## Clean required columns only for acc_join2

acc_join2 = pd.DataFrame(acc_join2, columns= ['Service Name','Category',"Type",'Item','PC Model','RAM','PC Model','Capability List'])

acc_join2
# Out:
#        Service Name  Category  ...              PC Model Capability List
# 0   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 1   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 2   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 3   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 4   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 5   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 6   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 7   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 8   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 9   Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 10  Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 11  Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 12  Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 13  Docking Station  Hardware  ...      HP USB-C Dock G4           Other
# 14      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 15      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 16      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 17      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 18      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 19      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 20      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 21      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 22      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 23      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 24      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 25      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 26      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 27      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 28      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 29      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 30      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 31      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 32      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 33      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 34      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 35      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
# 36      Monitor 24”  Hardware  ...  HP EliteDisplay E243           Other
#
# [37 rows x 8 columns]

# %%
# merge1 = pd.merge(outer_join1, outer_join2, on='Service Name')

# merge1

## VLOOKUP myGenie Request Number   

merge1 = pd.merge(outer_join1, 
                      outer_join2, 
                      on ='Service Name', 
                      how ='outer')

final1 = merge1.drop_duplicates(subset="Serial Number")



## Part 2 PC Accessories

   
macc1 = pd.merge(acc_join1, 
                      acc_join2, 
                      on ='Service Name', 
                      how ='outer')

facc1 = macc1.drop_duplicates(subset="Serial Number")

facc1
# Out:
#            Name Serial Number  ...              PC Model Capability List
# 0    5CG123ZCDB    5CG123ZCDB  ...      HP USB-C Dock G4           Other
# 14   5CG123ZCBL    5CG123ZCBL  ...      HP USB-C Dock G4           Other
# 28   5CG123ZCCM    5CG123ZCCM  ...      HP USB-C Dock G4           Other
# 42   5CG124ZWR5    5CG124ZWR5  ...      HP USB-C Dock G4           Other
# 56   5CG124ZWKV    5CG124ZWKV  ...      HP USB-C Dock G4           Other
# 70   5CG123ZCRB    5CG123ZCRB  ...      HP USB-C Dock G4           Other
# 84   5CG115X1R6    5CG115X1R6  ...      HP USB-C Dock G4           Other
# 98   5CG123ZCDY    5CG123ZCDY  ...      HP USB-C Dock G4           Other
# 112  5CG124ZV80    5CG124ZV80  ...      HP USB-C Dock G4           Other
# 126  5CG123ZCDD    5CG123ZCDD  ...      HP USB-C Dock G4           Other
# 140  5CG123ZCDG    5CG123ZCDG  ...      HP USB-C Dock G4           Other
# 154  5CG123ZCCL    5CG123ZCCL  ...      HP USB-C Dock G4           Other
# 168  5CG123ZCRY    5CG123ZCRY  ...      HP USB-C Dock G4           Other
# 182  5CG123ZCFL    5CG123ZCFL  ...      HP USB-C Dock G4           Other
# 196  CN41182G5N    CN41182G5N  ...  HP EliteDisplay E243           Other
# 219  CN413039JB    CN413039JB  ...  HP EliteDisplay E243           Other
# 242  CN413039JM    CN413039JM  ...  HP EliteDisplay E243           Other
# 265  CN413039HH    CN413039HH  ...  HP EliteDisplay E243           Other
# 288  CN413039JH    CN413039JH  ...  HP EliteDisplay E243           Other
# 311  CN41182G5J    CN41182G5J  ...  HP EliteDisplay E243           Other
# 334  CN413039JP    CN413039JP  ...  HP EliteDisplay E243           Other
# 357  CN41182G42    CN41182G42  ...  HP EliteDisplay E243           Other
# 380         NaN           NaN  ...  HP EliteDisplay E243           Other
# 403  CN413039JT    CN413039JT  ...  HP EliteDisplay E243           Other
# 426   CN41303HR     CN41303HR  ...  HP EliteDisplay E243           Other
# 449  CN413039JL    CN413039JL  ...  HP EliteDisplay E243           Other
# 472  CN413039HN    CN413039HN  ...  HP EliteDisplay E243           Other
# 495  CN413039JW    CN413039JW  ...  HP EliteDisplay E243           Other
# 518  CN41182G5B    CN41182G5B  ...  HP EliteDisplay E243           Other
# 541  CN41182G60    CN41182G60  ...  HP EliteDisplay E243           Other
# 564  CN413039J5    CN413039J5  ...  HP EliteDisplay E243           Other
# 587  CN413039J8    CN413039J8  ...  HP EliteDisplay E243           Other
# 610  CN413039JD    CN413039JD  ...  HP EliteDisplay E243           Other
# 633  CN41182G64    CN41182G64  ...  HP EliteDisplay E243           Other
# 679  CN41182G4V    CN41182G4V  ...  HP EliteDisplay E243           Other
# 702  CN41182G4N    CN41182G4N  ...  HP EliteDisplay E243           Other
#
# [36 rows x 14 columns]

# %%
## Part 1

final1.drop('Service Name',
  axis='columns', inplace=True)



## Part 2

facc1.drop('Service Name',
  axis='columns', inplace=True)



facc1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#            Name Serial Number  ...              PC Model Capability List
# 0    5CG123ZCDB    5CG123ZCDB  ...      HP USB-C Dock G4           Other
# 14   5CG123ZCBL    5CG123ZCBL  ...      HP USB-C Dock G4           Other
# 28   5CG123ZCCM    5CG123ZCCM  ...      HP USB-C Dock G4           Other
# 42   5CG124ZWR5    5CG124ZWR5  ...      HP USB-C Dock G4           Other
# 56   5CG124ZWKV    5CG124ZWKV  ...      HP USB-C Dock G4           Other
# 70   5CG123ZCRB    5CG123ZCRB  ...      HP USB-C Dock G4           Other
# 84   5CG115X1R6    5CG115X1R6  ...      HP USB-C Dock G4           Other
# 98   5CG123ZCDY    5CG123ZCDY  ...      HP USB-C Dock G4           Other
# 112  5CG124ZV80    5CG124ZV80  ...      HP USB-C Dock G4           Other
# 126  5CG123ZCDD    5CG123ZCDD  ...      HP USB-C Dock G4           Other
# 140  5CG123ZCDG    5CG123ZCDG  ...      HP USB-C Dock G4           Other
# 154  5CG123ZCCL    5CG123ZCCL  ...      HP USB-C Dock G4           Other
# 168  5CG123ZCRY    5CG123ZCRY  ...      HP USB-C Dock G4           Other
# 182  5CG123ZCFL    5CG123ZCFL  ...      HP USB-C Dock G4           Other
# 196  CN41182G5N    CN41182G5N  ...  HP EliteDisplay E243           Other
# 219  CN413039JB    CN413039JB  ...  HP EliteDisplay E243           Other
# 242  CN413039JM    CN413039JM  ...  HP EliteDisplay E243           Other
# 265  CN413039HH    CN413039HH  ...  HP EliteDisplay E243           Other
# 288  CN413039JH    CN413039JH  ...  HP EliteDisplay E243           Other
# 311  CN41182G5J    CN41182G5J  ...  HP EliteDisplay E243           Other
# 334  CN413039JP    CN413039JP  ...  HP EliteDisplay E243           Other
# 357  CN41182G42    CN41182G42  ...  HP EliteDisplay E243           Other
# 380         NaN           NaN  ...  HP EliteDisplay E243           Other
# 403  CN413039JT    CN413039JT  ...  HP EliteDisplay E243           Other
# 426   CN41303HR     CN41303HR  ...  HP EliteDisplay E243           Other
# 449  CN413039JL    CN413039JL  ...  HP EliteDisplay E243           Other
# 472  CN413039HN    CN413039HN  ...  HP EliteDisplay E243           Other
# 495  CN413039JW    CN413039JW  ...  HP EliteDisplay E243           Other
# 518  CN41182G5B    CN41182G5B  ...  HP EliteDisplay E243           Other
# 541  CN41182G60    CN41182G60  ...  HP EliteDisplay E243           Other
# 564  CN413039J5    CN413039J5  ...  HP EliteDisplay E243           Other
# 587  CN413039J8    CN413039J8  ...  HP EliteDisplay E243           Other
# 610  CN413039JD    CN413039JD  ...  HP EliteDisplay E243           Other
# 633  CN41182G64    CN41182G64  ...  HP EliteDisplay E243           Other
# 679  CN41182G4V    CN41182G4V  ...  HP EliteDisplay E243           Other
# 702  CN41182G4N    CN41182G4N  ...  HP EliteDisplay E243           Other
#
# [36 rows x 13 columns]

# %%
## VLOOKUP myGenie Request Number   

merge2 = pd.merge(final1, 
                      data4, 
                      on ='Name', 
                      how ='outer')






## VLOOKUP myGenie Request Number  (PC Accessories) 

macc2 = pd.merge(facc1, 
                      acc4, 
                      on ='Name', 
                      how ='outer')




macc2
# Out:
#           Name  ...                       Custodian Email
# 0   5CG123ZCDB  ...      atikah_abuhassan@petronas.com.my
# 1   5CG123ZCBL  ...        hanif_zulkapli@petronas.com.my
# 2   5CG123ZCCM  ...         firdaus.razak@petronas.com.my
# 3   5CG124ZWR5  ...  sergio.fondevillealv@petronas.com.my
# 4   5CG124ZWKV  ...           amira.fauzi@petronas.com.my
# 5   5CG123ZCRB  ...          maziah_manaf@petronas.com.my
# 6   5CG115X1R6  ...         yongken.phoon@petronas.com.my
# 7   5CG123ZCDY  ...         luqman_rahman@petronas.com.my
# 8   5CG124ZV80  ...          erniezanasir@petronas.com.my
# 9   5CG123ZCDD  ...   leonardoramon.lopez@petronas.com.my
# 10  5CG123ZCDG  ...      hassan_abdullahb@petronas.com.my
# 11  5CG123ZCCL  ...          mnizam_ahmad@petronas.com.my
# 12  5CG123ZCRY  ...     megatahmadfaiz.abdaz@petronas.com
# 13  5CG123ZCFL  ...      ankajkumar.sinha@petronas.com.my
# 14  CN41182G5N  ...   ainaathirah.ablatip@petronas.com.my
# 15  CN413039JB  ...         firdaus.razak@petronas.com.my
# 16  CN413039JM  ...          maziah_manaf@petronas.com.my
# 17  CN413039HH  ...          maziah_manaf@petronas.com.my
# 18  CN413039JH  ...        hanif_zulkapli@petronas.com.my
# 19  CN41182G5J  ...           amira.fauzi@petronas.com.my
# 20  CN413039JP  ...   leonardoramon.lopez@petronas.com.my
# 21  CN41182G42  ...         yongken.phoon@petronas.com.my
# 22         NaN  ...         yongken.phoon@petronas.com.my
# 23         NaN  ...       shatilla.zainal@petronas.com.my
# 24  CN413039JT  ...  sergio.fondevillealv@petronas.com.my
# 25   CN41303HR  ...         firdaus.razak@petronas.com.my
# 26  CN413039JL  ...        hanif_zulkapli@petronas.com.my
# 27  CN413039HN  ...          erniezanasir@petronas.com.my
# 28  CN413039JW  ...          erniezanasir@petronas.com.my
# 29  CN41182G5B  ...  sergio.fondevillealv@petronas.com.my
# 30  CN41182G60  ...   leonardoramon.lopez@petronas.com.my
# 31  CN413039J5  ...           amira.fauzi@petronas.com.my
# 32  CN413039J8  ...     anisliyana.zahari@petronas.com.my
# 33  CN413039JD  ...      badariah.bahadon@petronas.com.my
# 34  CN41182G64  ...                emylia@petronas.com.my
# 35  CN41182G4V  ...          mnizam_ahmad@petronas.com.my
# 36  CN41182G4N  ...     megatahmadfaiz.abdaz@petronas.com
#
# [37 rows x 14 columns]

# %%
## Part 1

delivery = outer_join[["Delivery Address","Identifier 2 Value"]]


deli = delivery.rename(columns={'Identifier 2 Value': 'Name'})

deli

merge2 = pd.merge(merge2, 
                      deli, 
                      on ='Name', 
                      how ='outer')



## Part 2

delivery_acc = acc_join[["Delivery Address","Identifier 2 Value"]]


deli_acc = delivery_acc.rename(columns={'Identifier 2 Value': 'Name'})

deli_acc

macc2 = pd.merge(macc2, 
                      deli_acc, 
                      on ='Name', 
                      how ='outer')

# %%
# req = merge2["Category"]

# merge2.insert(loc=7,column = "Type", value = req)

merge2.columns.values[11] = "Short Description"


## Part 2

macc2.columns.values[11] = "Short Description"

# %%
macc2
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG123ZCDB  ...  LEVEL 14, TOWER 2, KLCC, 50088, KUALA LUMPUR, ...
# 1   5CG123ZCBL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 2   5CG123ZCCM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 3   5CG124ZWR5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 4   5CG124ZWKV  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 5   5CG123ZCRB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 6   5CG115X1R6  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 7   5CG123ZCDY  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 8   5CG124ZV80  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 9   5CG123ZCDD  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 10  5CG123ZCDG  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 11  5CG123ZCCL  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 12  5CG123ZCRY  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
# 13  5CG123ZCFL  ...  Level-20, Tower-2, PE SKG, 50088, Kuala Lumpur...
# 14  CN41182G5N  ...  Level 62, Tower 2, PETRONAS Twin Towers, Kuala...
# 15  CN413039JB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 16  CN413039JM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 17  CN413039HH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 18  CN413039JH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 19  CN41182G5J  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 20  CN413039JP  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 21  CN41182G42  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 22         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 23         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 24         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 25         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 26  CN413039JT  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 27   CN41303HR  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 28  CN413039JL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 29  CN413039HN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 30  CN413039JW  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 31  CN41182G5B  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 32  CN41182G60  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 33  CN413039J5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 34  CN413039J8  ...  Level 16, PeTT Tower 1, Bustle : WS 120, 50088...
# 35  CN413039JD  ...  Level 16, Tower 1, PETRONAS Twin Towers, Kuala...
# 36  CN41182G64  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 37  CN41182G4V  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 38  CN41182G4N  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
#
# [39 rows x 15 columns]

# %%
## Part 1
merge3 = merge2[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Capability List","Custodian Email","Custodian Email","Custodian Email","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]

## Part 2
macc3 = macc2[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Capability List","Custodian Email","Custodian Email","Custodian Email","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG123ZCDB  ...  LEVEL 14, TOWER 2, KLCC, 50088, KUALA LUMPUR, ...
# 1   5CG123ZCBL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 2   5CG123ZCCM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 3   5CG124ZWR5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 4   5CG124ZWKV  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 5   5CG123ZCRB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 6   5CG115X1R6  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 7   5CG123ZCDY  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 8   5CG124ZV80  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 9   5CG123ZCDD  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 10  5CG123ZCDG  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 11  5CG123ZCCL  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 12  5CG123ZCRY  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
# 13  5CG123ZCFL  ...  Level-20, Tower-2, PE SKG, 50088, Kuala Lumpur...
# 14  CN41182G5N  ...  Level 62, Tower 2, PETRONAS Twin Towers, Kuala...
# 15  CN413039JB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 16  CN413039JM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 17  CN413039HH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 18  CN413039JH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 19  CN41182G5J  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 20  CN413039JP  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 21  CN41182G42  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 22         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 23         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 24         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 25         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 26  CN413039JT  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 27   CN41303HR  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 28  CN413039JL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 29  CN413039HN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 30  CN413039JW  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 31  CN41182G5B  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 32  CN41182G60  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 33  CN413039J5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 34  CN413039J8  ...  Level 16, PeTT Tower 1, Bustle : WS 120, 50088...
# 35  CN413039JD  ...  Level 16, Tower 1, PETRONAS Twin Towers, Kuala...
# 36  CN41182G64  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 37  CN41182G4V  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 38  CN41182G4N  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
#
# [39 rows x 19 columns]

# %%
## Part 1

merge3.columns.values[10] = "Owned by"
merge3.columns.values[11] = "Owned by (Regional Focal Email)"
merge3.columns.values[12] = "Used by (User Email)"

## Part 2

macc3.columns.values[10] = "Owned by"
macc3.columns.values[11] = "Owned by (Regional Focal Email)"
macc3.columns.values[12] = "Used by (User Email)"
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG123ZCDB  ...  LEVEL 14, TOWER 2, KLCC, 50088, KUALA LUMPUR, ...
# 1   5CG123ZCBL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 2   5CG123ZCCM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 3   5CG124ZWR5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 4   5CG124ZWKV  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 5   5CG123ZCRB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 6   5CG115X1R6  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 7   5CG123ZCDY  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 8   5CG124ZV80  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 9   5CG123ZCDD  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 10  5CG123ZCDG  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 11  5CG123ZCCL  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 12  5CG123ZCRY  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
# 13  5CG123ZCFL  ...  Level-20, Tower-2, PE SKG, 50088, Kuala Lumpur...
# 14  CN41182G5N  ...  Level 62, Tower 2, PETRONAS Twin Towers, Kuala...
# 15  CN413039JB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 16  CN413039JM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 17  CN413039HH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 18  CN413039JH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 19  CN41182G5J  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 20  CN413039JP  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 21  CN41182G42  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 22         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 23         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 24         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 25         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 26  CN413039JT  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 27   CN41303HR  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 28  CN413039JL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 29  CN413039HN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 30  CN413039JW  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 31  CN41182G5B  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 32  CN41182G60  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 33  CN413039J5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 34  CN413039J8  ...  Level 16, PeTT Tower 1, Bustle : WS 120, 50088...
# 35  CN413039JD  ...  Level 16, Tower 1, PETRONAS Twin Towers, Kuala...
# 36  CN41182G64  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 37  CN41182G4V  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 38  CN41182G4N  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
#
# [39 rows x 19 columns]

# %%
## Part 1

merge3['Supported'] = ''



merge3.Supported = 'PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT'     # A single value 'propagates' to all column cells


## Part 2

macc3['Supported'] = ''



macc3.Supported = 'PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT'     # A single value 'propagates' to all column cells
macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#           Name  ...                                Supported
# 0   5CG123ZCDB  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 1   5CG123ZCBL  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 2   5CG123ZCCM  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 3   5CG124ZWR5  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 4   5CG124ZWKV  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 5   5CG123ZCRB  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 6   5CG115X1R6  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 7   5CG123ZCDY  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 8   5CG124ZV80  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 9   5CG123ZCDD  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 10  5CG123ZCDG  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 11  5CG123ZCCL  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 12  5CG123ZCRY  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 13  5CG123ZCFL  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 14  CN41182G5N  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 15  CN413039JB  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 16  CN413039JM  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 17  CN413039HH  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 18  CN413039JH  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 19  CN41182G5J  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 20  CN413039JP  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 21  CN41182G42  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 22         NaN  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 23         NaN  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 24         NaN  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 25         NaN  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 26  CN413039JT  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 27   CN41303HR  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 28  CN413039JL  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 29  CN413039HN  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 30  CN413039JW  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 31  CN41182G5B  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 32  CN41182G60  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 33  CN413039J5  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 34  CN413039J8  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 35  CN413039JD  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 36  CN41182G64  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 37  CN41182G4V  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
# 38  CN41182G4N  ...  PETRONAS ICT->EDX-DM->DEVICE MANAGEMENT
#
# [39 rows x 20 columns]

# %%
## Part 1

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
merge3
# Out:
#            Name  ...                                   Delivery Address
# 0           NaN  ...  PETRONAS Refinery & Petrochemical Corp Sdn Bhd...
# 1           NaN  ...  PETRONAS Refinery & Petrochemical Corp Sdn Bhd...
# 2           NaN  ...  Concourse, Tower 1, PETRONAS Twin Towers, 5008...
# 3           NaN  ...  Concourse, Tower 1, PETRONAS Twin Towers, 5008...
# 4           NaN  ...  Concourse, Tower 1, PETRONAS Twin Tower, 50088...
# ..          ...  ...                                                ...
# 156  CND1330L19  ...  Level 50 Tower 2 KLCC, 50088, Kuala Lumpur, Fe...
# 157  5CD04154Z3  ...  level 72, tower 1 KLCC, 50088, KL, Federal Ter...
# 158  5CD041551W  ...  Quickfix.it Center, PRC Level 4,  Tower 1, PET...
# 159  5CD0415519  ...  Level 70 Tower 2, PETRONAS Twin Towers, 50088,...
# 160  5CD04154Y8  ...  Level 38 Tower 3, PETRONAS Twin Towers, 50088,...
#
# [161 rows x 22 columns]

# %%
## Part 2

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported","PC Model","RAM","Short Description","Item","Capability List","Delivery Address"]]
macc3
# Out:
#           Name  ...                                   Delivery Address
# 0   5CG123ZCDB  ...  LEVEL 14, TOWER 2, KLCC, 50088, KUALA LUMPUR, ...
# 1   5CG123ZCBL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 2   5CG123ZCCM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 3   5CG124ZWR5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 4   5CG124ZWKV  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 5   5CG123ZCRB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 6   5CG115X1R6  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 7   5CG123ZCDY  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 8   5CG124ZV80  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 9   5CG123ZCDD  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 10  5CG123ZCDG  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 11  5CG123ZCCL  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 12  5CG123ZCRY  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
# 13  5CG123ZCFL  ...  Level-20, Tower-2, PE SKG, 50088, Kuala Lumpur...
# 14  CN41182G5N  ...  Level 62, Tower 2, PETRONAS Twin Towers, Kuala...
# 15  CN413039JB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 16  CN413039JM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 17  CN413039HH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 18  CN413039JH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 19  CN41182G5J  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 20  CN413039JP  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 21  CN41182G42  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 22         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 23         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 24         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 25         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 26  CN413039JT  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 27   CN41303HR  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 28  CN413039JL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 29  CN413039HN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 30  CN413039JW  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 31  CN41182G5B  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 32  CN41182G60  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 33  CN413039J5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 34  CN413039J8  ...  Level 16, PeTT Tower 1, Bustle : WS 120, 50088...
# 35  CN413039JD  ...  Level 16, Tower 1, PETRONAS Twin Towers, Kuala...
# 36  CN41182G64  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 37  CN41182G4V  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 38  CN41182G4N  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
#
# [39 rows x 22 columns]

# %%
## Part 1

merge3.columns.values[13] = "Supported by (MyGenie Support Group)"
merge3.columns.values[14] = "Model"
merge3.columns.values[15] = "Total RAM"
merge3.columns.values[19] = "Primary Capability"
merge3.columns.values[21] = "Location"


## Part 2

macc3.columns.values[13] = "Supported by (MyGenie Support Group)"
macc3.columns.values[14] = "Model"
macc3.columns.values[15] = "Total RAM"
macc3.columns.values[19] = "Primary Capability"
macc3.columns.values[21] = "Location"

macc3
# Out:
#           Name  ...                                           Location
# 0   5CG123ZCDB  ...  LEVEL 14, TOWER 2, KLCC, 50088, KUALA LUMPUR, ...
# 1   5CG123ZCBL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 2   5CG123ZCCM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 3   5CG124ZWR5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 4   5CG124ZWKV  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 5   5CG123ZCRB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 6   5CG115X1R6  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 7   5CG123ZCDY  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 8   5CG124ZV80  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 9   5CG123ZCDD  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 10  5CG123ZCDG  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 11  5CG123ZCCL  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 12  5CG123ZCRY  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
# 13  5CG123ZCFL  ...  Level-20, Tower-2, PE SKG, 50088, Kuala Lumpur...
# 14  CN41182G5N  ...  Level 62, Tower 2, PETRONAS Twin Towers, Kuala...
# 15  CN413039JB  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 16  CN413039JM  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 17  CN413039HH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 18  CN413039JH  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 19  CN41182G5J  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 20  CN413039JP  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 21  CN41182G42  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 22         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 23         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 24         NaN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 25         NaN  ...  Petronas Carigali Sdn. Bhd. Sarawak Gas, Malay...
# 26  CN413039JT  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 27   CN41303HR  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 28  CN413039JL  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 29  CN413039HN  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 30  CN413039JW  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 31  CN41182G5B  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 32  CN41182G60  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 33  CN413039J5  ...  LEVEL 20 TOWER 2 PETRONAS TWIN TOWERS, KUALA L...
# 34  CN413039J8  ...  Level 16, PeTT Tower 1, Bustle : WS 120, 50088...
# 35  CN413039JD  ...  Level 16, Tower 1, PETRONAS Twin Towers, Kuala...
# 36  CN41182G64  ...  Level 40, Tower 2, Petronas Twin Tower, 50088 ...
# 37  CN41182G4V  ...        L46 T1, PETT, 50088, Kuala Lumpur, Malaysia
# 38  CN41182G4N  ...  Level 62 Tower 2, PETRONAS Twin Towers, Kuala ...
#
# [39 rows x 22 columns]

# %%
## Part 1 

OPU_column = pd.DataFrame(data1, columns = ["Custodian Email","Identifer 1 Value"])
OPU_column.columns.values[0] = "Owned by"

## Part 2

OPU_acc = pd.DataFrame(acc1, columns = ["Custodian Email","Identifer 1 Value"])
OPU_acc.columns.values[0] = "Owned by"
OPU_acc
# Out:
#                                   Owned by          Identifer 1 Value
# 276      mohammadfahmi.myusof@prefchem.com     PENGERANG RC SDN. BHD.
# 283    rajashaharaputra.ra@petronas.com.my         Petrosains Sdn Bhd
# 313       nurzaimah.razali@petronas.com.my  Petronas Carigali Sdn Bhd
# 314       nurzaimah.razali@petronas.com.my  Petronas Carigali Sdn Bhd
# 493         ashraff.mashal@petronas.com.my  PET Ref & Petchem Corp SB
# ...                                    ...                        ...
# 12984    norshazlina.azlan@petronas.com.my  Petroliam Nasional Berhad
# 12986    norshazlina.azlan@petronas.com.my  Petroliam Nasional Berhad
# 12987     hassan_abdullahb@petronas.com.my  Petroliam Nasional Berhad
# 12988  aiman.shamsuliwardi@petronas.com.my  Petroliam Nasional Berhad
# 12989         edurrah.jani@petronas.com.my  Petroliam Nasional Berhad
#
# [664 rows x 2 columns]

# %%
## Part 1

merge3['Manufacturer'] = ''
merge3['Domain'] = ''
merge3['Region'] = ''
merge3['OPU'] = ''



## Part 2

macc3['Manufacturer'] = ''
macc3['Domain'] = ''
macc3['Region'] = ''
macc3['OPU'] = ''

macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#           Name Serial Number     Hostname  ... Domain Region OPU
# 0   5CG123ZCDB    5CG123ZCDB  H5CG123ZCDB  ...
# 1   5CG123ZCBL    5CG123ZCBL  H5CG123ZCBL  ...
# 2   5CG123ZCCM    5CG123ZCCM  H5CG123ZCCM  ...
# 3   5CG124ZWR5    5CG124ZWR5  H5CG124ZWR5  ...
# 4   5CG124ZWKV    5CG124ZWKV  H5CG124ZWKV  ...
# 5   5CG123ZCRB    5CG123ZCRB  H5CG123ZCRB  ...
# 6   5CG115X1R6    5CG115X1R6  H5CG115X1R6  ...
# 7   5CG123ZCDY    5CG123ZCDY  H5CG123ZCDY  ...
# 8   5CG124ZV80    5CG124ZV80  H5CG124ZV80  ...
# 9   5CG123ZCDD    5CG123ZCDD  H5CG123ZCDD  ...
# 10  5CG123ZCDG    5CG123ZCDG  H5CG123ZCDG  ...
# 11  5CG123ZCCL    5CG123ZCCL  H5CG123ZCCL  ...
# 12  5CG123ZCRY    5CG123ZCRY  H5CG123ZCRY  ...
# 13  5CG123ZCFL    5CG123ZCFL  H5CG123ZCFL  ...
# 14  CN41182G5N    CN41182G5N  HCN41182G5N  ...
# 15  CN413039JB    CN413039JB  HCN413039JB  ...
# 16  CN413039JM    CN413039JM  HCN413039JM  ...
# 17  CN413039HH    CN413039HH  HCN413039HH  ...
# 18  CN413039JH    CN413039JH  HCN413039JH  ...
# 19  CN41182G5J    CN41182G5J  HCN41182G5J  ...
# 20  CN413039JP    CN413039JP  HCN413039JP  ...
# 21  CN41182G42    CN41182G42  HCN41182G42  ...
# 22         NaN           NaN          NaN  ...
# 23         NaN           NaN          NaN  ...
# 24         NaN           NaN          NaN  ...
# 25         NaN           NaN          NaN  ...
# 26  CN413039JT    CN413039JT  HCN413039JT  ...
# 27   CN41303HR     CN41303HR   HCN41303HR  ...
# 28  CN413039JL    CN413039JL  HCN413039JL  ...
# 29  CN413039HN    CN413039HN  HCN413039HN  ...
# 30  CN413039JW    CN413039JW  HCN413039JW  ...
# 31  CN41182G5B    CN41182G5B  HCN41182G5B  ...
# 32  CN41182G60    CN41182G60  HCN41182G60  ...
# 33  CN413039J5    CN413039J5  HCN413039J5  ...
# 34  CN413039J8    CN413039J8  HCN413039J8  ...
# 35  CN413039JD    CN413039JD  HCN413039JD  ...
# 36  CN41182G64    CN41182G64  HCN41182G64  ...
# 37  CN41182G4V    CN41182G4V  HCN41182G4V  ...
# 38  CN41182G4N    CN41182G4N  HCN41182G4N  ...
#
# [39 rows x 26 columns]

# %%
## Part 1

merge3.Manufacturer = 'Hewlett Packard'     # A single value 'propagates' to all column cells

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region"]]


## Part 2

macc3.Manufacturer = 'Hewlett Packard'     # A single value 'propagates' to all column cells

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region"]]
macc3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#           Name  ... Region
# 0   5CG123ZCDB  ...
# 1   5CG123ZCBL  ...
# 2   5CG123ZCCM  ...
# 3   5CG124ZWR5  ...
# 4   5CG124ZWKV  ...
# 5   5CG123ZCRB  ...
# 6   5CG115X1R6  ...
# 7   5CG123ZCDY  ...
# 8   5CG124ZV80  ...
# 9   5CG123ZCDD  ...
# 10  5CG123ZCDG  ...
# 11  5CG123ZCCL  ...
# 12  5CG123ZCRY  ...
# 13  5CG123ZCFL  ...
# 14  CN41182G5N  ...
# 15  CN413039JB  ...
# 16  CN413039JM  ...
# 17  CN413039HH  ...
# 18  CN413039JH  ...
# 19  CN41182G5J  ...
# 20  CN413039JP  ...
# 21  CN41182G42  ...
# 22         NaN  ...
# 23         NaN  ...
# 24         NaN  ...
# 25         NaN  ...
# 26  CN413039JT  ...
# 27   CN41303HR  ...
# 28  CN413039JL  ...
# 29  CN413039HN  ...
# 30  CN413039JW  ...
# 31  CN41182G5B  ...
# 32  CN41182G60  ...
# 33  CN413039J5  ...
# 34  CN413039J8  ...
# 35  CN413039JD  ...
# 36  CN41182G64  ...
# 37  CN41182G4V  ...
# 38  CN41182G4N  ...
#
# [39 rows x 24 columns]

# %%
## Part 1
# Inset OPU Column

merge3 = pd.merge(merge3, 
                      OPU_column, 
                      on ='Owned by', 
                      how ='left')

merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)


merge3
# Out:
#             Name Serial Number  ... Region          Identifer 1 Value
# 0            NaN           NaN  ...         Petroliam Nasional Berhad
# 432          NaN           NaN  ...         Petroliam Nasional Berhad
# 480          NaN           NaN  ...         Petroliam Nasional Berhad
# 528          NaN           NaN  ...         Petroliam Nasional Berhad
# 576   5CD135B45J    5CD135B45J  ...         Petroliam Nasional Berhad
# ...          ...           ...  ...    ...                        ...
# 1079  CND1330L19    CND1330L19  ...         Petronas Carigali Sdn Bhd
# 1080  5CD04154Z3    5CD04154Z3  ...         Petroliam Nasional Berhad
# 1081  5CD041551W    5CD041551W  ...         Petroliam Nasional Berhad
# 1082  5CD0415519    5CD0415519  ...         Petroliam Nasional Berhad
# 1083  5CD04154Y8    5CD04154Y8  ...         Petroliam Nasional Berhad
#
# [80 rows x 25 columns]

# %%
## Part 2
# Inset OPU Column

macc3 = pd.merge(macc3, 
                      OPU_acc, 
                      on ='Owned by', 
                      how ='left')

macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... Region          Identifer 1 Value
# 0   5CG123ZCDB    5CG123ZCDB  ...         Petronas Carigali Sdn Bhd
# 1   5CG123ZCBL    5CG123ZCBL  ...         Petronas Carigali Sdn Bhd
# 4   5CG123ZCCM    5CG123ZCCM  ...         Petronas Carigali Sdn Bhd
# 7   5CG124ZWR5    5CG124ZWR5  ...         Petronas Carigali Sdn Bhd
# 10  5CG124ZWKV    5CG124ZWKV  ...         Petronas Carigali Sdn Bhd
# 13  5CG123ZCRB    5CG123ZCRB  ...         Petronas Carigali Sdn Bhd
# 16  5CG115X1R6    5CG115X1R6  ...         Petronas Carigali Sdn Bhd
# 19  5CG123ZCDY    5CG123ZCDY  ...         Petronas Carigali Sdn Bhd
# 20  5CG124ZV80    5CG124ZV80  ...         Petronas Carigali Sdn Bhd
# 23  5CG123ZCDD    5CG123ZCDD  ...         Petronas Carigali Sdn Bhd
# 26  5CG123ZCDG    5CG123ZCDG  ...         Petroliam Nasional Berhad
# 29  5CG123ZCCL    5CG123ZCCL  ...          Petronas Chemicals Group
# 31  5CG123ZCRY    5CG123ZCRY  ...          PETCO Trading Lbn Co Ltd
# 33  5CG123ZCFL    5CG123ZCFL  ...         Petronas Carigali Sdn Bhd
# 34  CN41182G5N    CN41182G5N  ...          PETCO Trading Lbn Co Ltd
# 62         NaN           NaN  ...         Petroliam Nasional Berhad
# 88  CN413039J8    CN413039J8  ...         Petroliam Nasional Berhad
# 89  CN413039JD    CN413039JD  ...         Petroliam Nasional Berhad
# 90  CN41182G64    CN41182G64  ...         Petroliam Nasional Berhad
#
# [19 rows x 25 columns]

# %%
## Part 1

merge3.columns.values[24] = "OPU"

merge3 = merge3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region","OPU"]]

merge3['Project Number'] = ''
merge3['Project Name'] = ''
merge3['Asset Type'] = ''
merge3['SAP Asset Number'] = ''


## Part 2

macc3.columns.values[24] = "OPU"

macc3 = macc3[["Name","Serial Number","Hostname","Operating System","Status","Status Reason","Category","Type","Item","Owned by","Owned by (Regional Focal Email)","Used by (User Email)","Supported by (MyGenie Support Group)","Model","Manufacturer","Total RAM","Short Description","Domain","Primary Capability","Location","Region","OPU"]]

macc3['Project Number'] = ''
macc3['Project Name'] = ''
macc3['Asset Type'] = ''
macc3['SAP Asset Number'] = ''

macc3
# Out:
#           Name Serial Number  ... Asset Type SAP Asset Number
# 0   5CG123ZCDB    5CG123ZCDB  ...
# 1   5CG123ZCBL    5CG123ZCBL  ...
# 4   5CG123ZCCM    5CG123ZCCM  ...
# 7   5CG124ZWR5    5CG124ZWR5  ...
# 10  5CG124ZWKV    5CG124ZWKV  ...
# 13  5CG123ZCRB    5CG123ZCRB  ...
# 16  5CG115X1R6    5CG115X1R6  ...
# 19  5CG123ZCDY    5CG123ZCDY  ...
# 20  5CG124ZV80    5CG124ZV80  ...
# 23  5CG123ZCDD    5CG123ZCDD  ...
# 26  5CG123ZCDG    5CG123ZCDG  ...
# 29  5CG123ZCCL    5CG123ZCCL  ...
# 31  5CG123ZCRY    5CG123ZCRY  ...
# 33  5CG123ZCFL    5CG123ZCFL  ...
# 34  CN41182G5N    CN41182G5N  ...
# 62         NaN           NaN  ...
# 88  CN413039J8    CN413039J8  ...
# 89  CN413039JD    CN413039JD  ...
# 90  CN41182G64    CN41182G64  ...
#
# [19 rows x 29 columns]

# %%
## Part 1

ict2u_column = pd.DataFrame(data1, columns = ["Custodian Email","Order Item Number"])

ict2u_column.columns.values[1] = "ICT2U Order Number"
ict2u_column.columns.values[0] = "Owned by"


## Part 2

ict2u_acc = pd.DataFrame(acc1, columns = ["Custodian Email","Order Item Number"])

ict2u_acc.columns.values[1] = "ICT2U Order Number"
ict2u_acc.columns.values[0] = "Owned by"

ict2u_acc
# Out:
#                                   Owned by  ICT2U Order Number
# 276      mohammadfahmi.myusof@prefchem.com             2488220
# 283    rajashaharaputra.ra@petronas.com.my             2488520
# 313       nurzaimah.razali@petronas.com.my             2488369
# 314       nurzaimah.razali@petronas.com.my             2488370
# 493         ashraff.mashal@petronas.com.my             2504550
# ...                                    ...                 ...
# 12984    norshazlina.azlan@petronas.com.my             2680972
# 12986    norshazlina.azlan@petronas.com.my             2680983
# 12987     hassan_abdullahb@petronas.com.my             2680982
# 12988  aiman.shamsuliwardi@petronas.com.my             2680981
# 12989         edurrah.jani@petronas.com.my             2680984
#
# [664 rows x 2 columns]

# %%
## Part 1
# Inset Order Number Column

merge3 = pd.merge(merge3, 
                      ict2u_column, 
                      on ='Owned by', 
                      how ='inner')

merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)


merge3
# Out:
#            Name Serial Number  ... SAP Asset Number ICT2U Order Number
# 0           NaN           NaN  ...                             2652687
# 27          NaN           NaN  ...                             2465934
# 30          NaN           NaN  ...                             2483252
# 33          NaN           NaN  ...                             2483267
# 36   5CD135B45J    5CD135B45J  ...                             2683619
# ..          ...           ...  ...              ...                ...
# 147  CND1330L19    CND1330L19  ...                             2683030
# 148  5CD04154Z3    5CD04154Z3  ...                             2684634
# 149  5CD041551W    5CD041551W  ...                             2685093
# 150  5CD0415519    5CD0415519  ...                             2718042
# 151  5CD04154Y8    5CD04154Y8  ...                             2718648
#
# [80 rows x 30 columns]

# %%
## Part 2
# Inset Order Number Column

macc3 = pd.merge(macc3, 
                      ict2u_acc, 
                      on ='Owned by', 
                      how ='inner')

macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... SAP Asset Number ICT2U Order Number
# 0   5CG123ZCDB    5CG123ZCDB  ...                             2683748
# 1   5CG123ZCBL    5CG123ZCBL  ...                             2684153
# 4   5CG123ZCCM    5CG123ZCCM  ...                             2684161
# 7   5CG124ZWR5    5CG124ZWR5  ...                             2684170
# 10  5CG124ZWKV    5CG124ZWKV  ...                             2684169
# 13  5CG123ZCRB    5CG123ZCRB  ...                             2684166
# 16  5CG115X1R6    5CG115X1R6  ...                             2684156
# 19  5CG123ZCDY    5CG123ZCDY  ...                             2684157
# 20  5CG124ZV80    5CG124ZV80  ...                             2684155
# 23  5CG123ZCDD    5CG123ZCDD  ...                             2684164
# 26  5CG123ZCDG    5CG123ZCDG  ...                             2684882
# 29  5CG123ZCCL    5CG123ZCCL  ...                             2694407
# 31  5CG123ZCRY    5CG123ZCRY  ...                             2716398
# 33  5CG123ZCFL    5CG123ZCFL  ...                             2711209
# 34  CN41182G5N    CN41182G5N  ...                             2683490
# 35         NaN           NaN  ...                             2685412
# 36  CN413039J8    CN413039J8  ...                             2684440
# 37  CN413039JD    CN413039JD  ...                             2684461
# 38  CN41182G64    CN41182G64  ...                             2684881
#
# [19 rows x 30 columns]

# %%
## Part 1

mygenie_column = pd.DataFrame(data1, columns = ["Custodian Email","myGenie Request Number"])

mygenie_column.columns.values[0] = "Owned by"


## Part 2

mygenie_acc = pd.DataFrame(acc1, columns = ["Custodian Email","myGenie Request Number"])

mygenie_acc.columns.values[0] = "Owned by"
mygenie_acc
# Out:
#                                   Owned by myGenie Request Number
# 276      mohammadfahmi.myusof@prefchem.com        REQ000003546242
# 283    rajashaharaputra.ra@petronas.com.my        REQ000003540877
# 313       nurzaimah.razali@petronas.com.my        REQ000003550044
# 314       nurzaimah.razali@petronas.com.my        REQ000003550045
# 493         ashraff.mashal@petronas.com.my        REQ000003566374
# ...                                    ...                    ...
# 12984    norshazlina.azlan@petronas.com.my        REQ000004019650
# 12986    norshazlina.azlan@petronas.com.my        REQ000004019648
# 12987     hassan_abdullahb@petronas.com.my        REQ000004019737
# 12988  aiman.shamsuliwardi@petronas.com.my        REQ000004019504
# 12989         edurrah.jani@petronas.com.my        REQ000004019649
#
# [664 rows x 2 columns]

# %%
## Part 1
# Inset ICT2U Column

merge3 = pd.merge(merge3, 
                      mygenie_column, 
                      on ='Owned by', 
                      how ='inner')


merge3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

merge3
# Out:
#            Name Serial Number  ... ICT2U Order Number myGenie Request Number
# 0           NaN           NaN  ...            2652687        REQ000003858912
# 27          NaN           NaN  ...            2465934        REQ000003513343
# 30          NaN           NaN  ...            2483252        REQ000003513345
# 33          NaN           NaN  ...            2483267        REQ000003513348
# 36   5CD135B45J    5CD135B45J  ...            2683619        REQ000004040861
# ..          ...           ...  ...                ...                    ...
# 147  CND1330L19    CND1330L19  ...            2683030        REQ000004040371
# 148  5CD04154Z3    5CD04154Z3  ...            2684634        REQ000004049145
# 149  5CD041551W    5CD041551W  ...            2685093        REQ000004053846
# 150  5CD0415519    5CD0415519  ...            2718042        REQ000004065875
# 151  5CD04154Y8    5CD04154Y8  ...            2718648        REQ000004074202
#
# [80 rows x 31 columns]

# %%
## Part 2
# Inset ICT2U Column

macc3 = pd.merge(macc3, 
                      mygenie_acc, 
                      on ='Owned by', 
                      how ='inner')


macc3.drop_duplicates(subset ="Owned by",
                     keep = 'first', inplace = True)

macc3
# Out:
#           Name Serial Number  ... ICT2U Order Number myGenie Request Number
# 0   5CG123ZCDB    5CG123ZCDB  ...            2683748        REQ000004040520
# 1   5CG123ZCBL    5CG123ZCBL  ...            2684153        REQ000004044807
# 4   5CG123ZCCM    5CG123ZCCM  ...            2684161        REQ000004045318
# 7   5CG124ZWR5    5CG124ZWR5  ...            2684170        REQ000004044812
# 10  5CG124ZWKV    5CG124ZWKV  ...            2684169        REQ000004045142
# 13  5CG123ZCRB    5CG123ZCRB  ...            2684166        REQ000004045140
# 16  5CG115X1R6    5CG115X1R6  ...            2684156        REQ000004045095
# 19  5CG123ZCDY    5CG123ZCDY  ...            2684157        REQ000004045015
# 20  5CG124ZV80    5CG124ZV80  ...            2684155        REQ000004044810
# 23  5CG123ZCDD    5CG123ZCDD  ...            2684164        REQ000004045137
# 26  5CG123ZCDG    5CG123ZCDG  ...            2684882        REQ000004051997
# 29  5CG123ZCCL    5CG123ZCCL  ...            2694407        REQ000004058764
# 31  5CG123ZCRY    5CG123ZCRY  ...            2716398        REQ000004063730
# 33  5CG123ZCFL    5CG123ZCFL  ...            2711209        REQ000004062045
# 34  CN41182G5N    CN41182G5N  ...            2683490        REQ000004038654
# 35         NaN           NaN  ...            2685412        REQ000004055470
# 36  CN413039J8    CN413039J8  ...            2684440        REQ000004046391
# 37  CN413039JD    CN413039JD  ...            2684461        REQ000004048120
# 38  CN41182G64    CN41182G64  ...            2684881        REQ000004051999
#
# [19 rows x 31 columns]

# %%
## Part 1

merge3['Vendor Schedule Number (EOL)'] = ''
merge3['Lessor Returned Verification (EOL)'] = ''
merge3['Return Batch Number (EOL)'] = ''
merge3['Return Item Number (EOL)'] = ''
merge3['Return Date To Lessor (EOL)'] = ''
merge3['Return Date By User (EOL)'] = ''


## Part 2

macc3['Vendor Schedule Number (EOL)'] = ''
macc3['Lessor Returned Verification (EOL)'] = ''
macc3['Return Batch Number (EOL)'] = ''
macc3['Return Item Number (EOL)'] = ''
macc3['Return Date To Lessor (EOL)'] = ''
macc3['Return Date By User (EOL)'] = ''
macc3
# Out:
#           Name  ... Return Date By User (EOL)
# 0   5CG123ZCDB  ...
# 1   5CG123ZCBL  ...
# 4   5CG123ZCCM  ...
# 7   5CG124ZWR5  ...
# 10  5CG124ZWKV  ...
# 13  5CG123ZCRB  ...
# 16  5CG115X1R6  ...
# 19  5CG123ZCDY  ...
# 20  5CG124ZV80  ...
# 23  5CG123ZCDD  ...
# 26  5CG123ZCDG  ...
# 29  5CG123ZCCL  ...
# 31  5CG123ZCRY  ...
# 33  5CG123ZCFL  ...
# 34  CN41182G5N  ...
# 35         NaN  ...
# 36  CN413039J8  ...
# 37  CN413039JD  ...
# 38  CN41182G64  ...
#
# [19 rows x 37 columns]

# %%
# header_row = 2

# data6.columns = data6.iloc[header_row]


# date_column1 = pd.DataFrame(data6, columns = ["SR Number","Submit Date"])

# date_column1.dropna(subset = ["SR Number"], inplace=True)

# date_column1 = date_column1.drop([0,2])

# date_column1.columns.values[1] = "Contract Start Date"
# date_column1.columns.values[0] = "myGenie Request Number"



# date_column1
# genie

# %%
# merge3 = pd.merge(merge3, 
#                       genie, 
#                       on ='myGenie Request Number', 
#                       how ='inner')

# %%
# # Inset Date columns

# genie = pd.DataFrame(data1,columns= ['myGenie Request Number'] )

# merge3 = pd.merge(merge3, 
#                       genie, 
#                       on ='myGenie Request Number', 
#                       how ='inner')


# merge3

# %%
## Part 1

merge6 = pd.DataFrame(data6, columns= ['DAAS (Desktop as a Service) Report – V2','Unnamed: 7'])

merge6.columns = merge6.iloc[2] 

merge6 = merge6[0:]

# %%
## Part 2

macc6 = pd.DataFrame(acc6, columns= ['DAAS (Desktop as a Service) Report – V2','Unnamed: 7'])

macc6.columns = macc6.iloc[2] 

macc6 = macc6[0:]

macc6
# Out:
# 2                       SR Number      Completion Date
# 0      Service Request Management                  NaN
# 1                             NaN                  NaN
# 2                       SR Number      Completion Date
# 3                 REQ000002513479                  NaN
# 4                 REQ000002889971  2021-01-11 14:26:03
# ...                           ...                  ...
# 59047             REQ000004088045  2021-11-19 15:04:34
# 59048             REQ000004088258  2021-11-19 16:02:55
# 59049             REQ000004088173  2021-11-19 16:02:54
# 59050             REQ000004088736  2021-11-19 17:42:45
# 59051             REQ000004088670  2021-11-19 18:03:07
#
# [59052 rows x 2 columns]

# %%
# Drop rows (Part 1)

merge6 = merge6.drop([merge6.index[0], merge6.index[1],merge6.index[2]])




# Drop rows (Part 2)

macc6 = macc6.drop([macc6.index[0], macc6.index[1],macc6.index[2]])
macc6
# Out:
# 2            SR Number      Completion Date
# 3      REQ000002513479                  NaN
# 4      REQ000002889971  2021-01-11 14:26:03
# 5      REQ000002889971  2021-01-11 14:26:03
# 6      REQ000002889971  2021-01-11 14:26:03
# 7      REQ000002889971  2021-01-11 14:26:03
# ...                ...                  ...
# 59047  REQ000004088045  2021-11-19 15:04:34
# 59048  REQ000004088258  2021-11-19 16:02:55
# 59049  REQ000004088173  2021-11-19 16:02:54
# 59050  REQ000004088736  2021-11-19 17:42:45
# 59051  REQ000004088670  2021-11-19 18:03:07
#
# [59049 rows x 2 columns]

# %%
## Rename column[0] as myGenie Request Number (Part 1)

merge6.columns.values[0] = "myGenie Request Number"


## Rename column[0] as myGenie Request Number (Part 2)

macc6.columns.values[0] = "myGenie Request Number"
macc6
# Out:
# 2     myGenie Request Number      Completion Date
# 3            REQ000002513479                  NaN
# 4            REQ000002889971  2021-01-11 14:26:03
# 5            REQ000002889971  2021-01-11 14:26:03
# 6            REQ000002889971  2021-01-11 14:26:03
# 7            REQ000002889971  2021-01-11 14:26:03
# ...                      ...                  ...
# 59047        REQ000004088045  2021-11-19 15:04:34
# 59048        REQ000004088258  2021-11-19 16:02:55
# 59049        REQ000004088173  2021-11-19 16:02:54
# 59050        REQ000004088736  2021-11-19 17:42:45
# 59051        REQ000004088670  2021-11-19 18:03:07
#
# [59049 rows x 2 columns]

# %%
## convert datetime column to only date (Part 1)

merge6['Completion Date1'] = pd.to_datetime(merge6['Completion Date']).dt.date
  


## convert datetime column to only date (Part 2)

macc6['Completion Date1'] = pd.to_datetime(macc6['Completion Date']).dt.date
macc6
# Out:
# 2     myGenie Request Number      Completion Date Completion Date1
# 3            REQ000002513479                  NaN              NaT
# 4            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 5            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 6            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 7            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# ...                      ...                  ...              ...
# 59047        REQ000004088045  2021-11-19 15:04:34       2021-11-19
# 59048        REQ000004088258  2021-11-19 16:02:55       2021-11-19
# 59049        REQ000004088173  2021-11-19 16:02:54       2021-11-19
# 59050        REQ000004088736  2021-11-19 17:42:45       2021-11-19
# 59051        REQ000004088670  2021-11-19 18:03:07       2021-11-19
#
# [59049 rows x 3 columns]

# %%
## Part 1
## Drop duplicates in myGenie Request Number column

merge6.drop_duplicates(subset = "myGenie Request Number", keep = 'first', inplace = True )


## Drop COmpletion Date column

merge6.drop(['Completion Date'], axis = 1)


## Part 2
## Drop duplicates in myGenie Request Number column

macc6.drop_duplicates(subset = "myGenie Request Number", keep = 'first', inplace = True )


## Drop COmpletion Date column

macc6.drop(['Completion Date'], axis = 1)
macc6
# Out:
# 2     myGenie Request Number      Completion Date Completion Date1
# 3            REQ000002513479                  NaN              NaT
# 4            REQ000002889971  2021-01-11 14:26:03       2021-01-11
# 8            REQ000002945934  2021-02-04 18:41:41       2021-02-04
# 12           REQ000002953496                  NaN              NaT
# 14           REQ000002969398                  NaN              NaT
# ...                      ...                  ...              ...
# 59047        REQ000004088045  2021-11-19 15:04:34       2021-11-19
# 59048        REQ000004088258  2021-11-19 16:02:55       2021-11-19
# 59049        REQ000004088173  2021-11-19 16:02:54       2021-11-19
# 59050        REQ000004088736  2021-11-19 17:42:45       2021-11-19
# 59051        REQ000004088670  2021-11-19 18:03:07       2021-11-19
#
# [24149 rows x 3 columns]

# %%
# Part 1
# Fill Operating system column

merge3.loc[:,'Operating System'] = 'Windows 10'


# Fill Status Reason column with N/A

merge3.loc[:,'Status Reason'] = 'N/A'

# Fill Domain column with PETRONAS.PETRONET.DIR

merge3.loc[:,'Domain'] = 'PETRONAS.PETRONET.DIR'

# Fill Asset Type column with Leasing

merge3.loc[:,'Asset Type'] = 'Leasing'

# Fill Project Number column with N/A

merge3.loc[:,'Project Number'] = 'N/A'

# Fill Project Name column with N/A

merge3.loc[:,'Project Name'] = 'N/A'

# Fill SAP Asset Number column with N/A

merge3.loc[:,'SAP Asset Number'] = 'N/A'





# Part 2
# Fill Operating system column

macc3.loc[:,'Operating System'] = 'Windows 10'


# Fill Status Reason column with N/A

macc3.loc[:,'Status Reason'] = 'N/A'

# Fill Domain column with PETRONAS.PETRONET.DIR

macc3.loc[:,'Domain'] = 'PETRONAS.PETRONET.DIR'

# Fill Asset Type column with Leasing

macc3.loc[:,'Asset Type'] = 'Leasing'

# Fill Project Number column with N/A

macc3.loc[:,'Project Number'] = 'N/A'

# Fill Project Name column with N/A

macc3.loc[:,'Project Name'] = 'N/A'

# Fill SAP Asset Number column with N/A

macc3.loc[:,'SAP Asset Number'] = 'N/A'

# %%
## Drop Completion Date column (Part 1)

merge6 = merge6.drop(['Completion Date'], axis = 1)


## Drop Completion Date column (Part 2)

macc6 = macc6.drop(['Completion Date'], axis = 1)
macc6
# Out:
# 2     myGenie Request Number Completion Date1
# 3            REQ000002513479              NaT
# 4            REQ000002889971       2021-01-11
# 8            REQ000002945934       2021-02-04
# 12           REQ000002953496              NaT
# 14           REQ000002969398              NaT
# ...                      ...              ...
# 59047        REQ000004088045       2021-11-19
# 59048        REQ000004088258       2021-11-19
# 59049        REQ000004088173       2021-11-19
# 59050        REQ000004088736       2021-11-19
# 59051        REQ000004088670       2021-11-19
#
# [24149 rows x 2 columns]

# %%
# Create End of warranty date (Completion Date1 + 3 years) - Part 1

merge6["ContendDate"] = merge6['Completion Date1'] + pd.offsets.DateOffset(years=3)


# Create End of warranty date (Completion Date1 + 3 years) - Part 2

macc6["ContendDate"] = macc6['Completion Date1'] + pd.offsets.DateOffset(years=3)
macc6
# Out:
# 2     myGenie Request Number Completion Date1 ContendDate
# 3            REQ000002513479              NaT         NaT
# 4            REQ000002889971       2021-01-11  2024-01-11
# 8            REQ000002945934       2021-02-04  2024-02-04
# 12           REQ000002953496              NaT         NaT
# 14           REQ000002969398              NaT         NaT
# ...                      ...              ...         ...
# 59047        REQ000004088045       2021-11-19  2024-11-19
# 59048        REQ000004088258       2021-11-19  2024-11-19
# 59049        REQ000004088173       2021-11-19  2024-11-19
# 59050        REQ000004088736       2021-11-19  2024-11-19
# 59051        REQ000004088670       2021-11-19  2024-11-19
#
# [24149 rows x 3 columns]

# %%
## Create Warranty Start, Warranty end, Status and Registered date columns - Part 1

merge6["Warranty Start"] = merge6["Completion Date1"]
merge6["Warranty End"] = merge6["ContendDate"]
merge6["STATUS"] = "Requested to Register in  CMDB"
merge6["REGISTERED DATE"] = ''



## Create Warranty Start, Warranty end, Status and Registered date columns - Part 2

macc6["Warranty Start"] = macc6["Completion Date1"]
macc6["Warranty End"] = macc6["ContendDate"]
macc6["STATUS"] = "Requested to Register in  CMDB"
macc6["REGISTERED DATE"] = ''
macc6
# Out:
# 2     myGenie Request Number  ... REGISTERED DATE
# 3            REQ000002513479  ...
# 4            REQ000002889971  ...
# 8            REQ000002945934  ...
# 12           REQ000002953496  ...
# 14           REQ000002969398  ...
# ...                      ...  ...             ...
# 59047        REQ000004088045  ...
# 59048        REQ000004088258  ...
# 59049        REQ000004088173  ...
# 59050        REQ000004088736  ...
# 59051        REQ000004088670  ...
#
# [24149 rows x 7 columns]

# %%
# # Inset Date columns - Part 1

merge6 = pd.merge(merge3, 
                      merge6, 
                      on ='myGenie Request Number', 
                      how ='inner')

merge6
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0          NaN           NaN  ...  Requested to Register in  CMDB
# 1          NaN           NaN  ...  Requested to Register in  CMDB
# 2          NaN           NaN  ...  Requested to Register in  CMDB
# 3          NaN           NaN  ...  Requested to Register in  CMDB
# 4   5CD135B45J    5CD135B45J  ...  Requested to Register in  CMDB
# ..         ...           ...  ...                             ...             ...
# 75  CND1330L19    CND1330L19  ...  Requested to Register in  CMDB
# 76  5CD04154Z3    5CD04154Z3  ...  Requested to Register in  CMDB
# 77  5CD041551W    5CD041551W  ...  Requested to Register in  CMDB
# 78  5CD0415519    5CD0415519  ...  Requested to Register in  CMDB
# 79  5CD04154Y8    5CD04154Y8  ...  Requested to Register in  CMDB
#
# [80 rows x 43 columns]

# %%
# # Inset Date columns - Part 2

macc6 = pd.merge(macc3, 
                      macc6, 
                      on ='myGenie Request Number', 
                      how ='inner')

macc6
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCRY    5CG123ZCRY  ...  Requested to Register in  CMDB
# 13  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 14  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 15         NaN           NaN  ...  Requested to Register in  CMDB
# 16  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 17  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 18  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [19 rows x 43 columns]

# %%
# Change owned by column with names and certifier - Part 1

data7 = pd.DataFrame(data7,columns= ["Full Name","Internet E-mail"] )
data7["Owned by"] = data7["Internet E-mail"]


# Change owned by column with names and certifier - Part 2

acc7 = pd.DataFrame(acc7,columns= ["Full Name","Internet E-mail"] )
acc7["Owned by"] = acc7["Internet E-mail"]
acc7
# Out:
#                                    Full Name  ...                         Owned by
# 0                          AP FS2 (FNA/PETH)  ...           ap.fs2@petronas.com.my
# 1      DFP Technical Helpdesk (TECH_OPE/DFP)  ...             technical@dfp.com.my
# 2                        FSDAP 005 (SDD/PDB)  ...         fsdap005@petronas.com.my
# 3                         FSDAP001 (FSD/PDB)  ...         fsdap001@petronas.com.my
# 4                         FSDAP002 (FSD/PDB)  ...         fsdap002@petronas.com.my
# ...                                      ...  ...                              ...
# 89020          Zuraida M Zabidi (LEGAL/PETH)  ...  zuraida.mzabidi@petronas.com.my
# 89021     Zuraidah Bt Hassan (USCA/Upstream)  ...           zuraih@petronas.com.my
# 89022        Zuraina Tamrin (OPERATION/PRPC)  ...   zuraina.tamrin@petronas.com.my
# 89023       Zuraina Tamrin (OPERATIONS/PRPC)  ...    zuraina.tamri@petronas.com.my
# 89024                                    NaN  ...                              NaN
#
# [89025 rows x 3 columns]

# %%
# # Inset Owner Name column - Part 1

merge7 = pd.merge(merge6, 
                      data7, 
                      on ='Owned by', 
                      how ='inner')

merge7
# Out:
#           Name  ...                       Internet E-mail
# 0          NaN  ...        nabilla.khisha@petronas.com.my
# 1          NaN  ...  mohamadfadhilha.azma@petronas.com.my
# 2          NaN  ...               zainurm@petronas.com.my
# 3          NaN  ...           mok.wenting@petronas.com.my
# 4   5CD135B45J  ...   shahriman_johannoor@petronas.com.my
# ..         ...  ...                                   ...
# 71  CND1330L19  ...   ahmadazizul.ahmadna@petronas.com.my
# 72  5CD04154Z3  ...        marylene_chung@petronas.com.my
# 73  5CD041551W  ...         intan_nooreen@petronas.com.my
# 74  5CD0415519  ...    thaya.balakrishnan@petronas.com.my
# 75  5CD04154Y8  ...                 rizal@petronas.com.my
#
# [76 rows x 45 columns]

# %%
# # Inset Owner Name column - Part 2

macc7 = pd.merge(macc6, 
                      acc7, 
                      on ='Owned by', 
                      how ='inner')

macc7
# Out:
#           Name  ...                       Internet E-mail
# 0   5CG123ZCDB  ...      atikah_abuhassan@petronas.com.my
# 1   5CG123ZCBL  ...        hanif_zulkapli@petronas.com.my
# 2   5CG123ZCCM  ...         firdaus.razak@petronas.com.my
# 3   5CG124ZWR5  ...  sergio.fondevillealv@petronas.com.my
# 4   5CG124ZWKV  ...           amira.fauzi@petronas.com.my
# 5   5CG123ZCRB  ...          maziah_manaf@petronas.com.my
# 6   5CG115X1R6  ...         yongken.phoon@petronas.com.my
# 7   5CG123ZCDY  ...         luqman_rahman@petronas.com.my
# 8   5CG124ZV80  ...          erniezanasir@petronas.com.my
# 9   5CG123ZCDD  ...   leonardoramon.lopez@petronas.com.my
# 10  5CG123ZCDG  ...      hassan_abdullahb@petronas.com.my
# 11  5CG123ZCCL  ...          mnizam_ahmad@petronas.com.my
# 12  5CG123ZCFL  ...      ankajkumar.sinha@petronas.com.my
# 13  CN41182G5N  ...   ainaathirah.ablatip@petronas.com.my
# 14         NaN  ...       shatilla.zainal@petronas.com.my
# 15  CN413039J8  ...     anisliyana.zahari@petronas.com.my
# 16  CN413039JD  ...      badariah.bahadon@petronas.com.my
# 17  CN41182G64  ...                emylia@petronas.com.my
#
# [18 rows x 45 columns]

# %%
## Part 1
merge7 = merge7.drop(['Internet E-mail'], axis = 1)

merge7
# Out:
#           Name  ...                                          Full Name
# 0          NaN  ...                         Nabilla Khisham (HRM/PETH)
# 1          NaN  ...                   M Fadhil Hanafi Azman (GFC/PETH)
# 2          NaN  ...          Sy Zainuddin B Sy A Rahman (MPM/Upstream)
# 3          NaN  ...                        Mok Wen Ting (HRM/Upstream)
# 4   5CD135B45J  ...                Shahriman B Johan Noor (LEGAL/PETH)
# ..         ...  ...                                                ...
# 71  CND1330L19  ...           Ahmad Azizul Ahmad Nazari (COE/Upstream)
# 72  5CD04154Z3  ...                  Marylene Chung Jen Nie (GSC/PETH)
# 73  5CD041551W  ...       Intan Nooreen Zairaniee Bt A Rahman (SC/GNE)
# 74  5CD0415519  ...  Thayananthan Balakrishnan (VP_DOWNSTREAM_OPS/P...
# 75  5CD04154Y8  ...                        M Rizal B Saluki (GPD/PD&T)
#
# [76 rows x 44 columns]

# %%
## Part 2
macc7 = macc7.drop(['Internet E-mail'], axis = 1)
macc7
# Out:
#           Name  ...                                          Full Name
# 0   5CG123ZCDB  ...              Atikah Bt Abu Hassan A (Exp/Upstream)
# 1   5CG123ZCBL  ...                  M Hanif B Zulkapli (SSO/Upstream)
# 2   5CG123ZCCM  ...                 M Firdaus B A Razak (COE/Upstream)
# 3   5CG124ZWR5  ...           Sergio Fondeville Alvarez (COE/Upstream)
# 4   5CG124ZWKV  ...           Noor 'Aliaa Amira M Fauzi (COE/Upstream)
# 5   5CG123ZCRB  ...                   Maziah Bt A Manaf (COE/Upstream)
# 6   5CG115X1R6  ...                      Phoon Yong Ken (COE/Upstream)
# 7   5CG123ZCDY  ...                   Luqman B A Rahman (COE/Upstream)
# 8   5CG124ZV80  ...                    Ernieza Bt Nasir (COE/Upstream)
# 9   5CG123ZCDD  ...      Leonardo Ramon Lopez Gutierrez (COE/Upstream)
# 10  5CG123ZCDG  ...                          Hassan Abdullah (GP/PD&T)
# 11  5CG123ZCCL  ...                        M Nizam Bin Ahmad (IS/PCGB)
# 12  5CG123ZCFL  ...                   Ankaj Kumar Sinha (COE/Upstream)
# 13  CN41182G5N  ...                              Aina Athirah Ab Latip
# 14         NaN  ...  Siti Nurul Shatilla Zainal  Shaharuddin (SKG/U...
# 15  CN413039J8  ...                       Anis Liyana Zahari (GP/PETH)
# 16  CN413039JD  ...                      Norbadariah Bahadon (GP/PETH)
# 17  CN41182G64  ...                     Emylia Bt A Ghafar (GCEM/PETH)
#
# [18 rows x 44 columns]

# %%
## Fill up Owned by column with Full name column data - Part 1

merge7["Owned by"] = merge7["Full Name"]


## Fill up Owned by column with Full name column data - Part 2

macc7["Owned by"] = macc7["Full Name"]
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name  ...                                          Full Name
# 0   5CG123ZCDB  ...              Atikah Bt Abu Hassan A (Exp/Upstream)
# 1   5CG123ZCBL  ...                  M Hanif B Zulkapli (SSO/Upstream)
# 2   5CG123ZCCM  ...                 M Firdaus B A Razak (COE/Upstream)
# 3   5CG124ZWR5  ...           Sergio Fondeville Alvarez (COE/Upstream)
# 4   5CG124ZWKV  ...           Noor 'Aliaa Amira M Fauzi (COE/Upstream)
# 5   5CG123ZCRB  ...                   Maziah Bt A Manaf (COE/Upstream)
# 6   5CG115X1R6  ...                      Phoon Yong Ken (COE/Upstream)
# 7   5CG123ZCDY  ...                   Luqman B A Rahman (COE/Upstream)
# 8   5CG124ZV80  ...                    Ernieza Bt Nasir (COE/Upstream)
# 9   5CG123ZCDD  ...      Leonardo Ramon Lopez Gutierrez (COE/Upstream)
# 10  5CG123ZCDG  ...                          Hassan Abdullah (GP/PD&T)
# 11  5CG123ZCCL  ...                        M Nizam Bin Ahmad (IS/PCGB)
# 12  5CG123ZCFL  ...                   Ankaj Kumar Sinha (COE/Upstream)
# 13  CN41182G5N  ...                              Aina Athirah Ab Latip
# 14         NaN  ...  Siti Nurul Shatilla Zainal  Shaharuddin (SKG/U...
# 15  CN413039J8  ...                       Anis Liyana Zahari (GP/PETH)
# 16  CN413039JD  ...                      Norbadariah Bahadon (GP/PETH)
# 17  CN41182G64  ...                     Emylia Bt A Ghafar (GCEM/PETH)
#
# [18 rows x 44 columns]

# %%
## Drop Full name column - Part 1

merge7 = merge7.drop(['Full Name'], axis = 1)


## Drop Full name column - Part 2

macc7 = macc7.drop(['Full Name'], axis = 1)
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 43 columns]

# %%
# Extract states from address - Part 1

States = ['Kuala Lumpur','KL','Petronas Twin Towers','PETRONAS Twin Towers','Selangor','Terengganu','Johor','Melaka','Perlis','Kedah','Perak','Negeri Sembilan','Sarawak','Sabah','Kelantan','Pahang', 'Pulau Pinang']
pat = '|'.join(r"\b{}\b".format(x) for x in States)

merge7['States1'] = merge7['Location'].str.extract('('+ pat + ')', expand=False, flags=re.I)



# Extract states from address - Part 2

States = ['Kuala Lumpur','KL','Petronas Twin Towers','PETRONAS Twin Towers','Selangor','Terengganu','Johor','Melaka','Perlis','Kedah','Perak','Negeri Sembilan','Sarawak','Sabah','Kelantan','Pahang', 'Pulau Pinang']
pat = '|'.join(r"\b{}\b".format(x) for x in States)

macc7['States1'] = macc7['Location'].str.extract('('+ pat + ')', expand=False, flags=re.I)
macc7
# Out:
#           Name Serial Number  ... REGISTERED DATE               States1
# 0   5CG123ZCDB    5CG123ZCDB  ...                          KUALA LUMPUR
# 1   5CG123ZCBL    5CG123ZCBL  ...                  PETRONAS TWIN TOWERS
# 2   5CG123ZCCM    5CG123ZCCM  ...                  PETRONAS TWIN TOWERS
# 3   5CG124ZWR5    5CG124ZWR5  ...                  PETRONAS TWIN TOWERS
# 4   5CG124ZWKV    5CG124ZWKV  ...                  PETRONAS TWIN TOWERS
# 5   5CG123ZCRB    5CG123ZCRB  ...                  PETRONAS TWIN TOWERS
# 6   5CG115X1R6    5CG115X1R6  ...                  PETRONAS TWIN TOWERS
# 7   5CG123ZCDY    5CG123ZCDY  ...                  PETRONAS TWIN TOWERS
# 8   5CG124ZV80    5CG124ZV80  ...                  PETRONAS TWIN TOWERS
# 9   5CG123ZCDD    5CG123ZCDD  ...                  PETRONAS TWIN TOWERS
# 10  5CG123ZCDG    5CG123ZCDG  ...                          Kuala Lumpur
# 11  5CG123ZCCL    5CG123ZCCL  ...                          Kuala Lumpur
# 12  5CG123ZCFL    5CG123ZCFL  ...                          Kuala Lumpur
# 13  CN41182G5N    CN41182G5N  ...                  PETRONAS Twin Towers
# 14         NaN           NaN  ...                  PETRONAS TWIN TOWERS
# 15  CN413039J8    CN413039J8  ...                          Kuala Lumpur
# 16  CN413039JD    CN413039JD  ...                  PETRONAS Twin Towers
# 17  CN41182G64    CN41182G64  ...                          Kuala Lumpur
#
# [18 rows x 44 columns]

# %%
# Set the conditions for determining values in new column: - Part 1

conditions = [
    (merge7['States1'] == 'Kuala Lumpur'),
    (merge7['States1'] == 'KL'),
    (merge7['States1'] == 'Petronas Twin Towers'),
    (merge7['States1'] == 'Selangor'),
    (merge7['States1'] == 'Terengganu'),
    (merge7['States1'] == 'Johor'),
    (merge7['States1'] == 'Melaka'),
    (merge7['States1'] == 'Perlis'),
    (merge7['States1'] == 'Kedah'),
    (merge7['States1'] == 'Perak'),
    (merge7['States1'] == 'Negeri Sembilan'),
    (merge7['States1'] == 'Sarawak'),
    (merge7['States1'] == 'Sabah'),
    (merge7['States1'] == 'Kelantan'),
    (merge7['States1'] == 'Pahang'),
    (merge7['States1'] == 'Pulau Pinang'),
    (merge7['States1'] == 'PETRONAS Twin Towers'),
    (merge7['States1'] == 'Kl'),
    (merge7['States1'] == 'KUALA LUMPUR'),
    (merge7['States1'] == 'Labuan'),
    (merge7['States1'] == 'PETRONAS TWIN TOWERS')]


# Set the new column values in order of the conditions they should
#	correspond to:

choices = ['Central','Central','Central','Central','East Coast','West Coast','West Coast','West Coast','West Coast','West Coast','West Coast','East Malaysia', 'East Malaysia','East Coast','East Coast','West Coast','Central','Central','Central','East Malaysia','Central']

# Add new column based on conditions and choices:

merge7['Region1'] = np.select(conditions, choices, default='')
merge7['Region'] = merge7['Region1']

merge7
# Out:
#           Name Serial Number  ...               States1     Region1
# 0          NaN           NaN  ...                 Johor  West Coast
# 1          NaN           NaN  ...                 Johor  West Coast
# 2          NaN           NaN  ...                 Johor  West Coast
# 3          NaN           NaN  ...                 Johor  West Coast
# 4   5CD135B45J    5CD135B45J  ...                    KL     Central
# ..         ...           ...  ...                   ...         ...
# 71  CND1330L19    CND1330L19  ...          Kuala Lumpur     Central
# 72  5CD04154Z3    5CD04154Z3  ...                    KL     Central
# 73  5CD041551W    5CD041551W  ...          Kuala Lumpur     Central
# 74  5CD0415519    5CD0415519  ...  PETRONAS Twin Towers     Central
# 75  5CD04154Y8    5CD04154Y8  ...  PETRONAS Twin Towers     Central
#
# [76 rows x 45 columns]

# %%
# Set the conditions for determining values in new column: - Part 2

conditions = [
    (macc7['States1'] == 'Kuala Lumpur'),
    (macc7['States1'] == 'KL'),
    (macc7['States1'] == 'Petronas Twin Towers'),
    (macc7['States1'] == 'Selangor'),
    (macc7['States1'] == 'Terengganu'),
    (macc7['States1'] == 'Johor'),
    (macc7['States1'] == 'Melaka'),
    (macc7['States1'] == 'Perlis'),
    (macc7['States1'] == 'Kedah'),
    (macc7['States1'] == 'Perak'),
    (macc7['States1'] == 'Negeri Sembilan'),
    (macc7['States1'] == 'Sarawak'),
    (macc7['States1'] == 'Sabah'),
    (macc7['States1'] == 'Kelantan'),
    (macc7['States1'] == 'Pahang'),
    (macc7['States1'] == 'Pulau Pinang'),
    (macc7['States1'] == 'PETRONAS Twin Towers'),
    (macc7['States1'] == 'Kl'),
    (macc7['States1'] == 'KUALA LUMPUR'),
    (macc7['States1'] == 'Labuan'),
    (macc7['States1'] == 'PETRONAS TWIN TOWERS')]


# Set the new column values in order of the conditions they should
#	correspond to:

choices = ['Central','Central','Central','Central','East Coast','West Coast','West Coast','West Coast','West Coast','West Coast','West Coast','East Malaysia', 'East Malaysia','East Coast','East Coast','West Coast','Central','Central','Central','East Malaysia','Central']

# Add new column based on conditions and choices:

macc7['Region1'] = np.select(conditions, choices, default='')
macc7['Region'] = macc7['Region1']

macc7
# Out:
#           Name Serial Number  ...               States1  Region1
# 0   5CG123ZCDB    5CG123ZCDB  ...          KUALA LUMPUR  Central
# 1   5CG123ZCBL    5CG123ZCBL  ...  PETRONAS TWIN TOWERS  Central
# 2   5CG123ZCCM    5CG123ZCCM  ...  PETRONAS TWIN TOWERS  Central
# 3   5CG124ZWR5    5CG124ZWR5  ...  PETRONAS TWIN TOWERS  Central
# 4   5CG124ZWKV    5CG124ZWKV  ...  PETRONAS TWIN TOWERS  Central
# 5   5CG123ZCRB    5CG123ZCRB  ...  PETRONAS TWIN TOWERS  Central
# 6   5CG115X1R6    5CG115X1R6  ...  PETRONAS TWIN TOWERS  Central
# 7   5CG123ZCDY    5CG123ZCDY  ...  PETRONAS TWIN TOWERS  Central
# 8   5CG124ZV80    5CG124ZV80  ...  PETRONAS TWIN TOWERS  Central
# 9   5CG123ZCDD    5CG123ZCDD  ...  PETRONAS TWIN TOWERS  Central
# 10  5CG123ZCDG    5CG123ZCDG  ...          Kuala Lumpur  Central
# 11  5CG123ZCCL    5CG123ZCCL  ...          Kuala Lumpur  Central
# 12  5CG123ZCFL    5CG123ZCFL  ...          Kuala Lumpur  Central
# 13  CN41182G5N    CN41182G5N  ...  PETRONAS Twin Towers  Central
# 14         NaN           NaN  ...  PETRONAS TWIN TOWERS  Central
# 15  CN413039J8    CN413039J8  ...          Kuala Lumpur  Central
# 16  CN413039JD    CN413039JD  ...  PETRONAS Twin Towers  Central
# 17  CN41182G64    CN41182G64  ...          Kuala Lumpur  Central
#
# [18 rows x 45 columns]

# %%
## Drop states1 and region1 columns - Part 1

merge7 = merge7.drop(['States1','Region1'], axis = 1)


## Drop states1 and region1 columns - Part 2

macc7 = macc7.drop(['States1','Region1'], axis = 1)
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 43 columns]

# %%
## Part 1

merge7['Completion Date1'] = pd.to_datetime(merge7['Completion Date1'], format='%Y-%m-%d')


## Part 2

macc7['Completion Date1'] = pd.to_datetime(macc7['Completion Date1'], format='%Y-%m-%d')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 43 columns]

# %%
## Part 1
merge7.insert(20, 'Lessor', '')

## Part 2
macc7.insert(20, 'Lessor', '')
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 44 columns]

# %%
## Fill up lessor with CTC - Part 1

merge7['Lessor'] = "CTC"


## Fill up lessor with CTC - Part 2

macc7['Lessor'] = "CTC"
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 44 columns]

# %%
## Part 1

merge7 = merge7.loc[:,~merge7.columns.duplicated()]

## Part 2

macc7 = macc7.loc[:,~macc7.columns.duplicated()]
macc7
# Out:
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 41 columns]

# %%
## Part 1

merge7['Completion Date1'] = merge7['Completion Date1'].dt.strftime('%d/%m/%Y')


## Part 2

macc7['Completion Date1'] = macc7['Completion Date1'].dt.strftime('%d/%m/%Y')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 41 columns]

# %%
## Part 1

merge7['ContendDate'] = merge7['ContendDate'].dt.strftime('%d/%m/%Y')


## Part 2

macc7['ContendDate'] = macc7['ContendDate'].dt.strftime('%d/%m/%Y')
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 41 columns]

# %%
## Part 1

merge7["Warranty Start"] = merge7["Completion Date1"]
merge7["Warranty End"] = merge7["ContendDate"]


## Part 2

macc7["Warranty Start"] = macc7["Completion Date1"]
macc7["Warranty End"] = macc7["ContendDate"]
macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 41 columns]

# %%
## Part 1

merge7['Vendor Schedule Number (EOL)'] = 'N/A'
merge7['Return Batch Number (EOL)'] = 'N/A'
merge7['Return Item Number (EOL)'] = 'N/A'
merge7['Return Date To Lessor (EOL)'] = 'N/A'
merge7['Return Date By User (EOL)'] = 'N/A'
merge7['Lessor Returned Verification (EOL)'] = 'N/A'


## Part 2

macc7['Vendor Schedule Number (EOL)'] = 'N/A'
macc7['Return Batch Number (EOL)'] = 'N/A'
macc7['Return Item Number (EOL)'] = 'N/A'
macc7['Return Date To Lessor (EOL)'] = 'N/A'
macc7['Return Date By User (EOL)'] = 'N/A'
macc7['Lessor Returned Verification (EOL)'] = 'N/A'

macc7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Name Serial Number  ...                          STATUS REGISTERED DATE
# 0   5CG123ZCDB    5CG123ZCDB  ...  Requested to Register in  CMDB
# 1   5CG123ZCBL    5CG123ZCBL  ...  Requested to Register in  CMDB
# 2   5CG123ZCCM    5CG123ZCCM  ...  Requested to Register in  CMDB
# 3   5CG124ZWR5    5CG124ZWR5  ...  Requested to Register in  CMDB
# 4   5CG124ZWKV    5CG124ZWKV  ...  Requested to Register in  CMDB
# 5   5CG123ZCRB    5CG123ZCRB  ...  Requested to Register in  CMDB
# 6   5CG115X1R6    5CG115X1R6  ...  Requested to Register in  CMDB
# 7   5CG123ZCDY    5CG123ZCDY  ...  Requested to Register in  CMDB
# 8   5CG124ZV80    5CG124ZV80  ...  Requested to Register in  CMDB
# 9   5CG123ZCDD    5CG123ZCDD  ...  Requested to Register in  CMDB
# 10  5CG123ZCDG    5CG123ZCDG  ...  Requested to Register in  CMDB
# 11  5CG123ZCCL    5CG123ZCCL  ...  Requested to Register in  CMDB
# 12  5CG123ZCFL    5CG123ZCFL  ...  Requested to Register in  CMDB
# 13  CN41182G5N    CN41182G5N  ...  Requested to Register in  CMDB
# 14         NaN           NaN  ...  Requested to Register in  CMDB
# 15  CN413039J8    CN413039J8  ...  Requested to Register in  CMDB
# 16  CN413039JD    CN413039JD  ...  Requested to Register in  CMDB
# 17  CN41182G64    CN41182G64  ...  Requested to Register in  CMDB
#
# [18 rows x 41 columns]

# %%
# acc1 = data1[(data1['Order Item Status'] == 'Completed') & (data1['Service Sub Category'] == 'PC Accessories')]
# acc1

# %%
# ##################################################################################################################################################################################3
# ## Part 1
# # determining the name of the file to be saved (Change the file path here)
# file_name = '/content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx'

# ## Part 2
# # determining the name of the file to be saved (Change the file path here)
# file_acc = '/content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx'
  
# # saving the excel
# merge7.to_excel(file_name,'Desktop')
# print('DataFrame is written to Excel File successfully.')

# # saving the excel
# macc7.to_excel(file_acc,'PC Accessories')
# print('DataFrame is written to Excel File successfully.')

###############################################################################################################################################################################
# Out:
# DataFrame is written to Excel File successfully.
# DataFrame is written to Excel File successfully.

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 5.1 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.2

# %%
path = r"/content/drive/MyDrive/PETRONAS/35 CMDB EUD Batch Upload Template V1.0_18112021.xlsx"

writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
merge7.to_excel(writer, sheet_name = 'Desktop')
macc7.to_excel(writer, sheet_name = 'PC Accessories')
writer.save()
writer.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/xlsxwriter/workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
